# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from helper_functions import *

# %%
#Continueing training?
continued = False
checkpoint_file_to_use = None #Example: 'ckpt_model_01_run01/hourly/model-9350'

#If training from step 0
#############################
naming = 'model_06_run01'
#############################
variables = {
    'modify_images': True,
    'crop_images': False,
    'enlarge_images': False,
    'before_flatten_image_side_size': 4, #Need to calculate
    'first_hidden_layer_features': 384,
    'weights_stddev': 0.015,
    'biases_initial': 0.1,
    'dropout_train_keep_prob': 0.5,
    'learning_rate_initial': 0.1,
    'learning_rate_decay_steps': int(10000000),
    'learning_rate_decay': 1.0,
    'start_step_early_stopping': 150000,
    'early_stopping_patience': 0.1,
    'batch_size': 200,
    'max_steps': 100000000,
    'average_n_validation_accuracy': 8
}

# %%
#Create accuracy_log to pickle and directories for TensorBoard and checkpoint
accuracy_log = prep_accuracy_log(continued, checkpoint_file_to_use, naming, variables)

# %%
#Get data and labels
(train_data, validation_data, test_data, train_labels, validation_labels, test_labels) = get_data_and_labels(accuracy_log)

# %%
#Build a model
crop_images = accuracy_log['variables']['crop_images']
modify_images = accuracy_log['variables']['modify_images']
weights_stddev = accuracy_log['variables']['weights_stddev']
biases_initial = accuracy_log['variables']['biases_initial']
input_image_side_size = accuracy_log['variables']['input_image_side_size']
crop_to_side_size = accuracy_log['variables']['crop_to_side_size']
before_flatten_image_side_size = accuracy_log['variables']['before_flatten_image_side_size']
first_hidden_layer_features = accuracy_log['variables']['first_hidden_layer_features']
learning_rate_initial = accuracy_log['variables']['learning_rate_initial']
learning_rate_decay_steps = accuracy_log['variables']['learning_rate_decay_steps']
learning_rate_decay = accuracy_log['variables']['learning_rate_decay']

graph = tf.Graph()
with graph.as_default():
    global_step = tf.Variable(0, trainable=False)
    is_training = tf.placeholder(tf.bool)
    keep_prob = tf.placeholder(tf.float32)

    data = tf.placeholder(tf.float32, [None, input_image_side_size, input_image_side_size, 3])
    labels = tf.placeholder(tf.float32, [None, 10])
    
    if crop_images & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    elif (not crop_images) & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify_no_crop(data), lambda: tf.identity(data))
    elif crop_images & (not modify_images):
        data_v2 = tf.cond(is_training, lambda: random_crop(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    else:
        data_v2 = tf.identity(data)

    data_v2 = batch_normalize(data_v2, is_training=is_training, global_step=global_step, scope='bn_data_v2')
    W_conv1 = weight_variable([3, 3, 3, 64], weights_stddev, 'W_conv1')
    b_conv1 = bias_variable(biases_initial, [64], 'b_conv1')
    conv1 = conv2d(data_v2, W_conv1) + b_conv1
    conv1_relu = tf.nn.relu(conv1)
    pool1 = max_pool_3x3_stride2(conv1_relu)
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm1 = batch_normalize(norm1, is_training=is_training, global_step=global_step, scope='bn_norm1')
    W_conv2 = weight_variable([3, 3, 64, 64], weights_stddev, 'W_conv2')
    b_conv2 = bias_variable(biases_initial, [64], 'b_conv2')
    conv2 = conv2d(norm1, W_conv2) + b_conv2
    conv2_relu = tf.nn.relu(conv2)
    pool2 = max_pool_3x3_stride2(conv2_relu)
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm2 = batch_normalize(norm2, is_training=is_training, global_step=global_step, scope='bn_norm2')
    W_conv3 = weight_variable([3, 3, 64, 128], weights_stddev, 'W_conv3')
    b_conv3 = bias_variable(biases_initial, [128], 'b_conv3')
    conv3 = conv2d(norm2, W_conv3) + b_conv3
    conv3_relu = tf.nn.relu(conv3)
    pool3 = max_pool_3x3_stride2(conv3_relu)
    norm3 = tf.nn.lrn(pool3, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)
    
    norm3_flat = tf.reshape(norm3, [-1, before_flatten_image_side_size*before_flatten_image_side_size*128])

    norm3_flat = batch_normalize(norm3_flat, is_training=is_training, global_step=global_step, scope='bn_norm3_flat')
    norm3_flat_drop = tf.nn.dropout(norm3_flat, keep_prob)
    W_fc1 = weight_variable([before_flatten_image_side_size*before_flatten_image_side_size*128, first_hidden_layer_features], weights_stddev, 'W_fc1')
    b_fc1 = bias_variable(biases_initial, [first_hidden_layer_features], 'b_fc1')
    fc1 = tf.matmul(norm3_flat_drop, W_fc1) + b_fc1
    fc1_relu = tf.nn.relu(fc1)

    fc1_relu = batch_normalize(fc1_relu, is_training=is_training, global_step=global_step, scope='bn_fc1_relu')    
    fc1_relu_drop = tf.nn.dropout(fc1_relu, keep_prob)
    W_fc2 = weight_variable([first_hidden_layer_features, int(first_hidden_layer_features/2)], weights_stddev, 'W_fc2')
    b_fc2 = bias_variable(biases_initial, [first_hidden_layer_features/2], 'b_fc2')
    fc2 = tf.matmul(fc1_relu_drop, W_fc2) + b_fc2
    fc2_relu = tf.nn.relu(fc2)

    fc2_relu = batch_normalize(fc2_relu, is_training=is_training, global_step=global_step, scope='bn_fc2_relu')
    fc2_relu_drop = tf.nn.dropout(fc2_relu, keep_prob)
    W_fc3 = weight_variable([int(first_hidden_layer_features/2), 10], weights_stddev, 'W_fc3')
    b_fc3 = bias_variable(biases_initial, [10], 'b_fc3')
    logits = tf.matmul(fc2_relu_drop, W_fc3) + b_fc3

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))
    
    learning_rate = tf.train.exponential_decay(learning_rate_initial, global_step, learning_rate_decay_steps, 
                                               learning_rate_decay, staircase=True)
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    tf.summary.scalar('loss', loss)
    tf.summary.scalar('learning_rate', learning_rate)
    tf.summary.scalar('training_accuracy', accuracy)
    
    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name, var)
    
    summarizer = tf.summary.merge_all()
    
graph_variables = {'graph': graph, 
                   'optimizer': optimizer, 
                   'summarizer': summarizer, 
                   'data': data, 
                   'labels': labels, 
                   'keep_prob': keep_prob, 
                   'is_training': is_training, 
                   'correct_prediction': correct_prediction,
                   'accuracy': accuracy}

# %%
#Train the model
train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
# Out:
# TRAINING   START @ 2016-12-24 04:06:41.231745
# << best model so far is saved in ckpt_model_06_run01/best/model-0 >> ave validation accuracy 0.10140
# STEP       0 END @ 2016-12-24 04:06:50.389634, training accuracy 0.09000, ave validation accuracy 0.10140
# << best model so far is saved in ckpt_model_06_run01/best/model-100 >> ave validation accuracy 0.10975
# << best model so far is saved in ckpt_model_06_run01/best/model-300 >> ave validation accuracy 0.11602
# << best model so far is saved in ckpt_model_06_run01/best/model-400 >> ave validation accuracy 0.12006
# << best model so far is saved in ckpt_model_06_run01/best/model-500 >> ave validation accuracy 0.12925
# << best model so far is saved in ckpt_model_06_run01/best/model-1000 >> ave validation accuracy 0.13640
# STEP    1000 END @ 2016-12-24 04:09:00.190518, training accuracy 0.18500, ave validation accuracy 0.13640
# << best model so far is saved in ckpt_model_06_run01/best/model-1100 >> ave validation accuracy 0.14444
# << best model so far is saved in ckpt_model_06_run01/best/model-1200 >> ave validation accuracy 0.16591
# << best model so far is saved in ckpt_model_06_run01/best/model-1300 >> ave validation accuracy 0.18909
# << best model so far is saved in ckpt_model_06_run01/best/model-1400 >> ave validation accuracy 0.22004
# << best model so far is saved in ckpt_model_06_run01/best/model-1500 >> ave validation accuracy 0.26192
# << best model so far is saved in ckpt_model_06_run01/best/model-1600 >> ave validation accuracy 0.31014
# << best model so far is saved in ckpt_model_06_run01/best/model-1700 >> ave validation accuracy 0.36134
# << best model so far is saved in ckpt_model_06_run01/best/model-1800 >> ave validation accuracy 0.40947
# << best model so far is saved in ckpt_model_06_run01/best/model-1900 >> ave validation accuracy 0.46676
# << best model so far is saved in ckpt_model_06_run01/best/model-2000 >> ave validation accuracy 0.50829
# STEP    2000 END @ 2016-12-24 04:11:33.552105, training accuracy 0.77500, ave validation accuracy 0.50829
# << best model so far is saved in ckpt_model_06_run01/best/model-2100 >> ave validation accuracy 0.55242
# << best model so far is saved in ckpt_model_06_run01/best/model-2200 >> ave validation accuracy 0.59804
# << best model so far is saved in ckpt_model_06_run01/best/model-2300 >> ave validation accuracy 0.63467
# << best model so far is saved in ckpt_model_06_run01/best/model-2400 >> ave validation accuracy 0.66325
# << best model so far is saved in ckpt_model_06_run01/best/model-2500 >> ave validation accuracy 0.68856
# << best model so far is saved in ckpt_model_06_run01/best/model-2600 >> ave validation accuracy 0.71411
# << best model so far is saved in ckpt_model_06_run01/best/model-2700 >> ave validation accuracy 0.72892
# << best model so far is saved in ckpt_model_06_run01/best/model-2800 >> ave validation accuracy 0.74609
# << best model so far is saved in ckpt_model_06_run01/best/model-2900 >> ave validation accuracy 0.75433
# << best model so far is saved in ckpt_model_06_run01/best/model-3000 >> ave validation accuracy 0.76110
# STEP    3000 END @ 2016-12-24 04:14:04.456029, training accuracy 0.85500, ave validation accuracy 0.76110
# << best model so far is saved in ckpt_model_06_run01/best/model-3100 >> ave validation accuracy 0.76709
# << best model so far is saved in ckpt_model_06_run01/best/model-3200 >> ave validation accuracy 0.77264
# << best model so far is saved in ckpt_model_06_run01/best/model-3300 >> ave validation accuracy 0.77848
# << best model so far is saved in ckpt_model_06_run01/best/model-3400 >> ave validation accuracy 0.78159
# << best model so far is saved in ckpt_model_06_run01/best/model-3500 >> ave validation accuracy 0.78388
# << best model so far is saved in ckpt_model_06_run01/best/model-3600 >> ave validation accuracy 0.78610
# << best model so far is saved in ckpt_model_06_run01/best/model-3700 >> ave validation accuracy 0.78903
# << best model so far is saved in ckpt_model_06_run01/best/model-3800 >> ave validation accuracy 0.79201
# << best model so far is saved in ckpt_model_06_run01/best/model-3900 >> ave validation accuracy 0.79444
# << best model so far is saved in ckpt_model_06_run01/best/model-4000 >> ave validation accuracy 0.79643
# STEP    4000 END @ 2016-12-24 04:16:39.512963, training accuracy 0.79500, ave validation accuracy 0.79643
# << best model so far is saved in ckpt_model_06_run01/best/model-4100 >> ave validation accuracy 0.79736
# << best model so far is saved in ckpt_model_06_run01/best/model-4200 >> ave validation accuracy 0.79851
# << best model so far is saved in ckpt_model_06_run01/best/model-4300 >> ave validation accuracy 0.79980
# << best model so far is saved in ckpt_model_06_run01/best/model-4400 >> ave validation accuracy 0.80014
# << best model so far is saved in ckpt_model_06_run01/best/model-4500 >> ave validation accuracy 0.80063
# << best model so far is saved in ckpt_model_06_run01/best/model-4700 >> ave validation accuracy 0.80071
# << best model so far is saved in ckpt_model_06_run01/best/model-4800 >> ave validation accuracy 0.80160
# << best model so far is saved in ckpt_model_06_run01/best/model-4900 >> ave validation accuracy 0.80338
# << best model so far is saved in ckpt_model_06_run01/best/model-5000 >> ave validation accuracy 0.80488
# STEP    5000 END @ 2016-12-24 04:19:07.805294, training accuracy 0.86500, ave validation accuracy 0.80488
# << best model so far is saved in ckpt_model_06_run01/best/model-5200 >> ave validation accuracy 0.80621
# << best model so far is saved in ckpt_model_06_run01/best/model-5300 >> ave validation accuracy 0.80689
# << best model so far is saved in ckpt_model_06_run01/best/model-5400 >> ave validation accuracy 0.80916
# << best model so far is saved in ckpt_model_06_run01/best/model-5500 >> ave validation accuracy 0.81040
# << best model so far is saved in ckpt_model_06_run01/best/model-5600 >> ave validation accuracy 0.81095
# << best model so far is saved in ckpt_model_06_run01/best/model-5700 >> ave validation accuracy 0.81173
# << best model so far is saved in ckpt_model_06_run01/best/model-5800 >> ave validation accuracy 0.81190
# << best model so far is saved in ckpt_model_06_run01/best/model-5900 >> ave validation accuracy 0.81383
# << best model so far is saved in ckpt_model_06_run01/best/model-6000 >> ave validation accuracy 0.81474
# STEP    6000 END @ 2016-12-24 04:21:34.676194, training accuracy 0.89000, ave validation accuracy 0.81474
# << best model so far is saved in ckpt_model_06_run01/best/model-6100 >> ave validation accuracy 0.81594
# << best model so far is saved in ckpt_model_06_run01/best/model-6200 >> ave validation accuracy 0.81633
# << best model so far is saved in ckpt_model_06_run01/best/model-6300 >> ave validation accuracy 0.81763
# << best model so far is saved in ckpt_model_06_run01/best/model-6400 >> ave validation accuracy 0.81856
# << best model so far is saved in ckpt_model_06_run01/best/model-6600 >> ave validation accuracy 0.81871
# << best model so far is saved in ckpt_model_06_run01/best/model-6700 >> ave validation accuracy 0.81926
# << best model so far is saved in ckpt_model_06_run01/best/model-6800 >> ave validation accuracy 0.82033
# << best model so far is saved in ckpt_model_06_run01/best/model-6900 >> ave validation accuracy 0.82088
# << best model so far is saved in ckpt_model_06_run01/best/model-7000 >> ave validation accuracy 0.82190
# STEP    7000 END @ 2016-12-24 04:24:03.179988, training accuracy 0.93000, ave validation accuracy 0.82190
# << best model so far is saved in ckpt_model_06_run01/best/model-7100 >> ave validation accuracy 0.82198
# << best model so far is saved in ckpt_model_06_run01/best/model-7200 >> ave validation accuracy 0.82286
# << best model so far is saved in ckpt_model_06_run01/best/model-7300 >> ave validation accuracy 0.82373
# << best model so far is saved in ckpt_model_06_run01/best/model-7400 >> ave validation accuracy 0.82465
# << best model so far is saved in ckpt_model_06_run01/best/model-7500 >> ave validation accuracy 0.82545
# << best model so far is saved in ckpt_model_06_run01/best/model-7600 >> ave validation accuracy 0.82556
# << best model so far is saved in ckpt_model_06_run01/best/model-7800 >> ave validation accuracy 0.82581
# << best model so far is saved in ckpt_model_06_run01/best/model-7900 >> ave validation accuracy 0.82620
# << best model so far is saved in ckpt_model_06_run01/best/model-8000 >> ave validation accuracy 0.82709
# STEP    8000 END @ 2016-12-24 04:26:30.870423, training accuracy 0.92500, ave validation accuracy 0.82709
# << best model so far is saved in ckpt_model_06_run01/best/model-8100 >> ave validation accuracy 0.82796
# << best model so far is saved in ckpt_model_06_run01/best/model-8200 >> ave validation accuracy 0.82906
# << best model so far is saved in ckpt_model_06_run01/best/model-8400 >> ave validation accuracy 0.82935
# << best model so far is saved in ckpt_model_06_run01/best/model-8500 >> ave validation accuracy 0.82973
# << best model so far is saved in ckpt_model_06_run01/best/model-8700 >> ave validation accuracy 0.83076
# << best model so far is saved in ckpt_model_06_run01/best/model-8900 >> ave validation accuracy 0.83108
# << best model so far is saved in ckpt_model_06_run01/best/model-9000 >> ave validation accuracy 0.83164
# STEP    9000 END @ 2016-12-24 04:28:48.076235, training accuracy 0.90500, ave validation accuracy 0.83164
# << best model so far is saved in ckpt_model_06_run01/best/model-9100 >> ave validation accuracy 0.83239
# << best model so far is saved in ckpt_model_06_run01/best/model-9300 >> ave validation accuracy 0.83286
# << best model so far is saved in ckpt_model_06_run01/best/model-9400 >> ave validation accuracy 0.83389
# STEP   10000 END @ 2016-12-24 04:30:44.902656, training accuracy 0.91000, ave validation accuracy 0.83304
# << best model so far is saved in ckpt_model_06_run01/best/model-10200 >> ave validation accuracy 0.83434
# << best model so far is saved in ckpt_model_06_run01/best/model-10300 >> ave validation accuracy 0.83539
# << best model so far is saved in ckpt_model_06_run01/best/model-10400 >> ave validation accuracy 0.83614
# << best model so far is saved in ckpt_model_06_run01/best/model-10500 >> ave validation accuracy 0.83679
# << best model so far is saved in ckpt_model_06_run01/best/model-10600 >> ave validation accuracy 0.83753
# STEP   11000 END @ 2016-12-24 04:32:51.252048, training accuracy 0.94000, ave validation accuracy 0.83691
# << best model so far is saved in ckpt_model_06_run01/best/model-11200 >> ave validation accuracy 0.83795
# << best model so far is saved in ckpt_model_06_run01/best/model-11500 >> ave validation accuracy 0.83870
# STEP   12000 END @ 2016-12-24 04:34:41.226536, training accuracy 0.93500, ave validation accuracy 0.83795
# << best model so far is saved in ckpt_model_06_run01/best/model-12200 >> ave validation accuracy 0.83919
# << best model so far is saved in ckpt_model_06_run01/best/model-12400 >> ave validation accuracy 0.83959
# << best model so far is saved in ckpt_model_06_run01/best/model-12500 >> ave validation accuracy 0.83980
# << best model so far is saved in ckpt_model_06_run01/best/model-12600 >> ave validation accuracy 0.84070
# << best model so far is saved in ckpt_model_06_run01/best/model-12700 >> ave validation accuracy 0.84170
# << best model so far is saved in ckpt_model_06_run01/best/model-13000 >> ave validation accuracy 0.84208
# STEP   13000 END @ 2016-12-24 04:36:52.837219, training accuracy 0.93000, ave validation accuracy 0.84208
# << best model so far is saved in ckpt_model_06_run01/best/model-13100 >> ave validation accuracy 0.84260
# << best model so far is saved in ckpt_model_06_run01/best/model-13200 >> ave validation accuracy 0.84303
# << best model so far is saved in ckpt_model_06_run01/best/model-13600 >> ave validation accuracy 0.84316
# << best model so far is saved in ckpt_model_06_run01/best/model-13700 >> ave validation accuracy 0.84359
# << best model so far is saved in ckpt_model_06_run01/best/model-13800 >> ave validation accuracy 0.84364
# << best model so far is saved in ckpt_model_06_run01/best/model-13900 >> ave validation accuracy 0.84410
# << best model so far is saved in ckpt_model_06_run01/best/model-14000 >> ave validation accuracy 0.84423
# STEP   14000 END @ 2016-12-24 04:39:10.549856, training accuracy 0.95000, ave validation accuracy 0.84423
# << best model so far is saved in ckpt_model_06_run01/best/model-14100 >> ave validation accuracy 0.84433
# << best model so far is saved in ckpt_model_06_run01/best/model-14200 >> ave validation accuracy 0.84443
# << best model so far is saved in ckpt_model_06_run01/best/model-14300 >> ave validation accuracy 0.84448
# << best model so far is saved in ckpt_model_06_run01/best/model-14400 >> ave validation accuracy 0.84464
# << best model so far is saved in ckpt_model_06_run01/best/model-15000 >> ave validation accuracy 0.84476
# STEP   15000 END @ 2016-12-24 04:41:16.948437, training accuracy 0.92000, ave validation accuracy 0.84476
# << best model so far is saved in ckpt_model_06_run01/best/model-15200 >> ave validation accuracy 0.84485
# << best model so far is saved in ckpt_model_06_run01/best/model-15300 >> ave validation accuracy 0.84595
# << best model so far is saved in ckpt_model_06_run01/best/model-15700 >> ave validation accuracy 0.84638
# << best model so far is saved in ckpt_model_06_run01/best/model-15800 >> ave validation accuracy 0.84641
# << best model so far is saved in ckpt_model_06_run01/best/model-15900 >> ave validation accuracy 0.84643
# << best model so far is saved in ckpt_model_06_run01/best/model-16000 >> ave validation accuracy 0.84728
# STEP   16000 END @ 2016-12-24 04:43:28.760333, training accuracy 0.95000, ave validation accuracy 0.84728
# << best model so far is saved in ckpt_model_06_run01/best/model-16100 >> ave validation accuracy 0.84743
# << best model so far is saved in ckpt_model_06_run01/best/model-16300 >> ave validation accuracy 0.84746
# << best model so far is saved in ckpt_model_06_run01/best/model-16400 >> ave validation accuracy 0.84763
# STEP   17000 END @ 2016-12-24 04:45:24.810840, training accuracy 0.95000, ave validation accuracy 0.84734
# << best model so far is saved in ckpt_model_06_run01/best/model-17900 >> ave validation accuracy 0.84795
# STEP   18000 END @ 2016-12-24 04:47:09.147312, training accuracy 0.94500, ave validation accuracy 0.84755
# << best model so far is saved in ckpt_model_06_run01/best/model-18100 >> ave validation accuracy 0.84830
# << best model so far is saved in ckpt_model_06_run01/best/model-18200 >> ave validation accuracy 0.84851
# << best model so far is saved in ckpt_model_06_run01/best/model-18300 >> ave validation accuracy 0.84905
# << best model so far is saved in ckpt_model_06_run01/best/model-18400 >> ave validation accuracy 0.84911
# << best model so far is saved in ckpt_model_06_run01/best/model-18500 >> ave validation accuracy 0.85013
# << best model so far is saved in ckpt_model_06_run01/best/model-18600 >> ave validation accuracy 0.85026
# << best model so far is saved in ckpt_model_06_run01/best/model-18700 >> ave validation accuracy 0.85054
# << best model so far is saved in ckpt_model_06_run01/best/model-18800 >> ave validation accuracy 0.85129
# << best model so far is saved in ckpt_model_06_run01/best/model-18900 >> ave validation accuracy 0.85130
# << best model so far is saved in ckpt_model_06_run01/best/model-19000 >> ave validation accuracy 0.85193
# STEP   19000 END @ 2016-12-24 04:49:42.030303, training accuracy 0.97000, ave validation accuracy 0.85193
# << best model so far is saved in ckpt_model_06_run01/best/model-19100 >> ave validation accuracy 0.85236
# << best model so far is saved in ckpt_model_06_run01/best/model-19200 >> ave validation accuracy 0.85250
# STEP   20000 END @ 2016-12-24 04:51:32.706105, training accuracy 0.96500, ave validation accuracy 0.85118
# << best model so far is saved in ckpt_model_06_run01/best/model-20900 >> ave validation accuracy 0.85274
# STEP   21000 END @ 2016-12-24 04:53:18.572512, training accuracy 0.97000, ave validation accuracy 0.85268
# << best model so far is saved in ckpt_model_06_run01/best/model-21600 >> ave validation accuracy 0.85305
# STEP   22000 END @ 2016-12-24 04:55:03.139897, training accuracy 0.96000, ave validation accuracy 0.85221
# << best model so far is saved in ckpt_model_06_run01/best/model-22900 >> ave validation accuracy 0.85340
# STEP   23000 END @ 2016-12-24 04:56:47.532982, training accuracy 0.98000, ave validation accuracy 0.85330
# << best model so far is saved in ckpt_model_06_run01/best/model-23100 >> ave validation accuracy 0.85385
# << best model so far is saved in ckpt_model_06_run01/best/model-23200 >> ave validation accuracy 0.85420
# STEP   24000 END @ 2016-12-24 04:58:35.300767, training accuracy 0.96000, ave validation accuracy 0.85410
# << best model so far is saved in ckpt_model_06_run01/best/model-24200 >> ave validation accuracy 0.85434
# << best model so far is saved in ckpt_model_06_run01/best/model-24300 >> ave validation accuracy 0.85444
# << best model so far is saved in ckpt_model_06_run01/best/model-24400 >> ave validation accuracy 0.85543
# << best model so far is saved in ckpt_model_06_run01/best/model-24500 >> ave validation accuracy 0.85603
# << best model so far is saved in ckpt_model_06_run01/best/model-24600 >> ave validation accuracy 0.85606
# STEP   25000 END @ 2016-12-24 05:00:42.239774, training accuracy 0.95500, ave validation accuracy 0.85529
# STEP   26000 END @ 2016-12-24 05:02:21.838248, training accuracy 0.98500, ave validation accuracy 0.85494
# << best model so far is saved in ckpt_model_06_run01/best/model-26600 >> ave validation accuracy 0.85678
# << best model so far is saved in ckpt_model_06_run01/best/model-26700 >> ave validation accuracy 0.85730
# << best model so far is saved in ckpt_model_06_run01/best/model-26900 >> ave validation accuracy 0.85784
# << best model so far is saved in ckpt_model_06_run01/best/model-27000 >> ave validation accuracy 0.85815
# STEP   27000 END @ 2016-12-24 05:04:22.264348, training accuracy 0.95500, ave validation accuracy 0.85815
# << best model so far is saved in ckpt_model_06_run01/best/model-27500 >> ave validation accuracy 0.85838
# STEP   28000 END @ 2016-12-24 05:06:06.032127, training accuracy 0.97000, ave validation accuracy 0.85675
# << hourly save at ckpt_model_06_run01/hourly/model-28400 and pickle_model_06_run01 >>
# STEP   29000 END @ 2016-12-24 05:07:50.490123, training accuracy 0.96500, ave validation accuracy 0.85771
# STEP   30000 END @ 2016-12-24 05:09:30.067619, training accuracy 0.97000, ave validation accuracy 0.85664
# STEP   31000 END @ 2016-12-24 05:11:09.657771, training accuracy 0.98500, ave validation accuracy 0.85698
# << best model so far is saved in ckpt_model_06_run01/best/model-31900 >> ave validation accuracy 0.85885
# STEP   32000 END @ 2016-12-24 05:12:53.585894, training accuracy 0.99000, ave validation accuracy 0.85880
# << best model so far is saved in ckpt_model_06_run01/best/model-32200 >> ave validation accuracy 0.85960
# << best model so far is saved in ckpt_model_06_run01/best/model-32500 >> ave validation accuracy 0.85976
# STEP   33000 END @ 2016-12-24 05:14:44.428710, training accuracy 0.97500, ave validation accuracy 0.85875
# STEP   34000 END @ 2016-12-24 05:16:23.708689, training accuracy 0.98500, ave validation accuracy 0.85801
# << best model so far is saved in ckpt_model_06_run01/best/model-35000 >> ave validation accuracy 0.85990
# STEP   35000 END @ 2016-12-24 05:18:07.685787, training accuracy 0.97500, ave validation accuracy 0.85990
# << best model so far is saved in ckpt_model_06_run01/best/model-35200 >> ave validation accuracy 0.85998
# STEP   36000 END @ 2016-12-24 05:19:52.177771, training accuracy 0.98000, ave validation accuracy 0.85880
# << best model so far is saved in ckpt_model_06_run01/best/model-36300 >> ave validation accuracy 0.86009
# << best model so far is saved in ckpt_model_06_run01/best/model-36400 >> ave validation accuracy 0.86015
# << best model so far is saved in ckpt_model_06_run01/best/model-36700 >> ave validation accuracy 0.86033
# << best model so far is saved in ckpt_model_06_run01/best/model-36800 >> ave validation accuracy 0.86093
# << best model so far is saved in ckpt_model_06_run01/best/model-36900 >> ave validation accuracy 0.86123
# STEP   37000 END @ 2016-12-24 05:21:58.449427, training accuracy 0.99500, ave validation accuracy 0.86110
# STEP   38000 END @ 2016-12-24 05:23:37.371110, training accuracy 0.98000, ave validation accuracy 0.86078
# STEP   39000 END @ 2016-12-24 05:25:16.467610, training accuracy 0.98500, ave validation accuracy 0.85981
# STEP   40000 END @ 2016-12-24 05:26:55.731677, training accuracy 0.98500, ave validation accuracy 0.86050
# STEP   41000 END @ 2016-12-24 05:28:35.339278, training accuracy 0.98500, ave validation accuracy 0.86061
# << best model so far is saved in ckpt_model_06_run01/best/model-41300 >> ave validation accuracy 0.86145
# STEP   42000 END @ 2016-12-24 05:30:19.743818, training accuracy 0.99000, ave validation accuracy 0.86063
# STEP   43000 END @ 2016-12-24 05:31:59.597746, training accuracy 0.99000, ave validation accuracy 0.86060
# << best model so far is saved in ckpt_model_06_run01/best/model-43600 >> ave validation accuracy 0.86178
# << best model so far is saved in ckpt_model_06_run01/best/model-43700 >> ave validation accuracy 0.86211
# << best model so far is saved in ckpt_model_06_run01/best/model-44000 >> ave validation accuracy 0.86211
# STEP   44000 END @ 2016-12-24 05:33:55.237798, training accuracy 0.99000, ave validation accuracy 0.86211
# << best model so far is saved in ckpt_model_06_run01/best/model-44100 >> ave validation accuracy 0.86228
# << best model so far is saved in ckpt_model_06_run01/best/model-44200 >> ave validation accuracy 0.86283
# << best model so far is saved in ckpt_model_06_run01/best/model-44300 >> ave validation accuracy 0.86290
# STEP   45000 END @ 2016-12-24 05:35:51.072264, training accuracy 0.98500, ave validation accuracy 0.86138
# STEP   46000 END @ 2016-12-24 05:37:30.627346, training accuracy 0.98000, ave validation accuracy 0.86169
# STEP   47000 END @ 2016-12-24 05:39:10.308987, training accuracy 0.99500, ave validation accuracy 0.86065
# << best model so far is saved in ckpt_model_06_run01/best/model-47600 >> ave validation accuracy 0.86304
# << best model so far is saved in ckpt_model_06_run01/best/model-47700 >> ave validation accuracy 0.86316
# STEP   48000 END @ 2016-12-24 05:41:00.817690, training accuracy 0.99500, ave validation accuracy 0.86235
# STEP   49000 END @ 2016-12-24 05:42:39.873934, training accuracy 0.99000, ave validation accuracy 0.86120
# STEP   50000 END @ 2016-12-24 05:44:19.419893, training accuracy 0.98000, ave validation accuracy 0.86273
# << best model so far is saved in ckpt_model_06_run01/best/model-50100 >> ave validation accuracy 0.86326
# << best model so far is saved in ckpt_model_06_run01/best/model-50200 >> ave validation accuracy 0.86331
# STEP   51000 END @ 2016-12-24 05:46:08.856147, training accuracy 0.98500, ave validation accuracy 0.86164
# << best model so far is saved in ckpt_model_06_run01/best/model-51900 >> ave validation accuracy 0.86365
# STEP   52000 END @ 2016-12-24 05:47:53.193741, training accuracy 0.99500, ave validation accuracy 0.86359
# STEP   53000 END @ 2016-12-24 05:49:32.986802, training accuracy 0.99500, ave validation accuracy 0.86173
# STEP   54000 END @ 2016-12-24 05:51:12.077475, training accuracy 1.00000, ave validation accuracy 0.86199
# STEP   55000 END @ 2016-12-24 05:52:51.344820, training accuracy 0.98000, ave validation accuracy 0.86116
# STEP   56000 END @ 2016-12-24 05:54:30.826479, training accuracy 1.00000, ave validation accuracy 0.86201
# STEP   57000 END @ 2016-12-24 05:56:09.940456, training accuracy 0.99500, ave validation accuracy 0.86294
# STEP   58000 END @ 2016-12-24 05:57:49.522764, training accuracy 0.99000, ave validation accuracy 0.86303
# << best model so far is saved in ckpt_model_06_run01/best/model-58700 >> ave validation accuracy 0.86403
# << best model so far is saved in ckpt_model_06_run01/best/model-58900 >> ave validation accuracy 0.86404
# << best model so far is saved in ckpt_model_06_run01/best/model-59000 >> ave validation accuracy 0.86419
# STEP   59000 END @ 2016-12-24 05:59:44.240567, training accuracy 1.00000, ave validation accuracy 0.86419
# << best model so far is saved in ckpt_model_06_run01/best/model-59100 >> ave validation accuracy 0.86433
# STEP   60000 END @ 2016-12-24 06:01:28.708905, training accuracy 0.99000, ave validation accuracy 0.86353
# STEP   61000 END @ 2016-12-24 06:03:07.608881, training accuracy 0.99500, ave validation accuracy 0.86296
# STEP   62000 END @ 2016-12-24 06:04:46.764312, training accuracy 0.99000, ave validation accuracy 0.86376
# STEP   63000 END @ 2016-12-24 06:06:26.362815, training accuracy 1.00000, ave validation accuracy 0.86245
# << hourly save at ckpt_model_06_run01/hourly/model-63300 and pickle_model_06_run01 >>
# STEP   64000 END @ 2016-12-24 06:08:12.684626, training accuracy 0.99500, ave validation accuracy 0.86378
# STEP   65000 END @ 2016-12-24 06:09:52.229801, training accuracy 1.00000, ave validation accuracy 0.86378
# << best model so far is saved in ckpt_model_06_run01/best/model-65800 >> ave validation accuracy 0.86451
# STEP   66000 END @ 2016-12-24 06:11:36.298344, training accuracy 1.00000, ave validation accuracy 0.86370
# STEP   67000 END @ 2016-12-24 06:13:15.337615, training accuracy 0.99500, ave validation accuracy 0.86268
# STEP   68000 END @ 2016-12-24 06:14:54.845295, training accuracy 1.00000, ave validation accuracy 0.86321
# STEP   69000 END @ 2016-12-24 06:16:34.288850, training accuracy 0.99500, ave validation accuracy 0.86278
# STEP   70000 END @ 2016-12-24 06:18:13.831075, training accuracy 0.99500, ave validation accuracy 0.86243
# STEP   71000 END @ 2016-12-24 06:19:53.096197, training accuracy 1.00000, ave validation accuracy 0.86276
# STEP   72000 END @ 2016-12-24 06:21:32.192741, training accuracy 0.98500, ave validation accuracy 0.86394
# STEP   73000 END @ 2016-12-24 06:23:11.472596, training accuracy 1.00000, ave validation accuracy 0.86401
# STEP   74000 END @ 2016-12-24 06:24:51.040335, training accuracy 0.99500, ave validation accuracy 0.86384
# STEP   75000 END @ 2016-12-24 06:26:30.411494, training accuracy 1.00000, ave validation accuracy 0.86286
# STEP   76000 END @ 2016-12-24 06:28:10.229337, training accuracy 0.99500, ave validation accuracy 0.86175
# STEP   77000 END @ 2016-12-24 06:29:49.550132, training accuracy 0.99500, ave validation accuracy 0.86230
# STEP   78000 END @ 2016-12-24 06:31:28.998719, training accuracy 1.00000, ave validation accuracy 0.86374
# << best model so far is saved in ckpt_model_06_run01/best/model-78500 >> ave validation accuracy 0.86453
# STEP   79000 END @ 2016-12-24 06:33:13.605529, training accuracy 1.00000, ave validation accuracy 0.86216
# STEP   80000 END @ 2016-12-24 06:34:52.709247, training accuracy 1.00000, ave validation accuracy 0.86281
# STEP   81000 END @ 2016-12-24 06:36:31.997168, training accuracy 1.00000, ave validation accuracy 0.86220
# STEP   82000 END @ 2016-12-24 06:38:11.323417, training accuracy 1.00000, ave validation accuracy 0.86326
# STEP   83000 END @ 2016-12-24 06:39:50.818078, training accuracy 1.00000, ave validation accuracy 0.86331
# STEP   84000 END @ 2016-12-24 06:41:29.918777, training accuracy 1.00000, ave validation accuracy 0.86351
# STEP   85000 END @ 2016-12-24 06:43:09.074520, training accuracy 1.00000, ave validation accuracy 0.86313
# STEP   86000 END @ 2016-12-24 06:44:48.172254, training accuracy 1.00000, ave validation accuracy 0.86368
# STEP   87000 END @ 2016-12-24 06:46:27.148267, training accuracy 1.00000, ave validation accuracy 0.86393
# STEP   88000 END @ 2016-12-24 06:48:06.322438, training accuracy 1.00000, ave validation accuracy 0.86069
# STEP   89000 END @ 2016-12-24 06:49:45.683604, training accuracy 1.00000, ave validation accuracy 0.86341
# STEP   90000 END @ 2016-12-24 06:51:24.638877, training accuracy 0.99500, ave validation accuracy 0.86283
# STEP   91000 END @ 2016-12-24 06:53:04.005525, training accuracy 1.00000, ave validation accuracy 0.86344
# STEP   92000 END @ 2016-12-24 06:54:43.352630, training accuracy 0.99500, ave validation accuracy 0.86316
# STEP   93000 END @ 2016-12-24 06:56:22.499061, training accuracy 1.00000, ave validation accuracy 0.86361
# STEP   94000 END @ 2016-12-24 06:58:01.895991, training accuracy 0.99500, ave validation accuracy 0.86238
# STEP   95000 END @ 2016-12-24 06:59:40.986422, training accuracy 1.00000, ave validation accuracy 0.86326
# STEP   96000 END @ 2016-12-24 07:01:19.921359, training accuracy 1.00000, ave validation accuracy 0.86335
# STEP   97000 END @ 2016-12-24 07:02:59.409003, training accuracy 1.00000, ave validation accuracy 0.86363
# STEP   98000 END @ 2016-12-24 07:04:38.437606, training accuracy 1.00000, ave validation accuracy 0.86286
# STEP   99000 END @ 2016-12-24 07:06:17.815972, training accuracy 1.00000, ave validation accuracy 0.86333
# << hourly save at ckpt_model_06_run01/hourly/model-99500 and pickle_model_06_run01 >>
# STEP  100000 END @ 2016-12-24 07:08:02.078776, training accuracy 0.99500, ave validation accuracy 0.86321
# STEP  101000 END @ 2016-12-24 07:09:41.240064, training accuracy 1.00000, ave validation accuracy 0.86273
# STEP  102000 END @ 2016-12-24 07:11:20.361213, training accuracy 1.00000, ave validation accuracy 0.86291
# STEP  103000 END @ 2016-12-24 07:12:59.684796, training accuracy 1.00000, ave validation accuracy 0.86320
# << best model so far is saved in ckpt_model_06_run01/best/model-104000 >> ave validation accuracy 0.86479
# STEP  104000 END @ 2016-12-24 07:14:44.165365, training accuracy 1.00000, ave validation accuracy 0.86479
# << best model so far is saved in ckpt_model_06_run01/best/model-104200 >> ave validation accuracy 0.86499
# STEP  105000 END @ 2016-12-24 07:16:28.777151, training accuracy 1.00000, ave validation accuracy 0.86296
# STEP  106000 END @ 2016-12-24 07:18:08.294147, training accuracy 1.00000, ave validation accuracy 0.86443
# STEP  107000 END @ 2016-12-24 07:19:48.081602, training accuracy 1.00000, ave validation accuracy 0.86395
# STEP  108000 END @ 2016-12-24 07:21:27.211277, training accuracy 1.00000, ave validation accuracy 0.86300
# STEP  109000 END @ 2016-12-24 07:23:06.233549, training accuracy 1.00000, ave validation accuracy 0.86224
# STEP  110000 END @ 2016-12-24 07:24:45.744329, training accuracy 1.00000, ave validation accuracy 0.86378
# STEP  111000 END @ 2016-12-24 07:26:24.707240, training accuracy 1.00000, ave validation accuracy 0.86341
# STEP  112000 END @ 2016-12-24 07:28:04.090420, training accuracy 0.99500, ave validation accuracy 0.86401
# STEP  113000 END @ 2016-12-24 07:29:43.799544, training accuracy 1.00000, ave validation accuracy 0.86308
# STEP  114000 END @ 2016-12-24 07:31:23.078122, training accuracy 1.00000, ave validation accuracy 0.86291
# STEP  115000 END @ 2016-12-24 07:33:02.369539, training accuracy 1.00000, ave validation accuracy 0.86405
# STEP  116000 END @ 2016-12-24 07:34:42.112275, training accuracy 1.00000, ave validation accuracy 0.86351
# STEP  117000 END @ 2016-12-24 07:36:21.467118, training accuracy 1.00000, ave validation accuracy 0.86386
# << best model so far is saved in ckpt_model_06_run01/best/model-117600 >> ave validation accuracy 0.86501
# STEP  118000 END @ 2016-12-24 07:38:04.693260, training accuracy 1.00000, ave validation accuracy 0.86426
# STEP  119000 END @ 2016-12-24 07:39:43.902946, training accuracy 1.00000, ave validation accuracy 0.86369
# STEP  120000 END @ 2016-12-24 07:41:23.160413, training accuracy 1.00000, ave validation accuracy 0.86379
# STEP  121000 END @ 2016-12-24 07:43:02.096307, training accuracy 1.00000, ave validation accuracy 0.86403
# STEP  122000 END @ 2016-12-24 07:44:41.829415, training accuracy 1.00000, ave validation accuracy 0.86325
# STEP  123000 END @ 2016-12-24 07:46:20.810029, training accuracy 1.00000, ave validation accuracy 0.86300
# STEP  124000 END @ 2016-12-24 07:48:00.278443, training accuracy 1.00000, ave validation accuracy 0.86421
# << best model so far is saved in ckpt_model_06_run01/best/model-124500 >> ave validation accuracy 0.86523
# << best model so far is saved in ckpt_model_06_run01/best/model-124700 >> ave validation accuracy 0.86529
# STEP  125000 END @ 2016-12-24 07:49:51.075371, training accuracy 1.00000, ave validation accuracy 0.86506
# STEP  126000 END @ 2016-12-24 07:51:30.403270, training accuracy 0.99500, ave validation accuracy 0.86424
# << best model so far is saved in ckpt_model_06_run01/best/model-126400 >> ave validation accuracy 0.86594
# STEP  127000 END @ 2016-12-24 07:53:14.678674, training accuracy 1.00000, ave validation accuracy 0.86558
# STEP  128000 END @ 2016-12-24 07:54:54.309235, training accuracy 1.00000, ave validation accuracy 0.86515
# STEP  129000 END @ 2016-12-24 07:56:33.516550, training accuracy 1.00000, ave validation accuracy 0.86511
# STEP  130000 END @ 2016-12-24 07:58:12.927391, training accuracy 1.00000, ave validation accuracy 0.86538
# STEP  131000 END @ 2016-12-24 07:59:52.354571, training accuracy 1.00000, ave validation accuracy 0.86520
# STEP  132000 END @ 2016-12-24 08:01:31.771277, training accuracy 1.00000, ave validation accuracy 0.86498
# STEP  133000 END @ 2016-12-24 08:03:10.804799, training accuracy 1.00000, ave validation accuracy 0.86436
# STEP  134000 END @ 2016-12-24 08:04:50.086382, training accuracy 0.99500, ave validation accuracy 0.86464
# STEP  135000 END @ 2016-12-24 08:06:29.414343, training accuracy 1.00000, ave validation accuracy 0.86405
# << hourly save at ckpt_model_06_run01/hourly/model-135500 and pickle_model_06_run01 >>
# STEP  136000 END @ 2016-12-24 08:08:14.998880, training accuracy 0.99000, ave validation accuracy 0.86408
# STEP  137000 END @ 2016-12-24 08:09:54.389649, training accuracy 1.00000, ave validation accuracy 0.86401
# STEP  138000 END @ 2016-12-24 08:11:33.707929, training accuracy 1.00000, ave validation accuracy 0.86365
# STEP  139000 END @ 2016-12-24 08:13:13.355908, training accuracy 1.00000, ave validation accuracy 0.86476
# STEP  140000 END @ 2016-12-24 08:14:52.566711, training accuracy 1.00000, ave validation accuracy 0.86446
# STEP  141000 END @ 2016-12-24 08:16:31.888588, training accuracy 1.00000, ave validation accuracy 0.86323
# STEP  142000 END @ 2016-12-24 08:18:11.410987, training accuracy 1.00000, ave validation accuracy 0.86453
# STEP  143000 END @ 2016-12-24 08:19:50.773419, training accuracy 1.00000, ave validation accuracy 0.86351
# STEP  144000 END @ 2016-12-24 08:21:29.702257, training accuracy 0.99500, ave validation accuracy 0.86429
# STEP  145000 END @ 2016-12-24 08:23:08.762585, training accuracy 1.00000, ave validation accuracy 0.86486
# STEP  146000 END @ 2016-12-24 08:24:48.293463, training accuracy 1.00000, ave validation accuracy 0.86354
# STEP  147000 END @ 2016-12-24 08:26:27.633263, training accuracy 1.00000, ave validation accuracy 0.86421
# STEP  148000 END @ 2016-12-24 08:28:06.842769, training accuracy 1.00000, ave validation accuracy 0.86413
# STEP  149000 END @ 2016-12-24 08:29:46.425969, training accuracy 1.00000, ave validation accuracy 0.86356
# STEP  150000 END @ 2016-12-24 08:31:25.854343, training accuracy 1.00000, ave validation accuracy 0.86436
# STEP  151000 END @ 2016-12-24 08:33:04.906520, training accuracy 1.00000, ave validation accuracy 0.86429
# STEP  152000 END @ 2016-12-24 08:34:43.948319, training accuracy 1.00000, ave validation accuracy 0.86413
# STEP  153000 END @ 2016-12-24 08:36:23.355936, training accuracy 1.00000, ave validation accuracy 0.86431
# STEP  154000 END @ 2016-12-24 08:38:02.945336, training accuracy 1.00000, ave validation accuracy 0.86431
# STEP  155000 END @ 2016-12-24 08:39:41.952998, training accuracy 1.00000, ave validation accuracy 0.86536
# << best model so far is saved in ckpt_model_06_run01/best/model-155500 >> ave validation accuracy 0.86606
# STEP  156000 END @ 2016-12-24 08:41:25.824025, training accuracy 1.00000, ave validation accuracy 0.86533
# << best model so far is saved in ckpt_model_06_run01/best/model-156800 >> ave validation accuracy 0.86621
# STEP  157000 END @ 2016-12-24 08:43:10.207822, training accuracy 1.00000, ave validation accuracy 0.86616
# STEP  158000 END @ 2016-12-24 08:44:49.494190, training accuracy 1.00000, ave validation accuracy 0.86470
# STEP  159000 END @ 2016-12-24 08:46:29.133848, training accuracy 1.00000, ave validation accuracy 0.86444
# STEP  160000 END @ 2016-12-24 08:48:08.531166, training accuracy 1.00000, ave validation accuracy 0.86528
# STEP  161000 END @ 2016-12-24 08:49:47.741926, training accuracy 1.00000, ave validation accuracy 0.86525
# STEP  162000 END @ 2016-12-24 08:51:26.626385, training accuracy 1.00000, ave validation accuracy 0.86416
# << best model so far is saved in ckpt_model_06_run01/best/model-162900 >> ave validation accuracy 0.86655
# STEP  163000 END @ 2016-12-24 08:53:11.194772, training accuracy 1.00000, ave validation accuracy 0.86650
# STEP  164000 END @ 2016-12-24 08:54:50.728696, training accuracy 1.00000, ave validation accuracy 0.86475
# STEP  165000 END @ 2016-12-24 08:56:30.069806, training accuracy 1.00000, ave validation accuracy 0.86294
# STEP  166000 END @ 2016-12-24 08:58:09.788268, training accuracy 1.00000, ave validation accuracy 0.86375
# STEP  167000 END @ 2016-12-24 08:59:49.578789, training accuracy 1.00000, ave validation accuracy 0.86398
# STEP  168000 END @ 2016-12-24 09:01:28.984046, training accuracy 1.00000, ave validation accuracy 0.86520
# STEP  169000 END @ 2016-12-24 09:03:08.447700, training accuracy 1.00000, ave validation accuracy 0.86385
# << best model so far is saved in ckpt_model_06_run01/best/model-170000 >> ave validation accuracy 0.86676
# STEP  170000 END @ 2016-12-24 09:04:54.372717, training accuracy 1.00000, ave validation accuracy 0.86676
# << best model so far is saved in ckpt_model_06_run01/best/model-170200 >> ave validation accuracy 0.86694
# STEP  171000 END @ 2016-12-24 09:06:38.593463, training accuracy 1.00000, ave validation accuracy 0.86501
# << hourly save at ckpt_model_06_run01/hourly/model-171500 and pickle_model_06_run01 >>
# STEP  172000 END @ 2016-12-24 09:08:22.937608, training accuracy 1.00000, ave validation accuracy 0.86478
# STEP  173000 END @ 2016-12-24 09:10:02.856678, training accuracy 1.00000, ave validation accuracy 0.86329
# STEP  174000 END @ 2016-12-24 09:11:41.808679, training accuracy 1.00000, ave validation accuracy 0.86415
# STEP  175000 END @ 2016-12-24 09:13:20.880461, training accuracy 1.00000, ave validation accuracy 0.86446
# STEP  176000 END @ 2016-12-24 09:15:00.684537, training accuracy 1.00000, ave validation accuracy 0.86359
# STEP  177000 END @ 2016-12-24 09:16:39.909987, training accuracy 0.99500, ave validation accuracy 0.86463
# STEP  178000 END @ 2016-12-24 09:18:18.969994, training accuracy 1.00000, ave validation accuracy 0.86534
# STEP  179000 END @ 2016-12-24 09:19:58.751656, training accuracy 1.00000, ave validation accuracy 0.86428
# STEP  180000 END @ 2016-12-24 09:21:38.335243, training accuracy 1.00000, ave validation accuracy 0.86489
# STEP  181000 END @ 2016-12-24 09:23:17.716835, training accuracy 1.00000, ave validation accuracy 0.86450
# STEP  182000 END @ 2016-12-24 09:24:57.032485, training accuracy 1.00000, ave validation accuracy 0.86466
# STEP  183000 END @ 2016-12-24 09:26:36.572144, training accuracy 1.00000, ave validation accuracy 0.86553
# STEP  184000 END @ 2016-12-24 09:28:15.779138, training accuracy 1.00000, ave validation accuracy 0.86558
# STEP  185000 END @ 2016-12-24 09:29:55.155238, training accuracy 0.99500, ave validation accuracy 0.86313
# STEP  186000 END @ 2016-12-24 09:31:34.251394, training accuracy 1.00000, ave validation accuracy 0.86319
# STEP  187000 END @ 2016-12-24 09:33:13.802844, training accuracy 1.00000, ave validation accuracy 0.86495
# STEP  188000 END @ 2016-12-24 09:34:53.013244, training accuracy 1.00000, ave validation accuracy 0.86549
# STEP  189000 END @ 2016-12-24 09:36:32.048514, training accuracy 1.00000, ave validation accuracy 0.86470
# STEP  190000 END @ 2016-12-24 09:38:11.401732, training accuracy 1.00000, ave validation accuracy 0.86531
# STEP  191000 END @ 2016-12-24 09:39:50.997959, training accuracy 1.00000, ave validation accuracy 0.86484
# STEP  192000 END @ 2016-12-24 09:41:29.928448, training accuracy 1.00000, ave validation accuracy 0.86391
# STEP  193000 END @ 2016-12-24 09:43:09.350137, training accuracy 1.00000, ave validation accuracy 0.86471
# STEP  194000 END @ 2016-12-24 09:44:48.583287, training accuracy 1.00000, ave validation accuracy 0.86445
# STEP  195000 END @ 2016-12-24 09:46:27.945871, training accuracy 1.00000, ave validation accuracy 0.86580
# STEP  196000 END @ 2016-12-24 09:48:07.358162, training accuracy 1.00000, ave validation accuracy 0.86611
# STEP  197000 END @ 2016-12-24 09:49:46.303624, training accuracy 1.00000, ave validation accuracy 0.86528
# STEP  198000 END @ 2016-12-24 09:51:25.617066, training accuracy 1.00000, ave validation accuracy 0.86435
# STEP  199000 END @ 2016-12-24 09:53:04.550583, training accuracy 1.00000, ave validation accuracy 0.86466
# STEP  200000 END @ 2016-12-24 09:54:43.720189, training accuracy 1.00000, ave validation accuracy 0.86520
# STEP  201000 END @ 2016-12-24 09:56:22.882221, training accuracy 1.00000, ave validation accuracy 0.86486
# STEP  202000 END @ 2016-12-24 09:58:02.607294, training accuracy 1.00000, ave validation accuracy 0.86551
# STEP  203000 END @ 2016-12-24 09:59:42.324676, training accuracy 1.00000, ave validation accuracy 0.86626
# STEP  204000 END @ 2016-12-24 10:01:21.529881, training accuracy 1.00000, ave validation accuracy 0.86455
# STEP  205000 END @ 2016-12-24 10:03:01.018076, training accuracy 1.00000, ave validation accuracy 0.86521
# STEP  206000 END @ 2016-12-24 10:04:40.464301, training accuracy 1.00000, ave validation accuracy 0.86583
# STEP  207000 END @ 2016-12-24 10:06:19.705416, training accuracy 1.00000, ave validation accuracy 0.86658
# << hourly save at ckpt_model_06_run01/hourly/model-207800 and pickle_model_06_run01 >>
# STEP  208000 END @ 2016-12-24 10:08:04.069363, training accuracy 1.00000, ave validation accuracy 0.86561
# STEP  209000 END @ 2016-12-24 10:09:43.442389, training accuracy 1.00000, ave validation accuracy 0.86549
# STEP  210000 END @ 2016-12-24 10:11:22.794898, training accuracy 1.00000, ave validation accuracy 0.86429
# STEP  211000 END @ 2016-12-24 10:13:02.113680, training accuracy 1.00000, ave validation accuracy 0.86448
# STEP  212000 END @ 2016-12-24 10:14:41.828626, training accuracy 1.00000, ave validation accuracy 0.86505
# STEP  213000 END @ 2016-12-24 10:16:21.161280, training accuracy 1.00000, ave validation accuracy 0.86665
# STEP  214000 END @ 2016-12-24 10:18:00.567113, training accuracy 1.00000, ave validation accuracy 0.86453
# STEP  215000 END @ 2016-12-24 10:19:39.971426, training accuracy 1.00000, ave validation accuracy 0.86503
# STEP  216000 END @ 2016-12-24 10:21:18.808672, training accuracy 1.00000, ave validation accuracy 0.86524
# STEP  217000 END @ 2016-12-24 10:22:58.547741, training accuracy 1.00000, ave validation accuracy 0.86490
# STEP  218000 END @ 2016-12-24 10:24:37.718603, training accuracy 1.00000, ave validation accuracy 0.86556
# STEP  219000 END @ 2016-12-24 10:26:17.063660, training accuracy 1.00000, ave validation accuracy 0.86440
# STEP  220000 END @ 2016-12-24 10:27:56.127654, training accuracy 1.00000, ave validation accuracy 0.86421
# STEP  221000 END @ 2016-12-24 10:29:35.428293, training accuracy 1.00000, ave validation accuracy 0.86466
# STEP  222000 END @ 2016-12-24 10:31:14.277517, training accuracy 1.00000, ave validation accuracy 0.86505
# STEP  223000 END @ 2016-12-24 10:32:53.513081, training accuracy 1.00000, ave validation accuracy 0.86539
# STEP  224000 END @ 2016-12-24 10:34:32.814682, training accuracy 1.00000, ave validation accuracy 0.86464
# STEP  225000 END @ 2016-12-24 10:36:12.258521, training accuracy 1.00000, ave validation accuracy 0.86686
# STEP  226000 END @ 2016-12-24 10:37:51.338200, training accuracy 1.00000, ave validation accuracy 0.86576
# STEP  227000 END @ 2016-12-24 10:39:30.383006, training accuracy 1.00000, ave validation accuracy 0.86540
# STEP  228000 END @ 2016-12-24 10:41:09.840866, training accuracy 1.00000, ave validation accuracy 0.86503
# STEP  229000 END @ 2016-12-24 10:42:48.951206, training accuracy 1.00000, ave validation accuracy 0.86615
# STEP  230000 END @ 2016-12-24 10:44:28.450520, training accuracy 1.00000, ave validation accuracy 0.86675
# << best model so far is saved in ckpt_model_06_run01/best/model-230100 >> ave validation accuracy 0.86701
# STEP  231000 END @ 2016-12-24 10:46:13.078758, training accuracy 1.00000, ave validation accuracy 0.86631
# STEP  232000 END @ 2016-12-24 10:47:52.485626, training accuracy 1.00000, ave validation accuracy 0.86538
# STEP  233000 END @ 2016-12-24 10:49:31.895800, training accuracy 1.00000, ave validation accuracy 0.86484
# STEP  234000 END @ 2016-12-24 10:51:11.670267, training accuracy 1.00000, ave validation accuracy 0.86509
# STEP  235000 END @ 2016-12-24 10:52:50.619674, training accuracy 1.00000, ave validation accuracy 0.86573
# STEP  236000 END @ 2016-12-24 10:54:29.765476, training accuracy 1.00000, ave validation accuracy 0.86480
# STEP  237000 END @ 2016-12-24 10:56:08.997493, training accuracy 1.00000, ave validation accuracy 0.86609
# STEP  238000 END @ 2016-12-24 10:57:48.346520, training accuracy 1.00000, ave validation accuracy 0.86621
# STEP  239000 END @ 2016-12-24 10:59:27.672596, training accuracy 1.00000, ave validation accuracy 0.86546
# STEP  240000 END @ 2016-12-24 11:01:06.761624, training accuracy 1.00000, ave validation accuracy 0.86508
# STEP  241000 END @ 2016-12-24 11:02:46.293111, training accuracy 1.00000, ave validation accuracy 0.86563
# STEP  242000 END @ 2016-12-24 11:04:25.767357, training accuracy 1.00000, ave validation accuracy 0.86613
# STEP  243000 END @ 2016-12-24 11:06:05.219301, training accuracy 1.00000, ave validation accuracy 0.86551
# STEP  244000 END @ 2016-12-24 11:07:44.262080, training accuracy 1.00000, ave validation accuracy 0.86516
# << hourly save at ckpt_model_06_run01/hourly/model-244100 and pickle_model_06_run01 >>
# STEP  245000 END @ 2016-12-24 11:09:28.576097, training accuracy 1.00000, ave validation accuracy 0.86614
# STEP  246000 END @ 2016-12-24 11:11:08.279989, training accuracy 1.00000, ave validation accuracy 0.86509
# STEP  247000 END @ 2016-12-24 11:12:47.808987, training accuracy 1.00000, ave validation accuracy 0.86511
# STEP  248000 END @ 2016-12-24 11:14:27.279625, training accuracy 1.00000, ave validation accuracy 0.86515
# STEP  249000 END @ 2016-12-24 11:16:06.959206, training accuracy 1.00000, ave validation accuracy 0.86543
# STEP  250000 END @ 2016-12-24 11:17:46.319764, training accuracy 1.00000, ave validation accuracy 0.86525
# STEP  251000 END @ 2016-12-24 11:19:25.872430, training accuracy 1.00000, ave validation accuracy 0.86518
# STEP  252000 END @ 2016-12-24 11:21:05.631553, training accuracy 1.00000, ave validation accuracy 0.86413
# STEP  253000 END @ 2016-12-24 11:22:45.074601, training accuracy 1.00000, ave validation accuracy 0.86428
# STEP  254000 END @ 2016-12-24 11:24:24.418098, training accuracy 1.00000, ave validation accuracy 0.86481
# STEP  255000 END @ 2016-12-24 11:26:03.743042, training accuracy 1.00000, ave validation accuracy 0.86513
# STEP  256000 END @ 2016-12-24 11:27:43.097619, training accuracy 1.00000, ave validation accuracy 0.86465
# STEP  257000 END @ 2016-12-24 11:29:22.367779, training accuracy 1.00000, ave validation accuracy 0.86444
# STEP  258000 END @ 2016-12-24 11:31:01.682978, training accuracy 1.00000, ave validation accuracy 0.86531
# STEP  259000 END @ 2016-12-24 11:32:41.185295, training accuracy 1.00000, ave validation accuracy 0.86671
# STEP  260000 END @ 2016-12-24 11:34:20.591255, training accuracy 1.00000, ave validation accuracy 0.86426
# STEP  261000 END @ 2016-12-24 11:35:59.906582, training accuracy 1.00000, ave validation accuracy 0.86384
# STEP  262000 END @ 2016-12-24 11:37:38.995552, training accuracy 1.00000, ave validation accuracy 0.86399
# STEP  263000 END @ 2016-12-24 11:39:18.218033, training accuracy 1.00000, ave validation accuracy 0.86585
# STEP  264000 END @ 2016-12-24 11:40:57.923553, training accuracy 1.00000, ave validation accuracy 0.86473
# STEP  265000 END @ 2016-12-24 11:42:37.302289, training accuracy 1.00000, ave validation accuracy 0.86440
# STEP  266000 END @ 2016-12-24 11:44:17.039100, training accuracy 1.00000, ave validation accuracy 0.86465
# STEP  267000 END @ 2016-12-24 11:45:56.548867, training accuracy 1.00000, ave validation accuracy 0.86363
# STEP  268000 END @ 2016-12-24 11:47:35.968316, training accuracy 1.00000, ave validation accuracy 0.86501
# STEP  269000 END @ 2016-12-24 11:49:14.951057, training accuracy 1.00000, ave validation accuracy 0.86494
# STEP  270000 END @ 2016-12-24 11:50:54.276522, training accuracy 1.00000, ave validation accuracy 0.86321
# STEP  271000 END @ 2016-12-24 11:52:33.731973, training accuracy 1.00000, ave validation accuracy 0.86460
# STEP  272000 END @ 2016-12-24 11:54:12.981775, training accuracy 1.00000, ave validation accuracy 0.86441
# STEP  273000 END @ 2016-12-24 11:55:52.390178, training accuracy 1.00000, ave validation accuracy 0.86545
# STEP  274000 END @ 2016-12-24 11:57:31.872112, training accuracy 1.00000, ave validation accuracy 0.86425
# STEP  275000 END @ 2016-12-24 11:59:11.615189, training accuracy 1.00000, ave validation accuracy 0.86543
# STEP  276000 END @ 2016-12-24 12:00:51.285955, training accuracy 1.00000, ave validation accuracy 0.86499
# STEP  277000 END @ 2016-12-24 12:02:30.404116, training accuracy 1.00000, ave validation accuracy 0.86463
# STEP  278000 END @ 2016-12-24 12:04:10.233166, training accuracy 1.00000, ave validation accuracy 0.86578
# STEP  279000 END @ 2016-12-24 12:05:49.837528, training accuracy 1.00000, ave validation accuracy 0.86475
# STEP  280000 END @ 2016-12-24 12:07:29.182953, training accuracy 1.00000, ave validation accuracy 0.86454
# << hourly save at ckpt_model_06_run01/hourly/model-280400 and pickle_model_06_run01 >>
# STEP  281000 END @ 2016-12-24 12:09:11.944742, training accuracy 1.00000, ave validation accuracy 0.86533
# STEP  282000 END @ 2016-12-24 12:10:51.366598, training accuracy 1.00000, ave validation accuracy 0.86380
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-feafc4fc8124> in <module>()
#       1 #Train the model
# ----> 2 train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#
# /home/kumiko/cifar10/helper_functions.pyc in train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#     251             _, summary = sess.run([graph_variables['optimizer'], graph_variables['summarizer']],
#     252                                   feed_dict={graph_variables['data']: batch_data, graph_variables['labels']: batch_labels,
# --> 253                                              graph_variables['keep_prob']: accuracy_log['variables']['dropout_train_keep_prob'], graph_variables['is_training']: True})
#     254
#     255             if i % accuracy_log['variables']['log_every'] == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Test accuracy
test_accuracy(graph_variables, accuracy_log, test_data, test_labels)
# Out:
# << test accuracy 0.86170 >>
