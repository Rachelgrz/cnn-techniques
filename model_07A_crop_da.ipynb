# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from helper_functions import *

# %%
#Continueing training?
continued = False
checkpoint_file_to_use = None #Example: 'ckpt_model_01_run01/hourly/model-9350'

#If training from step 0
#############################
naming = 'model_07A_run01'
#############################
variables = {
    'modify_images': True,
    'crop_images': True,
    'enlarge_images': False,
    'before_flatten_image_side_size': 3, #Need to calculate
    'first_hidden_layer_features': 384,
    'weights_stddev': 0.015,
    'biases_initial': 0.1,
    'dropout_train_keep_prob': 0.5,
    'learning_rate_initial': 0.1,
    'learning_rate_decay_steps': int(10000000),
    'learning_rate_decay': 1.0,
    'start_step_early_stopping': 150000,
    'early_stopping_patience': 0.1,
    'batch_size': 200,
    'max_steps': 100000000,
    'average_n_validation_accuracy': 8
}

# %%
#Create accuracy_log to pickle and directories for TensorBoard and checkpoint
accuracy_log = prep_accuracy_log(continued, checkpoint_file_to_use, naming, variables)

# %%
#Get data and labels
(train_data, validation_data, test_data, train_labels, validation_labels, test_labels) = get_data_and_labels(accuracy_log)

# %%
#Build a model
crop_images = accuracy_log['variables']['crop_images']
modify_images = accuracy_log['variables']['modify_images']
weights_stddev = accuracy_log['variables']['weights_stddev']
biases_initial = accuracy_log['variables']['biases_initial']
input_image_side_size = accuracy_log['variables']['input_image_side_size']
crop_to_side_size = accuracy_log['variables']['crop_to_side_size']
before_flatten_image_side_size = accuracy_log['variables']['before_flatten_image_side_size']
first_hidden_layer_features = accuracy_log['variables']['first_hidden_layer_features']
learning_rate_initial = accuracy_log['variables']['learning_rate_initial']
learning_rate_decay_steps = accuracy_log['variables']['learning_rate_decay_steps']
learning_rate_decay = accuracy_log['variables']['learning_rate_decay']

graph = tf.Graph()
with graph.as_default():
    global_step = tf.Variable(0, trainable=False)
    is_training = tf.placeholder(tf.bool)
    keep_prob = tf.placeholder(tf.float32)

    data = tf.placeholder(tf.float32, [None, input_image_side_size, input_image_side_size, 3])
    labels = tf.placeholder(tf.float32, [None, 10])
    
    if crop_images & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    elif (not crop_images) & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify_no_crop(data), lambda: tf.identity(data))
    elif crop_images & (not modify_images):
        data_v2 = tf.cond(is_training, lambda: random_crop(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    else:
        data_v2 = tf.identity(data)

    data_v2 = batch_normalize(data_v2, is_training=is_training, global_step=global_step, scope='bn_data_v2')
    W_conv1 = weight_variable([3, 3, 3, 64], weights_stddev, 'W_conv1')
    b_conv1 = bias_variable(biases_initial, [64], 'b_conv1')
    conv1 = conv2d(data_v2, W_conv1) + b_conv1
    conv1_relu = tf.nn.relu(conv1)
    pool1 = max_pool_3x3_stride2(conv1_relu)
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm1 = batch_normalize(norm1, is_training=is_training, global_step=global_step, scope='bn_norm1')
    W_conv2 = weight_variable([3, 3, 64, 64], weights_stddev, 'W_conv2')
    b_conv2 = bias_variable(biases_initial, [64], 'b_conv2')
    conv2 = conv2d(norm1, W_conv2) + b_conv2
    conv2_relu = tf.nn.relu(conv2)
    pool2 = max_pool_3x3_stride2(conv2_relu)
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm2 = batch_normalize(norm2, is_training=is_training, global_step=global_step, scope='bn_norm2')
    W_conv3 = weight_variable([3, 3, 64, 128], weights_stddev, 'W_conv3')
    b_conv3 = bias_variable(biases_initial, [128], 'b_conv3')
    conv3 = conv2d(norm2, W_conv3) + b_conv3
    conv3_relu = tf.nn.relu(conv3)
    pool3 = max_pool_3x3_stride2(conv3_relu)
    norm3 = tf.nn.lrn(pool3, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)
    
    norm3_flat = tf.reshape(norm3, [-1, before_flatten_image_side_size*before_flatten_image_side_size*128])

    norm3_flat = batch_normalize(norm3_flat, is_training=is_training, global_step=global_step, scope='bn_norm3_flat')
    norm3_flat_drop = tf.nn.dropout(norm3_flat, keep_prob)
    W_fc1 = weight_variable([before_flatten_image_side_size*before_flatten_image_side_size*128, first_hidden_layer_features], weights_stddev, 'W_fc1')
    b_fc1 = bias_variable(biases_initial, [first_hidden_layer_features], 'b_fc1')
    fc1 = tf.matmul(norm3_flat_drop, W_fc1) + b_fc1
    fc1_relu = tf.nn.relu(fc1)

    fc1_relu = batch_normalize(fc1_relu, is_training=is_training, global_step=global_step, scope='bn_fc1_relu')    
    fc1_relu_drop = tf.nn.dropout(fc1_relu, keep_prob)
    W_fc2 = weight_variable([first_hidden_layer_features, int(first_hidden_layer_features/2)], weights_stddev, 'W_fc2')
    b_fc2 = bias_variable(biases_initial, [first_hidden_layer_features/2], 'b_fc2')
    fc2 = tf.matmul(fc1_relu_drop, W_fc2) + b_fc2
    fc2_relu = tf.nn.relu(fc2)

    fc2_relu = batch_normalize(fc2_relu, is_training=is_training, global_step=global_step, scope='bn_fc2_relu')
    fc2_relu_drop = tf.nn.dropout(fc2_relu, keep_prob)
    W_fc3 = weight_variable([int(first_hidden_layer_features/2), 10], weights_stddev, 'W_fc3')
    b_fc3 = bias_variable(biases_initial, [10], 'b_fc3')
    logits = tf.matmul(fc2_relu_drop, W_fc3) + b_fc3

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))
    
    learning_rate = tf.train.exponential_decay(learning_rate_initial, global_step, learning_rate_decay_steps, 
                                               learning_rate_decay, staircase=True)
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    tf.summary.scalar('loss', loss)
    tf.summary.scalar('learning_rate', learning_rate)
    tf.summary.scalar('training_accuracy', accuracy)
    
    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name, var)
    
    summarizer = tf.summary.merge_all()
    
graph_variables = {'graph': graph, 
                   'optimizer': optimizer, 
                   'summarizer': summarizer, 
                   'data': data, 
                   'labels': labels, 
                   'keep_prob': keep_prob, 
                   'is_training': is_training, 
                   'correct_prediction': correct_prediction,
                   'accuracy': accuracy}

# %%
#Train the model
train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
# Out:
# TRAINING   START @ 2016-12-24 12:19:11.435695
# << best model so far is saved in ckpt_model_07A_run01/best/model-0 >> ave validation accuracy 0.10220
# STEP       0 END @ 2016-12-24 12:19:22.540729, training accuracy 0.09500, ave validation accuracy 0.10220
# << best model so far is saved in ckpt_model_07A_run01/best/model-100 >> ave validation accuracy 0.12445
# << best model so far is saved in ckpt_model_07A_run01/best/model-200 >> ave validation accuracy 0.14937
# STEP    1000 END @ 2016-12-24 12:21:51.895702, training accuracy 0.15000, ave validation accuracy 0.11147
# << best model so far is saved in ckpt_model_07A_run01/best/model-1600 >> ave validation accuracy 0.17522
# << best model so far is saved in ckpt_model_07A_run01/best/model-1700 >> ave validation accuracy 0.19717
# << best model so far is saved in ckpt_model_07A_run01/best/model-1800 >> ave validation accuracy 0.23719
# << best model so far is saved in ckpt_model_07A_run01/best/model-1900 >> ave validation accuracy 0.27632
# << best model so far is saved in ckpt_model_07A_run01/best/model-2000 >> ave validation accuracy 0.31585
# STEP    2000 END @ 2016-12-24 12:24:36.791253, training accuracy 0.40500, ave validation accuracy 0.31585
# << best model so far is saved in ckpt_model_07A_run01/best/model-2100 >> ave validation accuracy 0.36006
# << best model so far is saved in ckpt_model_07A_run01/best/model-2200 >> ave validation accuracy 0.40195
# << best model so far is saved in ckpt_model_07A_run01/best/model-2300 >> ave validation accuracy 0.44261
# << best model so far is saved in ckpt_model_07A_run01/best/model-2400 >> ave validation accuracy 0.48092
# << best model so far is saved in ckpt_model_07A_run01/best/model-2500 >> ave validation accuracy 0.52657
# << best model so far is saved in ckpt_model_07A_run01/best/model-2600 >> ave validation accuracy 0.55321
# << best model so far is saved in ckpt_model_07A_run01/best/model-2700 >> ave validation accuracy 0.58426
# << best model so far is saved in ckpt_model_07A_run01/best/model-2800 >> ave validation accuracy 0.61290
# << best model so far is saved in ckpt_model_07A_run01/best/model-2900 >> ave validation accuracy 0.63289
# << best model so far is saved in ckpt_model_07A_run01/best/model-3000 >> ave validation accuracy 0.65506
# STEP    3000 END @ 2016-12-24 12:27:47.981225, training accuracy 0.75500, ave validation accuracy 0.65506
# << best model so far is saved in ckpt_model_07A_run01/best/model-3100 >> ave validation accuracy 0.67036
# << best model so far is saved in ckpt_model_07A_run01/best/model-3200 >> ave validation accuracy 0.67884
# << best model so far is saved in ckpt_model_07A_run01/best/model-3300 >> ave validation accuracy 0.68855
# << best model so far is saved in ckpt_model_07A_run01/best/model-3400 >> ave validation accuracy 0.69821
# << best model so far is saved in ckpt_model_07A_run01/best/model-3500 >> ave validation accuracy 0.70527
# << best model so far is saved in ckpt_model_07A_run01/best/model-3600 >> ave validation accuracy 0.71027
# << best model so far is saved in ckpt_model_07A_run01/best/model-3700 >> ave validation accuracy 0.71704
# << best model so far is saved in ckpt_model_07A_run01/best/model-3800 >> ave validation accuracy 0.72100
# << best model so far is saved in ckpt_model_07A_run01/best/model-3900 >> ave validation accuracy 0.72452
# << best model so far is saved in ckpt_model_07A_run01/best/model-4000 >> ave validation accuracy 0.72822
# STEP    4000 END @ 2016-12-24 12:30:59.065667, training accuracy 0.79000, ave validation accuracy 0.72822
# << best model so far is saved in ckpt_model_07A_run01/best/model-4100 >> ave validation accuracy 0.73112
# << best model so far is saved in ckpt_model_07A_run01/best/model-4200 >> ave validation accuracy 0.73396
# << best model so far is saved in ckpt_model_07A_run01/best/model-4300 >> ave validation accuracy 0.73657
# << best model so far is saved in ckpt_model_07A_run01/best/model-4400 >> ave validation accuracy 0.73832
# << best model so far is saved in ckpt_model_07A_run01/best/model-4500 >> ave validation accuracy 0.74114
# << best model so far is saved in ckpt_model_07A_run01/best/model-4600 >> ave validation accuracy 0.74301
# << best model so far is saved in ckpt_model_07A_run01/best/model-4700 >> ave validation accuracy 0.74504
# << best model so far is saved in ckpt_model_07A_run01/best/model-4800 >> ave validation accuracy 0.74819
# << best model so far is saved in ckpt_model_07A_run01/best/model-4900 >> ave validation accuracy 0.74842
# << best model so far is saved in ckpt_model_07A_run01/best/model-5000 >> ave validation accuracy 0.74950
# STEP    5000 END @ 2016-12-24 12:34:07.423838, training accuracy 0.77500, ave validation accuracy 0.74950
# << best model so far is saved in ckpt_model_07A_run01/best/model-5100 >> ave validation accuracy 0.75066
# << best model so far is saved in ckpt_model_07A_run01/best/model-5200 >> ave validation accuracy 0.75255
# << best model so far is saved in ckpt_model_07A_run01/best/model-5400 >> ave validation accuracy 0.75340
# << best model so far is saved in ckpt_model_07A_run01/best/model-5500 >> ave validation accuracy 0.75415
# << best model so far is saved in ckpt_model_07A_run01/best/model-5700 >> ave validation accuracy 0.75623
# << best model so far is saved in ckpt_model_07A_run01/best/model-5800 >> ave validation accuracy 0.75669
# << best model so far is saved in ckpt_model_07A_run01/best/model-5900 >> ave validation accuracy 0.75780
# STEP    6000 END @ 2016-12-24 12:37:03.227491, training accuracy 0.85000, ave validation accuracy 0.75778
# << best model so far is saved in ckpt_model_07A_run01/best/model-6100 >> ave validation accuracy 0.75953
# << best model so far is saved in ckpt_model_07A_run01/best/model-6200 >> ave validation accuracy 0.76024
# << best model so far is saved in ckpt_model_07A_run01/best/model-6300 >> ave validation accuracy 0.76194
# << best model so far is saved in ckpt_model_07A_run01/best/model-6400 >> ave validation accuracy 0.76465
# << best model so far is saved in ckpt_model_07A_run01/best/model-6500 >> ave validation accuracy 0.76633
# << best model so far is saved in ckpt_model_07A_run01/best/model-6600 >> ave validation accuracy 0.76894
# << best model so far is saved in ckpt_model_07A_run01/best/model-6700 >> ave validation accuracy 0.77069
# << best model so far is saved in ckpt_model_07A_run01/best/model-6800 >> ave validation accuracy 0.77264
# << best model so far is saved in ckpt_model_07A_run01/best/model-6900 >> ave validation accuracy 0.77416
# << best model so far is saved in ckpt_model_07A_run01/best/model-7000 >> ave validation accuracy 0.77505
# STEP    7000 END @ 2016-12-24 12:40:12.850802, training accuracy 0.81500, ave validation accuracy 0.77505
# << best model so far is saved in ckpt_model_07A_run01/best/model-7100 >> ave validation accuracy 0.77550
# << best model so far is saved in ckpt_model_07A_run01/best/model-7700 >> ave validation accuracy 0.77584
# << best model so far is saved in ckpt_model_07A_run01/best/model-7800 >> ave validation accuracy 0.77739
# STEP    8000 END @ 2016-12-24 12:42:45.027229, training accuracy 0.82500, ave validation accuracy 0.77633
# << best model so far is saved in ckpt_model_07A_run01/best/model-8100 >> ave validation accuracy 0.77749
# << best model so far is saved in ckpt_model_07A_run01/best/model-8200 >> ave validation accuracy 0.77826
# << best model so far is saved in ckpt_model_07A_run01/best/model-8300 >> ave validation accuracy 0.77918
# << best model so far is saved in ckpt_model_07A_run01/best/model-8400 >> ave validation accuracy 0.78028
# << best model so far is saved in ckpt_model_07A_run01/best/model-8500 >> ave validation accuracy 0.78081
# << best model so far is saved in ckpt_model_07A_run01/best/model-8600 >> ave validation accuracy 0.78143
# << best model so far is saved in ckpt_model_07A_run01/best/model-8700 >> ave validation accuracy 0.78245
# << best model so far is saved in ckpt_model_07A_run01/best/model-8800 >> ave validation accuracy 0.78493
# << best model so far is saved in ckpt_model_07A_run01/best/model-9000 >> ave validation accuracy 0.78530
# STEP    9000 END @ 2016-12-24 12:45:49.441109, training accuracy 0.83500, ave validation accuracy 0.78530
# << best model so far is saved in ckpt_model_07A_run01/best/model-9100 >> ave validation accuracy 0.78636
# << best model so far is saved in ckpt_model_07A_run01/best/model-9200 >> ave validation accuracy 0.78660
# << best model so far is saved in ckpt_model_07A_run01/best/model-9300 >> ave validation accuracy 0.78710
# << best model so far is saved in ckpt_model_07A_run01/best/model-9400 >> ave validation accuracy 0.78775
# << best model so far is saved in ckpt_model_07A_run01/best/model-9500 >> ave validation accuracy 0.78834
# << best model so far is saved in ckpt_model_07A_run01/best/model-9700 >> ave validation accuracy 0.78891
# << best model so far is saved in ckpt_model_07A_run01/best/model-9800 >> ave validation accuracy 0.79007
# << best model so far is saved in ckpt_model_07A_run01/best/model-9900 >> ave validation accuracy 0.79020
# << best model so far is saved in ckpt_model_07A_run01/best/model-10000 >> ave validation accuracy 0.79114
# STEP   10000 END @ 2016-12-24 12:48:53.849162, training accuracy 0.84000, ave validation accuracy 0.79114
# << best model so far is saved in ckpt_model_07A_run01/best/model-10100 >> ave validation accuracy 0.79127
# << best model so far is saved in ckpt_model_07A_run01/best/model-10200 >> ave validation accuracy 0.79202
# << best model so far is saved in ckpt_model_07A_run01/best/model-10300 >> ave validation accuracy 0.79358
# << best model so far is saved in ckpt_model_07A_run01/best/model-10400 >> ave validation accuracy 0.79383
# << best model so far is saved in ckpt_model_07A_run01/best/model-10500 >> ave validation accuracy 0.79464
# << best model so far is saved in ckpt_model_07A_run01/best/model-10600 >> ave validation accuracy 0.79496
# << best model so far is saved in ckpt_model_07A_run01/best/model-10900 >> ave validation accuracy 0.79583
# << best model so far is saved in ckpt_model_07A_run01/best/model-11000 >> ave validation accuracy 0.79609
# STEP   11000 END @ 2016-12-24 12:51:52.119706, training accuracy 0.81500, ave validation accuracy 0.79609
# << best model so far is saved in ckpt_model_07A_run01/best/model-11400 >> ave validation accuracy 0.79625
# << best model so far is saved in ckpt_model_07A_run01/best/model-11500 >> ave validation accuracy 0.79816
# << best model so far is saved in ckpt_model_07A_run01/best/model-12000 >> ave validation accuracy 0.79926
# STEP   12000 END @ 2016-12-24 12:54:24.359418, training accuracy 0.84000, ave validation accuracy 0.79926
# << best model so far is saved in ckpt_model_07A_run01/best/model-12600 >> ave validation accuracy 0.79956
# << best model so far is saved in ckpt_model_07A_run01/best/model-12700 >> ave validation accuracy 0.80006
# << best model so far is saved in ckpt_model_07A_run01/best/model-12900 >> ave validation accuracy 0.80150
# << best model so far is saved in ckpt_model_07A_run01/best/model-13000 >> ave validation accuracy 0.80187
# STEP   13000 END @ 2016-12-24 12:57:01.339865, training accuracy 0.83500, ave validation accuracy 0.80187
# << best model so far is saved in ckpt_model_07A_run01/best/model-13100 >> ave validation accuracy 0.80297
# << best model so far is saved in ckpt_model_07A_run01/best/model-13200 >> ave validation accuracy 0.80359
# << best model so far is saved in ckpt_model_07A_run01/best/model-13300 >> ave validation accuracy 0.80455
# << best model so far is saved in ckpt_model_07A_run01/best/model-13400 >> ave validation accuracy 0.80466
# STEP   14000 END @ 2016-12-24 12:59:38.064412, training accuracy 0.78500, ave validation accuracy 0.80348
# << best model so far is saved in ckpt_model_07A_run01/best/model-14300 >> ave validation accuracy 0.80564
# << best model so far is saved in ckpt_model_07A_run01/best/model-14900 >> ave validation accuracy 0.80624
# STEP   15000 END @ 2016-12-24 13:02:02.163290, training accuracy 0.82500, ave validation accuracy 0.80575
# << best model so far is saved in ckpt_model_07A_run01/best/model-15400 >> ave validation accuracy 0.80734
# STEP   16000 END @ 2016-12-24 13:04:23.681935, training accuracy 0.85500, ave validation accuracy 0.80673
# << best model so far is saved in ckpt_model_07A_run01/best/model-16500 >> ave validation accuracy 0.80776
# << best model so far is saved in ckpt_model_07A_run01/best/model-16600 >> ave validation accuracy 0.80839
# << best model so far is saved in ckpt_model_07A_run01/best/model-16700 >> ave validation accuracy 0.80886
# << best model so far is saved in ckpt_model_07A_run01/best/model-16900 >> ave validation accuracy 0.80983
# << best model so far is saved in ckpt_model_07A_run01/best/model-17000 >> ave validation accuracy 0.81091
# STEP   17000 END @ 2016-12-24 13:07:07.541089, training accuracy 0.84500, ave validation accuracy 0.81091
# << best model so far is saved in ckpt_model_07A_run01/best/model-17100 >> ave validation accuracy 0.81134
# << best model so far is saved in ckpt_model_07A_run01/best/model-17200 >> ave validation accuracy 0.81280
# << best model so far is saved in ckpt_model_07A_run01/best/model-17300 >> ave validation accuracy 0.81294
# << best model so far is saved in ckpt_model_07A_run01/best/model-17500 >> ave validation accuracy 0.81333
# << best model so far is saved in ckpt_model_07A_run01/best/model-17600 >> ave validation accuracy 0.81381
# << best model so far is saved in ckpt_model_07A_run01/best/model-17800 >> ave validation accuracy 0.81423
# << best model so far is saved in ckpt_model_07A_run01/best/model-17900 >> ave validation accuracy 0.81479
# STEP   18000 END @ 2016-12-24 13:09:58.298988, training accuracy 0.86500, ave validation accuracy 0.81449
# << best model so far is saved in ckpt_model_07A_run01/best/model-19000 >> ave validation accuracy 0.81551
# STEP   19000 END @ 2016-12-24 13:12:17.279066, training accuracy 0.88000, ave validation accuracy 0.81551
# << best model so far is saved in ckpt_model_07A_run01/best/model-19100 >> ave validation accuracy 0.81644
# << best model so far is saved in ckpt_model_07A_run01/best/model-19200 >> ave validation accuracy 0.81650
# << best model so far is saved in ckpt_model_07A_run01/best/model-19300 >> ave validation accuracy 0.81665
# << best model so far is saved in ckpt_model_07A_run01/best/model-19400 >> ave validation accuracy 0.81711
# << best model so far is saved in ckpt_model_07A_run01/best/model-19600 >> ave validation accuracy 0.81741
# << best model so far is saved in ckpt_model_07A_run01/best/model-19700 >> ave validation accuracy 0.81760
# STEP   20000 END @ 2016-12-24 13:15:05.864900, training accuracy 0.89000, ave validation accuracy 0.81658
# << best model so far is saved in ckpt_model_07A_run01/best/model-20300 >> ave validation accuracy 0.81766
# << best model so far is saved in ckpt_model_07A_run01/best/model-20800 >> ave validation accuracy 0.81848
# STEP   21000 END @ 2016-12-24 13:17:29.909539, training accuracy 0.87500, ave validation accuracy 0.81819
# << hourly save at ckpt_model_07A_run01/hourly/model-21800 and pickle_model_07A_run01 >>
# << best model so far is saved in ckpt_model_07A_run01/best/model-21800 >> ave validation accuracy 0.81868
# << best model so far is saved in ckpt_model_07A_run01/best/model-21900 >> ave validation accuracy 0.81946
# << best model so far is saved in ckpt_model_07A_run01/best/model-22000 >> ave validation accuracy 0.81971
# STEP   22000 END @ 2016-12-24 13:20:06.827973, training accuracy 0.89500, ave validation accuracy 0.81971
# << best model so far is saved in ckpt_model_07A_run01/best/model-22100 >> ave validation accuracy 0.82033
# << best model so far is saved in ckpt_model_07A_run01/best/model-22200 >> ave validation accuracy 0.82041
# << best model so far is saved in ckpt_model_07A_run01/best/model-22300 >> ave validation accuracy 0.82116
# STEP   23000 END @ 2016-12-24 13:22:36.012003, training accuracy 0.82000, ave validation accuracy 0.82074
# << best model so far is saved in ckpt_model_07A_run01/best/model-24000 >> ave validation accuracy 0.82116
# STEP   24000 END @ 2016-12-24 13:24:54.794432, training accuracy 0.91000, ave validation accuracy 0.82116
# << best model so far is saved in ckpt_model_07A_run01/best/model-24100 >> ave validation accuracy 0.82150
# << best model so far is saved in ckpt_model_07A_run01/best/model-24200 >> ave validation accuracy 0.82241
# << best model so far is saved in ckpt_model_07A_run01/best/model-24300 >> ave validation accuracy 0.82286
# << best model so far is saved in ckpt_model_07A_run01/best/model-24400 >> ave validation accuracy 0.82320
# << best model so far is saved in ckpt_model_07A_run01/best/model-24500 >> ave validation accuracy 0.82395
# << best model so far is saved in ckpt_model_07A_run01/best/model-24600 >> ave validation accuracy 0.82405
# << best model so far is saved in ckpt_model_07A_run01/best/model-24700 >> ave validation accuracy 0.82453
# << best model so far is saved in ckpt_model_07A_run01/best/model-24800 >> ave validation accuracy 0.82515
# << best model so far is saved in ckpt_model_07A_run01/best/model-24900 >> ave validation accuracy 0.82539
# STEP   25000 END @ 2016-12-24 13:27:55.866422, training accuracy 0.87500, ave validation accuracy 0.82478
# STEP   26000 END @ 2016-12-24 13:30:09.498727, training accuracy 0.84500, ave validation accuracy 0.82381
# << best model so far is saved in ckpt_model_07A_run01/best/model-26600 >> ave validation accuracy 0.82600
# << best model so far is saved in ckpt_model_07A_run01/best/model-26800 >> ave validation accuracy 0.82650
# << best model so far is saved in ckpt_model_07A_run01/best/model-26900 >> ave validation accuracy 0.82680
# << best model so far is saved in ckpt_model_07A_run01/best/model-27000 >> ave validation accuracy 0.82689
# STEP   27000 END @ 2016-12-24 13:32:45.122100, training accuracy 0.89500, ave validation accuracy 0.82689
# << best model so far is saved in ckpt_model_07A_run01/best/model-27100 >> ave validation accuracy 0.82695
# << best model so far is saved in ckpt_model_07A_run01/best/model-27300 >> ave validation accuracy 0.82721
# << best model so far is saved in ckpt_model_07A_run01/best/model-27500 >> ave validation accuracy 0.82753
# STEP   28000 END @ 2016-12-24 13:35:14.178706, training accuracy 0.89500, ave validation accuracy 0.82679
# STEP   29000 END @ 2016-12-24 13:37:28.044801, training accuracy 0.85000, ave validation accuracy 0.82586
# << best model so far is saved in ckpt_model_07A_run01/best/model-29600 >> ave validation accuracy 0.82788
# << best model so far is saved in ckpt_model_07A_run01/best/model-29800 >> ave validation accuracy 0.82843
# << best model so far is saved in ckpt_model_07A_run01/best/model-29900 >> ave validation accuracy 0.82905
# << best model so far is saved in ckpt_model_07A_run01/best/model-30000 >> ave validation accuracy 0.82911
# STEP   30000 END @ 2016-12-24 13:40:03.559663, training accuracy 0.87000, ave validation accuracy 0.82911
# STEP   31000 END @ 2016-12-24 13:42:17.531802, training accuracy 0.86500, ave validation accuracy 0.82901
# STEP   32000 END @ 2016-12-24 13:44:31.163749, training accuracy 0.90500, ave validation accuracy 0.82866
# << best model so far is saved in ckpt_model_07A_run01/best/model-32400 >> ave validation accuracy 0.83019
# << best model so far is saved in ckpt_model_07A_run01/best/model-32500 >> ave validation accuracy 0.83095
# << best model so far is saved in ckpt_model_07A_run01/best/model-32600 >> ave validation accuracy 0.83114
# << best model so far is saved in ckpt_model_07A_run01/best/model-32700 >> ave validation accuracy 0.83171
# << best model so far is saved in ckpt_model_07A_run01/best/model-32800 >> ave validation accuracy 0.83173
# << best model so far is saved in ckpt_model_07A_run01/best/model-33000 >> ave validation accuracy 0.83193
# STEP   33000 END @ 2016-12-24 13:47:18.375814, training accuracy 0.88000, ave validation accuracy 0.83193
# << best model so far is saved in ckpt_model_07A_run01/best/model-33100 >> ave validation accuracy 0.83206
# STEP   34000 END @ 2016-12-24 13:49:37.137503, training accuracy 0.90500, ave validation accuracy 0.82978
# STEP   35000 END @ 2016-12-24 13:51:50.939902, training accuracy 0.85000, ave validation accuracy 0.83091
# STEP   36000 END @ 2016-12-24 13:54:04.742090, training accuracy 0.86500, ave validation accuracy 0.83179
# << best model so far is saved in ckpt_model_07A_run01/best/model-36100 >> ave validation accuracy 0.83276
# << best model so far is saved in ckpt_model_07A_run01/best/model-36400 >> ave validation accuracy 0.83294
# << best model so far is saved in ckpt_model_07A_run01/best/model-36500 >> ave validation accuracy 0.83320
# << best model so far is saved in ckpt_model_07A_run01/best/model-36700 >> ave validation accuracy 0.83346
# << best model so far is saved in ckpt_model_07A_run01/best/model-37000 >> ave validation accuracy 0.83365
# STEP   37000 END @ 2016-12-24 13:56:45.361072, training accuracy 0.91500, ave validation accuracy 0.83365
# << best model so far is saved in ckpt_model_07A_run01/best/model-37100 >> ave validation accuracy 0.83395
# << best model so far is saved in ckpt_model_07A_run01/best/model-37200 >> ave validation accuracy 0.83429
# << best model so far is saved in ckpt_model_07A_run01/best/model-37500 >> ave validation accuracy 0.83448
# << best model so far is saved in ckpt_model_07A_run01/best/model-37600 >> ave validation accuracy 0.83473
# << best model so far is saved in ckpt_model_07A_run01/best/model-37700 >> ave validation accuracy 0.83484
# << best model so far is saved in ckpt_model_07A_run01/best/model-38000 >> ave validation accuracy 0.83506
# STEP   38000 END @ 2016-12-24 13:59:32.667160, training accuracy 0.91500, ave validation accuracy 0.83506
# << best model so far is saved in ckpt_model_07A_run01/best/model-38100 >> ave validation accuracy 0.83526
# << best model so far is saved in ckpt_model_07A_run01/best/model-38200 >> ave validation accuracy 0.83544
# << best model so far is saved in ckpt_model_07A_run01/best/model-38600 >> ave validation accuracy 0.83558
# STEP   39000 END @ 2016-12-24 14:02:01.475533, training accuracy 0.86500, ave validation accuracy 0.83338
# STEP   40000 END @ 2016-12-24 14:04:15.254259, training accuracy 0.90500, ave validation accuracy 0.83551
# << best model so far is saved in ckpt_model_07A_run01/best/model-40200 >> ave validation accuracy 0.83610
# << best model so far is saved in ckpt_model_07A_run01/best/model-40300 >> ave validation accuracy 0.83645
# << best model so far is saved in ckpt_model_07A_run01/best/model-40400 >> ave validation accuracy 0.83683
# << best model so far is saved in ckpt_model_07A_run01/best/model-40700 >> ave validation accuracy 0.83724
# STEP   41000 END @ 2016-12-24 14:06:51.843950, training accuracy 0.91000, ave validation accuracy 0.83676
# << best model so far is saved in ckpt_model_07A_run01/best/model-41700 >> ave validation accuracy 0.83726
# << best model so far is saved in ckpt_model_07A_run01/best/model-41800 >> ave validation accuracy 0.83754
# << best model so far is saved in ckpt_model_07A_run01/best/model-41900 >> ave validation accuracy 0.83760
# STEP   42000 END @ 2016-12-24 14:09:22.284552, training accuracy 0.90000, ave validation accuracy 0.83729
# << best model so far is saved in ckpt_model_07A_run01/best/model-42100 >> ave validation accuracy 0.83775
# << best model so far is saved in ckpt_model_07A_run01/best/model-42300 >> ave validation accuracy 0.83788
# << best model so far is saved in ckpt_model_07A_run01/best/model-42800 >> ave validation accuracy 0.83789
# STEP   43000 END @ 2016-12-24 14:11:51.298569, training accuracy 0.89000, ave validation accuracy 0.83754
# << best model so far is saved in ckpt_model_07A_run01/best/model-43200 >> ave validation accuracy 0.83830
# << best model so far is saved in ckpt_model_07A_run01/best/model-43600 >> ave validation accuracy 0.83853
# << best model so far is saved in ckpt_model_07A_run01/best/model-43700 >> ave validation accuracy 0.83866
# << best model so far is saved in ckpt_model_07A_run01/best/model-43800 >> ave validation accuracy 0.83874
# << best model so far is saved in ckpt_model_07A_run01/best/model-44000 >> ave validation accuracy 0.83899
# STEP   44000 END @ 2016-12-24 14:14:33.592973, training accuracy 0.86500, ave validation accuracy 0.83899
# << best model so far is saved in ckpt_model_07A_run01/best/model-44100 >> ave validation accuracy 0.83904
# STEP   45000 END @ 2016-12-24 14:16:52.352824, training accuracy 0.90500, ave validation accuracy 0.83718
# << best model so far is saved in ckpt_model_07A_run01/best/model-46000 >> ave validation accuracy 0.83906
# STEP   46000 END @ 2016-12-24 14:19:09.877663, training accuracy 0.88500, ave validation accuracy 0.83906
# << best model so far is saved in ckpt_model_07A_run01/best/model-46100 >> ave validation accuracy 0.83998
# << hourly save at ckpt_model_07A_run01/hourly/model-46200 and pickle_model_07A_run01 >>
# STEP   47000 END @ 2016-12-24 14:21:35.203850, training accuracy 0.91000, ave validation accuracy 0.83893
# << best model so far is saved in ckpt_model_07A_run01/best/model-47700 >> ave validation accuracy 0.84034
# << best model so far is saved in ckpt_model_07A_run01/best/model-47800 >> ave validation accuracy 0.84078
# STEP   48000 END @ 2016-12-24 14:24:00.504659, training accuracy 0.89500, ave validation accuracy 0.84025
# << best model so far is saved in ckpt_model_07A_run01/best/model-48200 >> ave validation accuracy 0.84079
# << best model so far is saved in ckpt_model_07A_run01/best/model-48300 >> ave validation accuracy 0.84081
# << best model so far is saved in ckpt_model_07A_run01/best/model-48400 >> ave validation accuracy 0.84123
# STEP   49000 END @ 2016-12-24 14:26:30.868152, training accuracy 0.88500, ave validation accuracy 0.84055
# STEP   50000 END @ 2016-12-24 14:28:44.518049, training accuracy 0.90000, ave validation accuracy 0.84079
# << best model so far is saved in ckpt_model_07A_run01/best/model-50100 >> ave validation accuracy 0.84128
# << best model so far is saved in ckpt_model_07A_run01/best/model-50200 >> ave validation accuracy 0.84141
# << best model so far is saved in ckpt_model_07A_run01/best/model-50400 >> ave validation accuracy 0.84210
# << best model so far is saved in ckpt_model_07A_run01/best/model-50500 >> ave validation accuracy 0.84245
# << best model so far is saved in ckpt_model_07A_run01/best/model-50600 >> ave validation accuracy 0.84256
# << best model so far is saved in ckpt_model_07A_run01/best/model-50700 >> ave validation accuracy 0.84271
# STEP   51000 END @ 2016-12-24 14:31:31.525346, training accuracy 0.91000, ave validation accuracy 0.84244
# STEP   52000 END @ 2016-12-24 14:33:45.299654, training accuracy 0.92000, ave validation accuracy 0.84174
# STEP   53000 END @ 2016-12-24 14:35:59.091313, training accuracy 0.85000, ave validation accuracy 0.84074
# STEP   54000 END @ 2016-12-24 14:38:12.819579, training accuracy 0.86000, ave validation accuracy 0.84140
# STEP   55000 END @ 2016-12-24 14:40:26.613272, training accuracy 0.90500, ave validation accuracy 0.84041
# STEP   56000 END @ 2016-12-24 14:42:40.489239, training accuracy 0.91000, ave validation accuracy 0.84114
# << best model so far is saved in ckpt_model_07A_run01/best/model-56500 >> ave validation accuracy 0.84305
# << best model so far is saved in ckpt_model_07A_run01/best/model-56600 >> ave validation accuracy 0.84309
# STEP   57000 END @ 2016-12-24 14:45:04.411868, training accuracy 0.90500, ave validation accuracy 0.84243
# << best model so far is saved in ckpt_model_07A_run01/best/model-57800 >> ave validation accuracy 0.84313
# << best model so far is saved in ckpt_model_07A_run01/best/model-58000 >> ave validation accuracy 0.84315
# STEP   58000 END @ 2016-12-24 14:47:29.744452, training accuracy 0.90000, ave validation accuracy 0.84315
# << best model so far is saved in ckpt_model_07A_run01/best/model-58600 >> ave validation accuracy 0.84318
# << best model so far is saved in ckpt_model_07A_run01/best/model-58700 >> ave validation accuracy 0.84350
# << best model so far is saved in ckpt_model_07A_run01/best/model-58800 >> ave validation accuracy 0.84361
# STEP   59000 END @ 2016-12-24 14:49:59.970083, training accuracy 0.90500, ave validation accuracy 0.84225
# << best model so far is saved in ckpt_model_07A_run01/best/model-59900 >> ave validation accuracy 0.84383
# STEP   60000 END @ 2016-12-24 14:52:18.861054, training accuracy 0.88500, ave validation accuracy 0.84364
# << best model so far is saved in ckpt_model_07A_run01/best/model-60600 >> ave validation accuracy 0.84403
# << best model so far is saved in ckpt_model_07A_run01/best/model-60700 >> ave validation accuracy 0.84429
# << best model so far is saved in ckpt_model_07A_run01/best/model-60800 >> ave validation accuracy 0.84496
# << best model so far is saved in ckpt_model_07A_run01/best/model-60900 >> ave validation accuracy 0.84509
# << best model so far is saved in ckpt_model_07A_run01/best/model-61000 >> ave validation accuracy 0.84535
# STEP   61000 END @ 2016-12-24 14:54:59.474988, training accuracy 0.91000, ave validation accuracy 0.84535
# << best model so far is saved in ckpt_model_07A_run01/best/model-61300 >> ave validation accuracy 0.84554
# << best model so far is saved in ckpt_model_07A_run01/best/model-61800 >> ave validation accuracy 0.84585
# STEP   62000 END @ 2016-12-24 14:57:25.002731, training accuracy 0.92000, ave validation accuracy 0.84583
# << best model so far is saved in ckpt_model_07A_run01/best/model-62300 >> ave validation accuracy 0.84589
# STEP   63000 END @ 2016-12-24 14:59:43.776152, training accuracy 0.94000, ave validation accuracy 0.84456
# STEP   64000 END @ 2016-12-24 15:01:57.305542, training accuracy 0.88500, ave validation accuracy 0.84438
# STEP   65000 END @ 2016-12-24 15:04:11.002590, training accuracy 0.89500, ave validation accuracy 0.84468
# STEP   66000 END @ 2016-12-24 15:06:24.603678, training accuracy 0.92500, ave validation accuracy 0.84445
# STEP   67000 END @ 2016-12-24 15:08:38.308360, training accuracy 0.92000, ave validation accuracy 0.84438
# STEP   68000 END @ 2016-12-24 15:10:52.005849, training accuracy 0.92500, ave validation accuracy 0.84579
# STEP   69000 END @ 2016-12-24 15:13:05.861317, training accuracy 0.90000, ave validation accuracy 0.84406
# << best model so far is saved in ckpt_model_07A_run01/best/model-69800 >> ave validation accuracy 0.84619
# << best model so far is saved in ckpt_model_07A_run01/best/model-70000 >> ave validation accuracy 0.84648
# STEP   70000 END @ 2016-12-24 15:15:31.334935, training accuracy 0.91500, ave validation accuracy 0.84648
# << best model so far is saved in ckpt_model_07A_run01/best/model-70100 >> ave validation accuracy 0.84651
# STEP   71000 END @ 2016-12-24 15:17:50.287893, training accuracy 0.90500, ave validation accuracy 0.84556
# << hourly save at ckpt_model_07A_run01/hourly/model-71900 and pickle_model_07A_run01 >>
# STEP   72000 END @ 2016-12-24 15:20:09.154905, training accuracy 0.90000, ave validation accuracy 0.84468
# << best model so far is saved in ckpt_model_07A_run01/best/model-72700 >> ave validation accuracy 0.84699
# STEP   73000 END @ 2016-12-24 15:22:29.397925, training accuracy 0.93500, ave validation accuracy 0.84650
# << best model so far is saved in ckpt_model_07A_run01/best/model-73200 >> ave validation accuracy 0.84738
# << best model so far is saved in ckpt_model_07A_run01/best/model-73300 >> ave validation accuracy 0.84761
# << best model so far is saved in ckpt_model_07A_run01/best/model-73700 >> ave validation accuracy 0.84768
# STEP   74000 END @ 2016-12-24 15:24:59.934304, training accuracy 0.89500, ave validation accuracy 0.84756
# << best model so far is saved in ckpt_model_07A_run01/best/model-74100 >> ave validation accuracy 0.84795
# << best model so far is saved in ckpt_model_07A_run01/best/model-74300 >> ave validation accuracy 0.84838
# << best model so far is saved in ckpt_model_07A_run01/best/model-75000 >> ave validation accuracy 0.84851
# STEP   75000 END @ 2016-12-24 15:27:29.020409, training accuracy 0.89500, ave validation accuracy 0.84851
# << best model so far is saved in ckpt_model_07A_run01/best/model-76000 >> ave validation accuracy 0.84875
# STEP   76000 END @ 2016-12-24 15:29:48.134052, training accuracy 0.87000, ave validation accuracy 0.84875
# << best model so far is saved in ckpt_model_07A_run01/best/model-76100 >> ave validation accuracy 0.84876
# << best model so far is saved in ckpt_model_07A_run01/best/model-76200 >> ave validation accuracy 0.84884
# << best model so far is saved in ckpt_model_07A_run01/best/model-76300 >> ave validation accuracy 0.84898
# STEP   77000 END @ 2016-12-24 15:32:18.607748, training accuracy 0.90000, ave validation accuracy 0.84770
# STEP   78000 END @ 2016-12-24 15:34:32.285080, training accuracy 0.92500, ave validation accuracy 0.84788
# STEP   79000 END @ 2016-12-24 15:36:46.057907, training accuracy 0.90000, ave validation accuracy 0.84725
# STEP   80000 END @ 2016-12-24 15:38:59.662991, training accuracy 0.93000, ave validation accuracy 0.84840
# << best model so far is saved in ckpt_model_07A_run01/best/model-80900 >> ave validation accuracy 0.84945
# << best model so far is saved in ckpt_model_07A_run01/best/model-81000 >> ave validation accuracy 0.84991
# STEP   81000 END @ 2016-12-24 15:41:25.144670, training accuracy 0.92000, ave validation accuracy 0.84991
# STEP   82000 END @ 2016-12-24 15:43:38.882119, training accuracy 0.91500, ave validation accuracy 0.84810
# STEP   83000 END @ 2016-12-24 15:45:52.638998, training accuracy 0.93500, ave validation accuracy 0.84896
# << best model so far is saved in ckpt_model_07A_run01/best/model-83800 >> ave validation accuracy 0.85001
# << best model so far is saved in ckpt_model_07A_run01/best/model-83900 >> ave validation accuracy 0.85015
# << best model so far is saved in ckpt_model_07A_run01/best/model-84000 >> ave validation accuracy 0.85098
# STEP   84000 END @ 2016-12-24 15:48:23.004605, training accuracy 0.91500, ave validation accuracy 0.85098
# STEP   85000 END @ 2016-12-24 15:50:36.668979, training accuracy 0.94000, ave validation accuracy 0.84926
# STEP   86000 END @ 2016-12-24 15:52:50.644068, training accuracy 0.93500, ave validation accuracy 0.84834
# STEP   87000 END @ 2016-12-24 15:55:04.331777, training accuracy 0.93500, ave validation accuracy 0.84765
# STEP   88000 END @ 2016-12-24 15:57:18.042326, training accuracy 0.94000, ave validation accuracy 0.84939
# STEP   89000 END @ 2016-12-24 15:59:31.904930, training accuracy 0.95500, ave validation accuracy 0.85075
# << best model so far is saved in ckpt_model_07A_run01/best/model-89500 >> ave validation accuracy 0.85111
# << best model so far is saved in ckpt_model_07A_run01/best/model-90000 >> ave validation accuracy 0.85113
# STEP   90000 END @ 2016-12-24 16:01:55.819156, training accuracy 0.91500, ave validation accuracy 0.85113
# << best model so far is saved in ckpt_model_07A_run01/best/model-90600 >> ave validation accuracy 0.85125
# STEP   91000 END @ 2016-12-24 16:04:14.776784, training accuracy 0.93500, ave validation accuracy 0.84995
# STEP   92000 END @ 2016-12-24 16:06:28.479715, training accuracy 0.91500, ave validation accuracy 0.85065
# STEP   93000 END @ 2016-12-24 16:08:42.086611, training accuracy 0.91500, ave validation accuracy 0.85121
# << best model so far is saved in ckpt_model_07A_run01/best/model-93900 >> ave validation accuracy 0.85136
# << best model so far is saved in ckpt_model_07A_run01/best/model-94000 >> ave validation accuracy 0.85180
# STEP   94000 END @ 2016-12-24 16:11:07.465381, training accuracy 0.89500, ave validation accuracy 0.85180
# << best model so far is saved in ckpt_model_07A_run01/best/model-94100 >> ave validation accuracy 0.85219
# << best model so far is saved in ckpt_model_07A_run01/best/model-94300 >> ave validation accuracy 0.85221
# << best model so far is saved in ckpt_model_07A_run01/best/model-94400 >> ave validation accuracy 0.85239
# STEP   95000 END @ 2016-12-24 16:13:36.630711, training accuracy 0.93500, ave validation accuracy 0.85130
# STEP   96000 END @ 2016-12-24 16:15:50.367324, training accuracy 0.93500, ave validation accuracy 0.85078
# STEP   97000 END @ 2016-12-24 16:18:04.293789, training accuracy 0.94500, ave validation accuracy 0.85146
# << best model so far is saved in ckpt_model_07A_run01/best/model-97700 >> ave validation accuracy 0.85279
# << hourly save at ckpt_model_07A_run01/hourly/model-97800 and pickle_model_07A_run01 >>
# << best model so far is saved in ckpt_model_07A_run01/best/model-97900 >> ave validation accuracy 0.85293
# STEP   98000 END @ 2016-12-24 16:20:34.887183, training accuracy 0.93500, ave validation accuracy 0.85259
# STEP   99000 END @ 2016-12-24 16:22:48.717821, training accuracy 0.90000, ave validation accuracy 0.85040
# STEP  100000 END @ 2016-12-24 16:25:02.215251, training accuracy 0.89500, ave validation accuracy 0.85175
# STEP  101000 END @ 2016-12-24 16:27:15.838277, training accuracy 0.92500, ave validation accuracy 0.85113
# STEP  102000 END @ 2016-12-24 16:29:29.535264, training accuracy 0.94500, ave validation accuracy 0.85268
# << best model so far is saved in ckpt_model_07A_run01/best/model-102300 >> ave validation accuracy 0.85335
# << best model so far is saved in ckpt_model_07A_run01/best/model-102600 >> ave validation accuracy 0.85363
# STEP  103000 END @ 2016-12-24 16:31:53.567176, training accuracy 0.90000, ave validation accuracy 0.85220
# STEP  104000 END @ 2016-12-24 16:34:07.204583, training accuracy 0.89500, ave validation accuracy 0.85361
# << best model so far is saved in ckpt_model_07A_run01/best/model-104100 >> ave validation accuracy 0.85369
# << best model so far is saved in ckpt_model_07A_run01/best/model-104200 >> ave validation accuracy 0.85375
# << best model so far is saved in ckpt_model_07A_run01/best/model-104300 >> ave validation accuracy 0.85378
# STEP  105000 END @ 2016-12-24 16:36:36.051168, training accuracy 0.93000, ave validation accuracy 0.85344
# << best model so far is saved in ckpt_model_07A_run01/best/model-105200 >> ave validation accuracy 0.85456
# << best model so far is saved in ckpt_model_07A_run01/best/model-105300 >> ave validation accuracy 0.85464
# STEP  106000 END @ 2016-12-24 16:39:01.111097, training accuracy 0.91500, ave validation accuracy 0.85106
# STEP  107000 END @ 2016-12-24 16:41:14.836286, training accuracy 0.95000, ave validation accuracy 0.85251
# STEP  108000 END @ 2016-12-24 16:43:28.515634, training accuracy 0.90000, ave validation accuracy 0.85294
# STEP  109000 END @ 2016-12-24 16:45:42.260214, training accuracy 0.92000, ave validation accuracy 0.85366
# STEP  110000 END @ 2016-12-24 16:47:55.965215, training accuracy 0.91000, ave validation accuracy 0.85266
# STEP  111000 END @ 2016-12-24 16:50:09.595312, training accuracy 0.91500, ave validation accuracy 0.85153
# STEP  112000 END @ 2016-12-24 16:52:23.499680, training accuracy 0.91500, ave validation accuracy 0.85185
# STEP  113000 END @ 2016-12-24 16:54:37.232836, training accuracy 0.91500, ave validation accuracy 0.85335
# STEP  114000 END @ 2016-12-24 16:56:50.922571, training accuracy 0.92500, ave validation accuracy 0.85129
# STEP  115000 END @ 2016-12-24 16:59:04.828913, training accuracy 0.92000, ave validation accuracy 0.85193
# STEP  116000 END @ 2016-12-24 17:01:18.652612, training accuracy 0.89500, ave validation accuracy 0.85310
# STEP  117000 END @ 2016-12-24 17:03:32.421933, training accuracy 0.88500, ave validation accuracy 0.85426
# STEP  118000 END @ 2016-12-24 17:05:45.905016, training accuracy 0.93000, ave validation accuracy 0.85251
# STEP  119000 END @ 2016-12-24 17:07:59.870138, training accuracy 0.91000, ave validation accuracy 0.85405
# STEP  120000 END @ 2016-12-24 17:10:13.597238, training accuracy 0.94500, ave validation accuracy 0.85368
# STEP  121000 END @ 2016-12-24 17:12:27.201618, training accuracy 0.92500, ave validation accuracy 0.85418
# << best model so far is saved in ckpt_model_07A_run01/best/model-121100 >> ave validation accuracy 0.85468
# << best model so far is saved in ckpt_model_07A_run01/best/model-121700 >> ave validation accuracy 0.85474
# STEP  122000 END @ 2016-12-24 17:14:52.503145, training accuracy 0.92000, ave validation accuracy 0.85453
# STEP  123000 END @ 2016-12-24 17:17:06.232532, training accuracy 0.95000, ave validation accuracy 0.85424
# << best model so far is saved in ckpt_model_07A_run01/best/model-123500 >> ave validation accuracy 0.85499
# << best model so far is saved in ckpt_model_07A_run01/best/model-123600 >> ave validation accuracy 0.85501
# << best model so far is saved in ckpt_model_07A_run01/best/model-123700 >> ave validation accuracy 0.85533
# << best model so far is saved in ckpt_model_07A_run01/best/model-123800 >> ave validation accuracy 0.85554
# << best model so far is saved in ckpt_model_07A_run01/best/model-124000 >> ave validation accuracy 0.85589
# STEP  124000 END @ 2016-12-24 17:19:46.901382, training accuracy 0.95500, ave validation accuracy 0.85589
# << best model so far is saved in ckpt_model_07A_run01/best/model-124100 >> ave validation accuracy 0.85623
# << hourly save at ckpt_model_07A_run01/hourly/model-124200 and pickle_model_07A_run01 >>
# STEP  125000 END @ 2016-12-24 17:22:12.168759, training accuracy 0.93000, ave validation accuracy 0.85555
# << best model so far is saved in ckpt_model_07A_run01/best/model-125200 >> ave validation accuracy 0.85640
# << best model so far is saved in ckpt_model_07A_run01/best/model-125300 >> ave validation accuracy 0.85685
# STEP  126000 END @ 2016-12-24 17:24:36.343491, training accuracy 0.94000, ave validation accuracy 0.85456
# STEP  127000 END @ 2016-12-24 17:26:50.161877, training accuracy 0.93000, ave validation accuracy 0.85639
# STEP  128000 END @ 2016-12-24 17:29:03.807126, training accuracy 0.91500, ave validation accuracy 0.85534
# STEP  129000 END @ 2016-12-24 17:31:17.565164, training accuracy 0.93000, ave validation accuracy 0.85633
# STEP  130000 END @ 2016-12-24 17:33:31.251478, training accuracy 0.93000, ave validation accuracy 0.85566
# STEP  131000 END @ 2016-12-24 17:35:44.872004, training accuracy 0.94500, ave validation accuracy 0.85543
# STEP  132000 END @ 2016-12-24 17:37:58.667571, training accuracy 0.93500, ave validation accuracy 0.85435
# STEP  133000 END @ 2016-12-24 17:40:12.337874, training accuracy 0.91000, ave validation accuracy 0.85311
# << best model so far is saved in ckpt_model_07A_run01/best/model-134000 >> ave validation accuracy 0.85693
# STEP  134000 END @ 2016-12-24 17:42:31.286990, training accuracy 0.94000, ave validation accuracy 0.85693
# STEP  135000 END @ 2016-12-24 17:44:45.084417, training accuracy 0.95000, ave validation accuracy 0.85471
# STEP  136000 END @ 2016-12-24 17:46:58.770107, training accuracy 0.92500, ave validation accuracy 0.85623
# STEP  137000 END @ 2016-12-24 17:49:12.428120, training accuracy 0.91500, ave validation accuracy 0.85514
# STEP  138000 END @ 2016-12-24 17:51:26.150863, training accuracy 0.92500, ave validation accuracy 0.85538
# STEP  139000 END @ 2016-12-24 17:53:39.898692, training accuracy 0.94500, ave validation accuracy 0.85600
# STEP  140000 END @ 2016-12-24 17:55:53.681124, training accuracy 0.94000, ave validation accuracy 0.85559
# STEP  141000 END @ 2016-12-24 17:58:07.427742, training accuracy 0.88500, ave validation accuracy 0.85499
# STEP  142000 END @ 2016-12-24 18:00:21.216794, training accuracy 0.97000, ave validation accuracy 0.85586
# STEP  143000 END @ 2016-12-24 18:02:34.885354, training accuracy 0.89500, ave validation accuracy 0.85561
# << best model so far is saved in ckpt_model_07A_run01/best/model-144000 >> ave validation accuracy 0.85711
# STEP  144000 END @ 2016-12-24 18:04:53.842334, training accuracy 0.92500, ave validation accuracy 0.85711
# << best model so far is saved in ckpt_model_07A_run01/best/model-144100 >> ave validation accuracy 0.85800
# << best model so far is saved in ckpt_model_07A_run01/best/model-144200 >> ave validation accuracy 0.85804
# << best model so far is saved in ckpt_model_07A_run01/best/model-144300 >> ave validation accuracy 0.85809
# << best model so far is saved in ckpt_model_07A_run01/best/model-144400 >> ave validation accuracy 0.85830
# << best model so far is saved in ckpt_model_07A_run01/best/model-144600 >> ave validation accuracy 0.85870
# << best model so far is saved in ckpt_model_07A_run01/best/model-144700 >> ave validation accuracy 0.85893
# STEP  145000 END @ 2016-12-24 18:07:39.953021, training accuracy 0.92000, ave validation accuracy 0.85856
# STEP  146000 END @ 2016-12-24 18:09:53.432325, training accuracy 0.92000, ave validation accuracy 0.85538
# STEP  147000 END @ 2016-12-24 18:12:07.221868, training accuracy 0.91500, ave validation accuracy 0.85731
# STEP  148000 END @ 2016-12-24 18:14:21.038919, training accuracy 0.94500, ave validation accuracy 0.85691
# STEP  149000 END @ 2016-12-24 18:16:34.852486, training accuracy 0.96500, ave validation accuracy 0.85714
# STEP  150000 END @ 2016-12-24 18:18:48.496149, training accuracy 0.94000, ave validation accuracy 0.85833
# << hourly save at ckpt_model_07A_run01/hourly/model-150800 and pickle_model_07A_run01 >>
# STEP  151000 END @ 2016-12-24 18:21:07.310468, training accuracy 0.92000, ave validation accuracy 0.85718
# STEP  152000 END @ 2016-12-24 18:23:21.178424, training accuracy 0.96500, ave validation accuracy 0.85761
# STEP  153000 END @ 2016-12-24 18:25:34.911385, training accuracy 0.92500, ave validation accuracy 0.85693
# STEP  154000 END @ 2016-12-24 18:27:48.768596, training accuracy 0.91500, ave validation accuracy 0.85619
# STEP  155000 END @ 2016-12-24 18:30:02.639601, training accuracy 0.93500, ave validation accuracy 0.85735
# STEP  156000 END @ 2016-12-24 18:32:16.227702, training accuracy 0.93000, ave validation accuracy 0.85619
# STEP  157000 END @ 2016-12-24 18:34:30.004796, training accuracy 0.95000, ave validation accuracy 0.85721
# STEP  158000 END @ 2016-12-24 18:36:43.634543, training accuracy 0.95500, ave validation accuracy 0.85730
# STEP  159000 END @ 2016-12-24 18:38:57.473808, training accuracy 0.95000, ave validation accuracy 0.85761
# STEP  160000 END @ 2016-12-24 18:41:11.255961, training accuracy 0.91000, ave validation accuracy 0.85793
# STEP  161000 END @ 2016-12-24 18:43:25.025717, training accuracy 0.93000, ave validation accuracy 0.85678
# STEP  162000 END @ 2016-12-24 18:45:38.891849, training accuracy 0.91500, ave validation accuracy 0.85834
# STEP  163000 END @ 2016-12-24 18:47:52.651975, training accuracy 0.95000, ave validation accuracy 0.85758
# STEP  164000 END @ 2016-12-24 18:50:06.424414, training accuracy 0.95500, ave validation accuracy 0.85785
# STEP  165000 END @ 2016-12-24 18:52:20.098181, training accuracy 0.93500, ave validation accuracy 0.85810
# << best model so far is saved in ckpt_model_07A_run01/best/model-165200 >> ave validation accuracy 0.85918
# STEP  166000 END @ 2016-12-24 18:54:39.259858, training accuracy 0.96000, ave validation accuracy 0.85670
# STEP  167000 END @ 2016-12-24 18:56:53.030728, training accuracy 0.92500, ave validation accuracy 0.85725
# STEP  168000 END @ 2016-12-24 18:59:06.852311, training accuracy 0.92500, ave validation accuracy 0.85771
# << best model so far is saved in ckpt_model_07A_run01/best/model-168600 >> ave validation accuracy 0.85918
# << best model so far is saved in ckpt_model_07A_run01/best/model-168700 >> ave validation accuracy 0.85918
# STEP  169000 END @ 2016-12-24 19:01:32.049335, training accuracy 0.92500, ave validation accuracy 0.85808
# STEP  170000 END @ 2016-12-24 19:03:45.746980, training accuracy 0.94500, ave validation accuracy 0.85741
# STEP  171000 END @ 2016-12-24 19:05:59.507870, training accuracy 0.91500, ave validation accuracy 0.85804
# STEP  172000 END @ 2016-12-24 19:08:13.461953, training accuracy 0.92500, ave validation accuracy 0.85821
# << best model so far is saved in ckpt_model_07A_run01/best/model-172500 >> ave validation accuracy 0.85921
# << best model so far is saved in ckpt_model_07A_run01/best/model-172600 >> ave validation accuracy 0.85946
# << best model so far is saved in ckpt_model_07A_run01/best/model-172900 >> ave validation accuracy 0.85981
# << best model so far is saved in ckpt_model_07A_run01/best/model-173000 >> ave validation accuracy 0.85986
# STEP  173000 END @ 2016-12-24 19:10:48.977952, training accuracy 0.92500, ave validation accuracy 0.85986
# ...
# STEP  527000 END @ 2016-12-25 08:26:53.397321, training accuracy 0.95500, ave validation accuracy 0.86944
# STEP  528000 END @ 2016-12-25 08:29:07.043282, training accuracy 0.96000, ave validation accuracy 0.86956
# STEP  529000 END @ 2016-12-25 08:31:20.556873, training accuracy 0.95500, ave validation accuracy 0.86895
# STEP  530000 END @ 2016-12-25 08:33:34.404041, training accuracy 0.96000, ave validation accuracy 0.86968
# STEP  531000 END @ 2016-12-25 08:35:48.134379, training accuracy 0.97500, ave validation accuracy 0.86818
# STEP  532000 END @ 2016-12-25 08:38:01.858396, training accuracy 0.93000, ave validation accuracy 0.86904
# STEP  533000 END @ 2016-12-25 08:40:15.760077, training accuracy 0.93000, ave validation accuracy 0.86900
# << best model so far is saved in ckpt_model_07A_run01/best/model-533900 >> ave validation accuracy 0.87080
# STEP  534000 END @ 2016-12-25 08:42:34.581992, training accuracy 0.94000, ave validation accuracy 0.87071
# << best model so far is saved in ckpt_model_07A_run01/best/model-534100 >> ave validation accuracy 0.87081
# << best model so far is saved in ckpt_model_07A_run01/best/model-534300 >> ave validation accuracy 0.87086
# STEP  535000 END @ 2016-12-25 08:44:59.915920, training accuracy 0.95000, ave validation accuracy 0.86893
# STEP  536000 END @ 2016-12-25 08:47:13.468242, training accuracy 0.97000, ave validation accuracy 0.86996
# STEP  537000 END @ 2016-12-25 08:49:27.104102, training accuracy 0.95000, ave validation accuracy 0.87080
# << best model so far is saved in ckpt_model_07A_run01/best/model-537300 >> ave validation accuracy 0.87093
# << best model so far is saved in ckpt_model_07A_run01/best/model-537400 >> ave validation accuracy 0.87134
# << best model so far is saved in ckpt_model_07A_run01/best/model-537700 >> ave validation accuracy 0.87149
# << best model so far is saved in ckpt_model_07A_run01/best/model-537800 >> ave validation accuracy 0.87158
# STEP  538000 END @ 2016-12-25 08:52:02.962861, training accuracy 0.94000, ave validation accuracy 0.87138
# STEP  539000 END @ 2016-12-25 08:54:16.522571, training accuracy 0.93500, ave validation accuracy 0.86914
# STEP  540000 END @ 2016-12-25 08:56:30.431688, training accuracy 0.95000, ave validation accuracy 0.86935
# STEP  541000 END @ 2016-12-25 08:58:44.213036, training accuracy 0.96000, ave validation accuracy 0.86905
# STEP  542000 END @ 2016-12-25 09:00:57.864282, training accuracy 0.93000, ave validation accuracy 0.86960
# STEP  543000 END @ 2016-12-25 09:03:11.726743, training accuracy 0.94500, ave validation accuracy 0.86908
# STEP  544000 END @ 2016-12-25 09:05:25.354700, training accuracy 0.94500, ave validation accuracy 0.86981
# STEP  545000 END @ 2016-12-25 09:07:39.325688, training accuracy 0.97500, ave validation accuracy 0.87008
# STEP  546000 END @ 2016-12-25 09:09:52.923875, training accuracy 0.96500, ave validation accuracy 0.86966
# STEP  547000 END @ 2016-12-25 09:12:06.681291, training accuracy 0.95500, ave validation accuracy 0.86911
# STEP  548000 END @ 2016-12-25 09:14:20.370051, training accuracy 0.93500, ave validation accuracy 0.86954
# STEP  549000 END @ 2016-12-25 09:16:34.149892, training accuracy 0.93500, ave validation accuracy 0.87058
# STEP  550000 END @ 2016-12-25 09:18:47.843197, training accuracy 0.94000, ave validation accuracy 0.86963
# STEP  551000 END @ 2016-12-25 09:21:01.535294, training accuracy 0.97000, ave validation accuracy 0.86954
# STEP  552000 END @ 2016-12-25 09:23:15.382563, training accuracy 0.95000, ave validation accuracy 0.87048
# << hourly save at ckpt_model_07A_run01/hourly/model-552100 and pickle_model_07A_run01 >>
# STEP  553000 END @ 2016-12-25 09:25:34.366975, training accuracy 0.96000, ave validation accuracy 0.86971
# STEP  554000 END @ 2016-12-25 09:27:48.022819, training accuracy 0.94000, ave validation accuracy 0.87023
# STEP  555000 END @ 2016-12-25 09:30:01.897685, training accuracy 0.95000, ave validation accuracy 0.87030
# STEP  556000 END @ 2016-12-25 09:32:15.679928, training accuracy 0.93000, ave validation accuracy 0.86953
# STEP  557000 END @ 2016-12-25 09:34:29.403372, training accuracy 0.94000, ave validation accuracy 0.87011
# STEP  558000 END @ 2016-12-25 09:36:43.184806, training accuracy 0.97500, ave validation accuracy 0.87024
# STEP  559000 END @ 2016-12-25 09:38:56.870556, training accuracy 0.97500, ave validation accuracy 0.86971
# STEP  560000 END @ 2016-12-25 09:41:11.023979, training accuracy 0.96000, ave validation accuracy 0.87053
# STEP  561000 END @ 2016-12-25 09:43:24.843447, training accuracy 0.94000, ave validation accuracy 0.86948
# STEP  562000 END @ 2016-12-25 09:45:38.657170, training accuracy 0.94000, ave validation accuracy 0.86951
# STEP  563000 END @ 2016-12-25 09:47:52.362443, training accuracy 0.93500, ave validation accuracy 0.86960
# STEP  564000 END @ 2016-12-25 09:50:06.058747, training accuracy 0.95000, ave validation accuracy 0.86993
# STEP  565000 END @ 2016-12-25 09:52:19.714103, training accuracy 0.91500, ave validation accuracy 0.87029
# STEP  566000 END @ 2016-12-25 09:54:33.484352, training accuracy 0.96000, ave validation accuracy 0.86983
# STEP  567000 END @ 2016-12-25 09:56:47.155404, training accuracy 0.96000, ave validation accuracy 0.86924
# STEP  568000 END @ 2016-12-25 09:59:01.013663, training accuracy 0.94500, ave validation accuracy 0.86918
# STEP  569000 END @ 2016-12-25 10:01:14.754502, training accuracy 0.94500, ave validation accuracy 0.87020
# STEP  570000 END @ 2016-12-25 10:03:28.427965, training accuracy 0.96000, ave validation accuracy 0.87058
# STEP  571000 END @ 2016-12-25 10:05:42.350371, training accuracy 0.96500, ave validation accuracy 0.87113
# STEP  572000 END @ 2016-12-25 10:07:56.129600, training accuracy 0.93500, ave validation accuracy 0.87076
# STEP  573000 END @ 2016-12-25 10:10:09.861972, training accuracy 0.94500, ave validation accuracy 0.87026
# STEP  574000 END @ 2016-12-25 10:12:23.769505, training accuracy 0.95000, ave validation accuracy 0.87081
# STEP  575000 END @ 2016-12-25 10:14:37.471238, training accuracy 0.93500, ave validation accuracy 0.87014
# STEP  576000 END @ 2016-12-25 10:16:51.078383, training accuracy 0.95000, ave validation accuracy 0.87036
# STEP  577000 END @ 2016-12-25 10:19:04.520818, training accuracy 0.96500, ave validation accuracy 0.87048
# STEP  578000 END @ 2016-12-25 10:21:18.408725, training accuracy 0.94500, ave validation accuracy 0.86986
# STEP  579000 END @ 2016-12-25 10:23:32.056543, training accuracy 0.95000, ave validation accuracy 0.87088
# << hourly save at ckpt_model_07A_run01/hourly/model-579100 and pickle_model_07A_run01 >>
# STEP  580000 END @ 2016-12-25 10:25:52.264027, training accuracy 0.95000, ave validation accuracy 0.86894
# STEP  581000 END @ 2016-12-25 10:28:05.971517, training accuracy 0.95000, ave validation accuracy 0.86974
# STEP  582000 END @ 2016-12-25 10:30:19.840708, training accuracy 0.95000, ave validation accuracy 0.86965
# STEP  583000 END @ 2016-12-25 10:32:33.644688, training accuracy 0.95000, ave validation accuracy 0.87024
# << best model so far is saved in ckpt_model_07A_run01/best/model-583500 >> ave validation accuracy 0.87175
# << best model so far is saved in ckpt_model_07A_run01/best/model-583600 >> ave validation accuracy 0.87195
# << best model so far is saved in ckpt_model_07A_run01/best/model-583700 >> ave validation accuracy 0.87220
# STEP  584000 END @ 2016-12-25 10:35:04.632482, training accuracy 0.96000, ave validation accuracy 0.87101
# STEP  585000 END @ 2016-12-25 10:37:18.470302, training accuracy 0.95500, ave validation accuracy 0.87011
# STEP  586000 END @ 2016-12-25 10:39:32.470877, training accuracy 0.95000, ave validation accuracy 0.87000
# STEP  587000 END @ 2016-12-25 10:41:46.310408, training accuracy 0.93000, ave validation accuracy 0.87140
# STEP  588000 END @ 2016-12-25 10:44:00.149835, training accuracy 0.95500, ave validation accuracy 0.87046
# STEP  589000 END @ 2016-12-25 10:46:13.983721, training accuracy 0.97000, ave validation accuracy 0.87113
# STEP  590000 END @ 2016-12-25 10:48:27.726161, training accuracy 0.98000, ave validation accuracy 0.87000
# STEP  591000 END @ 2016-12-25 10:50:41.452686, training accuracy 0.96000, ave validation accuracy 0.87048
# STEP  592000 END @ 2016-12-25 10:52:55.304428, training accuracy 0.93500, ave validation accuracy 0.86899
# STEP  593000 END @ 2016-12-25 10:55:09.287281, training accuracy 0.98000, ave validation accuracy 0.86960
# STEP  594000 END @ 2016-12-25 10:57:23.209854, training accuracy 0.96500, ave validation accuracy 0.87015
# STEP  595000 END @ 2016-12-25 10:59:36.972496, training accuracy 0.96000, ave validation accuracy 0.86966
# STEP  596000 END @ 2016-12-25 11:01:50.826575, training accuracy 0.95500, ave validation accuracy 0.86996
# STEP  597000 END @ 2016-12-25 11:04:04.634876, training accuracy 0.96500, ave validation accuracy 0.86983
# STEP  598000 END @ 2016-12-25 11:06:18.086667, training accuracy 0.93000, ave validation accuracy 0.87121
# STEP  599000 END @ 2016-12-25 11:08:31.840157, training accuracy 0.95000, ave validation accuracy 0.87130
# STEP  600000 END @ 2016-12-25 11:10:45.778601, training accuracy 0.95500, ave validation accuracy 0.87130
# STEP  601000 END @ 2016-12-25 11:12:59.511402, training accuracy 0.93000, ave validation accuracy 0.87118
# STEP  602000 END @ 2016-12-25 11:15:13.367596, training accuracy 0.97000, ave validation accuracy 0.87058
# STEP  603000 END @ 2016-12-25 11:17:27.137469, training accuracy 0.96000, ave validation accuracy 0.87068
# STEP  604000 END @ 2016-12-25 11:19:40.956483, training accuracy 0.94500, ave validation accuracy 0.87089
# STEP  605000 END @ 2016-12-25 11:21:54.654594, training accuracy 0.96500, ave validation accuracy 0.87138
# << hourly save at ckpt_model_07A_run01/hourly/model-605900 and pickle_model_07A_run01 >>
# STEP  606000 END @ 2016-12-25 11:24:13.738024, training accuracy 0.95000, ave validation accuracy 0.87098
# STEP  607000 END @ 2016-12-25 11:26:27.598953, training accuracy 0.94500, ave validation accuracy 0.87044
# STEP  608000 END @ 2016-12-25 11:28:41.260516, training accuracy 0.95000, ave validation accuracy 0.86974
# STEP  609000 END @ 2016-12-25 11:30:55.117983, training accuracy 0.95500, ave validation accuracy 0.87141
# STEP  610000 END @ 2016-12-25 11:33:08.724675, training accuracy 0.94000, ave validation accuracy 0.87045
# STEP  611000 END @ 2016-12-25 11:35:22.635656, training accuracy 0.97000, ave validation accuracy 0.87125
# STEP  612000 END @ 2016-12-25 11:37:36.401487, training accuracy 0.97500, ave validation accuracy 0.87098
# STEP  613000 END @ 2016-12-25 11:39:49.947602, training accuracy 0.98500, ave validation accuracy 0.87030
# STEP  614000 END @ 2016-12-25 11:42:03.696615, training accuracy 0.97500, ave validation accuracy 0.87174
# << best model so far is saved in ckpt_model_07A_run01/best/model-614900 >> ave validation accuracy 0.87243
# STEP  615000 END @ 2016-12-25 11:44:24.037690, training accuracy 0.94500, ave validation accuracy 0.87218
# STEP  616000 END @ 2016-12-25 11:46:37.849566, training accuracy 0.95500, ave validation accuracy 0.87090
# STEP  617000 END @ 2016-12-25 11:48:51.614996, training accuracy 0.96000, ave validation accuracy 0.87185
# STEP  618000 END @ 2016-12-25 11:51:05.217385, training accuracy 0.94500, ave validation accuracy 0.87058
# << best model so far is saved in ckpt_model_07A_run01/best/model-618900 >> ave validation accuracy 0.87253
# STEP  619000 END @ 2016-12-25 11:53:22.879358, training accuracy 0.94500, ave validation accuracy 0.87224
# STEP  620000 END @ 2016-12-25 11:55:36.541839, training accuracy 0.97500, ave validation accuracy 0.87161
# STEP  621000 END @ 2016-12-25 11:57:50.370476, training accuracy 0.95000, ave validation accuracy 0.87058
# STEP  622000 END @ 2016-12-25 12:00:04.060127, training accuracy 0.96000, ave validation accuracy 0.87026
# STEP  623000 END @ 2016-12-25 12:02:18.124773, training accuracy 0.97000, ave validation accuracy 0.86978
# STEP  624000 END @ 2016-12-25 12:04:32.000372, training accuracy 0.94000, ave validation accuracy 0.86931
# STEP  625000 END @ 2016-12-25 12:06:45.750271, training accuracy 0.96000, ave validation accuracy 0.87001
# STEP  626000 END @ 2016-12-25 12:08:59.531363, training accuracy 0.99000, ave validation accuracy 0.87076
# STEP  627000 END @ 2016-12-25 12:11:13.233786, training accuracy 0.95500, ave validation accuracy 0.87098
# STEP  628000 END @ 2016-12-25 12:13:27.122398, training accuracy 0.95500, ave validation accuracy 0.87033
# STEP  629000 END @ 2016-12-25 12:15:40.829962, training accuracy 0.94000, ave validation accuracy 0.87148
# STEP  630000 END @ 2016-12-25 12:17:54.637663, training accuracy 0.97500, ave validation accuracy 0.87133
# STEP  631000 END @ 2016-12-25 12:20:08.391394, training accuracy 0.94000, ave validation accuracy 0.87041
# STEP  632000 END @ 2016-12-25 12:22:22.280439, training accuracy 0.95000, ave validation accuracy 0.87181
# << hourly save at ckpt_model_07A_run01/hourly/model-632800 and pickle_model_07A_run01 >>
# STEP  633000 END @ 2016-12-25 12:24:42.570137, training accuracy 0.97000, ave validation accuracy 0.86966
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-feafc4fc8124> in <module>()
#       1 #Train the model
# ----> 2 train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#
# /home/kumiko/cifar10/helper_functions.pyc in train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#     251             _, summary = sess.run([graph_variables['optimizer'], graph_variables['summarizer']],
#     252                                   feed_dict={graph_variables['data']: batch_data, graph_variables['labels']: batch_labels,
# --> 253                                              graph_variables['keep_prob']: accuracy_log['variables']['dropout_train_keep_prob'], graph_variables['is_training']: True})
#     254
#     255             if i % accuracy_log['variables']['log_every'] == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Test accuracy
test_accuracy(graph_variables, accuracy_log, test_data, test_labels)
# Out:
# << test accuracy 0.86900 >>
