# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from helper_functions import *

# %%
#Continueing training?
continued = False
checkpoint_file_to_use = None #Example: 'ckpt_model_01_run01/hourly/model-9350'

#If training from step 0
#############################
naming = 'model_02_run01'
#############################
variables = {
    'modify_images': False,
    'crop_images': False,
    'enlarge_images': False,
    'before_flatten_image_side_size': 4, #Need to calculate
    'first_hidden_layer_features': 384,
    'weights_stddev': 0.015,
    'biases_initial': 0.1,
    'dropout_train_keep_prob': 1.0,
    'learning_rate_initial': 0.01,
    'learning_rate_decay_steps': int(10000000),
    'learning_rate_decay': 1.0,
    'start_step_early_stopping': 150000,
    'early_stopping_patience': 0.1,
    'batch_size': 200,
    'max_steps': 100000000,
    'average_n_validation_accuracy': 8
}

# %%
#Create accuracy_log to pickle and directories for TensorBoard and checkpoint
accuracy_log = prep_accuracy_log(continued, checkpoint_file_to_use, naming, variables)

# %%
#Get data and labels
(train_data, validation_data, test_data, train_labels, validation_labels, test_labels) = get_data_and_labels(accuracy_log)

# %%
#Build a model
crop_images = accuracy_log['variables']['crop_images']
modify_images = accuracy_log['variables']['modify_images']
weights_stddev = accuracy_log['variables']['weights_stddev']
biases_initial = accuracy_log['variables']['biases_initial']
input_image_side_size = accuracy_log['variables']['input_image_side_size']
crop_to_side_size = accuracy_log['variables']['crop_to_side_size']
before_flatten_image_side_size = accuracy_log['variables']['before_flatten_image_side_size']
first_hidden_layer_features = accuracy_log['variables']['first_hidden_layer_features']
learning_rate_initial = accuracy_log['variables']['learning_rate_initial']
learning_rate_decay_steps = accuracy_log['variables']['learning_rate_decay_steps']
learning_rate_decay = accuracy_log['variables']['learning_rate_decay']

graph = tf.Graph()
with graph.as_default():
    global_step = tf.Variable(0, trainable=False)
    is_training = tf.placeholder(tf.bool)
    keep_prob = tf.placeholder(tf.float32)

    data = tf.placeholder(tf.float32, [None, input_image_side_size, input_image_side_size, 3])
    labels = tf.placeholder(tf.float32, [None, 10])
    
    if crop_images & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    elif (not crop_images) & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify_no_crop(data), lambda: tf.identity(data))
    elif crop_images & (not modify_images):
        data_v2 = tf.cond(is_training, lambda: random_crop(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    else:
        data_v2 = tf.identity(data)
        
    W_conv1 = weight_variable([3, 3, 3, 64], weights_stddev, 'W_conv1')
    b_conv1 = bias_variable(biases_initial, [64], 'b_conv1')
    conv1 = conv2d(data_v2, W_conv1) + b_conv1
    conv1_relu = tf.nn.relu(conv1)
    pool1 = max_pool_3x3_stride2(conv1_relu)

    W_conv2 = weight_variable([3, 3, 64, 64], weights_stddev, 'W_conv2')
    b_conv2 = bias_variable(biases_initial, [64], 'b_conv2')
    conv2 = conv2d(pool1, W_conv2) + b_conv2
    conv2_relu = tf.nn.relu(conv2)
    pool2 = max_pool_3x3_stride2(conv2_relu)

    W_conv3 = weight_variable([3, 3, 64, 128], weights_stddev, 'W_conv3')
    b_conv3 = bias_variable(biases_initial, [128], 'b_conv3')
    conv3 = conv2d(pool2, W_conv3) + b_conv3
    conv3_relu = tf.nn.relu(conv3)
    pool3 = max_pool_3x3_stride2(conv3_relu)
    
    pool3_flat = tf.reshape(pool3, [-1, before_flatten_image_side_size*before_flatten_image_side_size*128])

    W_fc1 = weight_variable([before_flatten_image_side_size*before_flatten_image_side_size*128, first_hidden_layer_features], weights_stddev, 'W_fc1')
    b_fc1 = bias_variable(biases_initial, [first_hidden_layer_features], 'b_fc1')
    fc1 = tf.matmul(pool3_flat, W_fc1) + b_fc1
    fc1_relu = tf.nn.relu(fc1)
    
    W_fc2 = weight_variable([first_hidden_layer_features, int(first_hidden_layer_features/2)], weights_stddev, 'W_fc2')
    b_fc2 = bias_variable(biases_initial, [first_hidden_layer_features/2], 'b_fc2')
    fc2 = tf.matmul(fc1_relu, W_fc2) + b_fc2
    fc2_relu = tf.nn.relu(fc2)
    
    W_fc3 = weight_variable([int(first_hidden_layer_features/2), 10], weights_stddev, 'W_fc3')
    b_fc3 = bias_variable(biases_initial, [10], 'b_fc3')
    logits = tf.matmul(fc2_relu, W_fc3) + b_fc3

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))
    
    learning_rate = tf.train.exponential_decay(learning_rate_initial, global_step, learning_rate_decay_steps, 
                                               learning_rate_decay, staircase=True)
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    tf.summary.scalar('loss', loss)
    tf.summary.scalar('learning_rate', learning_rate)
    tf.summary.scalar('training_accuracy', accuracy)
    
    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name, var)
    
    summarizer = tf.summary.merge_all()
    
graph_variables = {'graph': graph, 
                   'optimizer': optimizer, 
                   'summarizer': summarizer, 
                   'data': data, 
                   'labels': labels, 
                   'keep_prob': keep_prob, 
                   'is_training': is_training, 
                   'correct_prediction': correct_prediction,
                   'accuracy': accuracy}

# %%
#Train the model
train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
# Out:
# TRAINING   START @ 2016-12-23 20:45:28.032808
# << best model so far is saved in ckpt_model_02_run01/best/model-0 >> ave validation accuracy 0.09770
# STEP       0 END @ 2016-12-23 20:45:33.134318, training accuracy 0.10500, ave validation accuracy 0.09770
# << best model so far is saved in ckpt_model_02_run01/best/model-100 >> ave validation accuracy 0.09770
# << best model so far is saved in ckpt_model_02_run01/best/model-200 >> ave validation accuracy 0.09770
# << best model so far is saved in ckpt_model_02_run01/best/model-300 >> ave validation accuracy 0.09770
# << best model so far is saved in ckpt_model_02_run01/best/model-400 >> ave validation accuracy 0.09770
# STEP    1000 END @ 2016-12-23 20:46:31.087736, training accuracy 0.10000, ave validation accuracy 0.09645
# STEP    2000 END @ 2016-12-23 20:47:23.625687, training accuracy 0.11000, ave validation accuracy 0.09551
# STEP    3000 END @ 2016-12-23 20:48:16.123336, training accuracy 0.11500, ave validation accuracy 0.09584
# STEP    4000 END @ 2016-12-23 20:49:08.797763, training accuracy 0.11000, ave validation accuracy 0.09555
# STEP    5000 END @ 2016-12-23 20:50:01.184966, training accuracy 0.12000, ave validation accuracy 0.09520
# STEP    6000 END @ 2016-12-23 20:50:53.703922, training accuracy 0.11000, ave validation accuracy 0.09555
# STEP    7000 END @ 2016-12-23 20:51:46.180622, training accuracy 0.11000, ave validation accuracy 0.09551
# STEP    8000 END @ 2016-12-23 20:52:38.608547, training accuracy 0.10500, ave validation accuracy 0.09586
# STEP    9000 END @ 2016-12-23 20:53:30.965938, training accuracy 0.10000, ave validation accuracy 0.09576
# STEP   10000 END @ 2016-12-23 20:54:23.387730, training accuracy 0.10500, ave validation accuracy 0.09590
# STEP   11000 END @ 2016-12-23 20:55:15.907839, training accuracy 0.11500, ave validation accuracy 0.09551
# STEP   12000 END @ 2016-12-23 20:56:08.481527, training accuracy 0.11000, ave validation accuracy 0.09520
# STEP   13000 END @ 2016-12-23 20:57:01.075596, training accuracy 0.15500, ave validation accuracy 0.09619
# STEP   14000 END @ 2016-12-23 20:57:53.504836, training accuracy 0.11500, ave validation accuracy 0.09520
# STEP   15000 END @ 2016-12-23 20:58:45.977238, training accuracy 0.09500, ave validation accuracy 0.09551
# STEP   16000 END @ 2016-12-23 20:59:38.530294, training accuracy 0.11000, ave validation accuracy 0.09652
# STEP   17000 END @ 2016-12-23 21:00:31.055631, training accuracy 0.09000, ave validation accuracy 0.09583
# STEP   18000 END @ 2016-12-23 21:01:23.496060, training accuracy 0.10000, ave validation accuracy 0.09669
# STEP   19000 END @ 2016-12-23 21:02:15.969021, training accuracy 0.11000, ave validation accuracy 0.09551
# << best model so far is saved in ckpt_model_02_run01/best/model-19300 >> ave validation accuracy 0.09914
# << best model so far is saved in ckpt_model_02_run01/best/model-19900 >> ave validation accuracy 0.09939
# << best model so far is saved in ckpt_model_02_run01/best/model-20000 >> ave validation accuracy 0.09939
# STEP   20000 END @ 2016-12-23 21:03:12.221004, training accuracy 0.09500, ave validation accuracy 0.09939
# STEP   21000 END @ 2016-12-23 21:04:04.615692, training accuracy 0.11000, ave validation accuracy 0.09771
# << best model so far is saved in ckpt_model_02_run01/best/model-22000 >> ave validation accuracy 0.10229
# STEP   22000 END @ 2016-12-23 21:04:57.511474, training accuracy 0.13000, ave validation accuracy 0.10229
# << best model so far is saved in ckpt_model_02_run01/best/model-22100 >> ave validation accuracy 0.10629
# << best model so far is saved in ckpt_model_02_run01/best/model-22200 >> ave validation accuracy 0.11256
# << best model so far is saved in ckpt_model_02_run01/best/model-22300 >> ave validation accuracy 0.12072
# << best model so far is saved in ckpt_model_02_run01/best/model-22400 >> ave validation accuracy 0.12720
# << best model so far is saved in ckpt_model_02_run01/best/model-22500 >> ave validation accuracy 0.13576
# << best model so far is saved in ckpt_model_02_run01/best/model-22600 >> ave validation accuracy 0.14164
# << best model so far is saved in ckpt_model_02_run01/best/model-22700 >> ave validation accuracy 0.14837
# << best model so far is saved in ckpt_model_02_run01/best/model-22800 >> ave validation accuracy 0.15155
# << best model so far is saved in ckpt_model_02_run01/best/model-22900 >> ave validation accuracy 0.15754
# << best model so far is saved in ckpt_model_02_run01/best/model-23000 >> ave validation accuracy 0.16111
# STEP   23000 END @ 2016-12-23 21:06:02.933668, training accuracy 0.15500, ave validation accuracy 0.16111
# << best model so far is saved in ckpt_model_02_run01/best/model-23200 >> ave validation accuracy 0.16324
# << best model so far is saved in ckpt_model_02_run01/best/model-23300 >> ave validation accuracy 0.16484
# << best model so far is saved in ckpt_model_02_run01/best/model-23400 >> ave validation accuracy 0.16704
# << best model so far is saved in ckpt_model_02_run01/best/model-23500 >> ave validation accuracy 0.16957
# << best model so far is saved in ckpt_model_02_run01/best/model-23600 >> ave validation accuracy 0.17057
# << best model so far is saved in ckpt_model_02_run01/best/model-23900 >> ave validation accuracy 0.17105
# << best model so far is saved in ckpt_model_02_run01/best/model-24000 >> ave validation accuracy 0.17136
# STEP   24000 END @ 2016-12-23 21:07:04.447958, training accuracy 0.15000, ave validation accuracy 0.17136
# << best model so far is saved in ckpt_model_02_run01/best/model-24100 >> ave validation accuracy 0.17149
# << best model so far is saved in ckpt_model_02_run01/best/model-24200 >> ave validation accuracy 0.17277
# << best model so far is saved in ckpt_model_02_run01/best/model-24300 >> ave validation accuracy 0.17472
# << best model so far is saved in ckpt_model_02_run01/best/model-24400 >> ave validation accuracy 0.17909
# << best model so far is saved in ckpt_model_02_run01/best/model-24500 >> ave validation accuracy 0.18365
# << best model so far is saved in ckpt_model_02_run01/best/model-24600 >> ave validation accuracy 0.18757
# << best model so far is saved in ckpt_model_02_run01/best/model-24700 >> ave validation accuracy 0.19330
# << best model so far is saved in ckpt_model_02_run01/best/model-24800 >> ave validation accuracy 0.19845
# << best model so far is saved in ckpt_model_02_run01/best/model-24900 >> ave validation accuracy 0.20534
# << best model so far is saved in ckpt_model_02_run01/best/model-25000 >> ave validation accuracy 0.21019
# STEP   25000 END @ 2016-12-23 21:08:09.824210, training accuracy 0.23000, ave validation accuracy 0.21019
# << best model so far is saved in ckpt_model_02_run01/best/model-25100 >> ave validation accuracy 0.21554
# << best model so far is saved in ckpt_model_02_run01/best/model-25200 >> ave validation accuracy 0.21834
# << best model so far is saved in ckpt_model_02_run01/best/model-25300 >> ave validation accuracy 0.22286
# << best model so far is saved in ckpt_model_02_run01/best/model-25400 >> ave validation accuracy 0.22575
# << best model so far is saved in ckpt_model_02_run01/best/model-25500 >> ave validation accuracy 0.22764
# << best model so far is saved in ckpt_model_02_run01/best/model-25600 >> ave validation accuracy 0.23284
# << best model so far is saved in ckpt_model_02_run01/best/model-25700 >> ave validation accuracy 0.23424
# << best model so far is saved in ckpt_model_02_run01/best/model-25800 >> ave validation accuracy 0.23850
# << best model so far is saved in ckpt_model_02_run01/best/model-25900 >> ave validation accuracy 0.24139
# << best model so far is saved in ckpt_model_02_run01/best/model-26000 >> ave validation accuracy 0.24621
# STEP   26000 END @ 2016-12-23 21:09:15.160605, training accuracy 0.24000, ave validation accuracy 0.24621
# << best model so far is saved in ckpt_model_02_run01/best/model-26100 >> ave validation accuracy 0.24791
# << best model so far is saved in ckpt_model_02_run01/best/model-26200 >> ave validation accuracy 0.25285
# << best model so far is saved in ckpt_model_02_run01/best/model-26300 >> ave validation accuracy 0.25571
# << best model so far is saved in ckpt_model_02_run01/best/model-26400 >> ave validation accuracy 0.25676
# << best model so far is saved in ckpt_model_02_run01/best/model-26500 >> ave validation accuracy 0.25865
# << best model so far is saved in ckpt_model_02_run01/best/model-26600 >> ave validation accuracy 0.25950
# << best model so far is saved in ckpt_model_02_run01/best/model-26900 >> ave validation accuracy 0.26180
# << best model so far is saved in ckpt_model_02_run01/best/model-27000 >> ave validation accuracy 0.26342
# STEP   27000 END @ 2016-12-23 21:10:18.401143, training accuracy 0.29500, ave validation accuracy 0.26342
# << best model so far is saved in ckpt_model_02_run01/best/model-27100 >> ave validation accuracy 0.26576
# << best model so far is saved in ckpt_model_02_run01/best/model-27200 >> ave validation accuracy 0.26775
# << best model so far is saved in ckpt_model_02_run01/best/model-27300 >> ave validation accuracy 0.26999
# << best model so far is saved in ckpt_model_02_run01/best/model-27400 >> ave validation accuracy 0.27074
# << best model so far is saved in ckpt_model_02_run01/best/model-27500 >> ave validation accuracy 0.27451
# << best model so far is saved in ckpt_model_02_run01/best/model-27700 >> ave validation accuracy 0.27619
# << best model so far is saved in ckpt_model_02_run01/best/model-27800 >> ave validation accuracy 0.27662
# << best model so far is saved in ckpt_model_02_run01/best/model-27900 >> ave validation accuracy 0.27856
# STEP   28000 END @ 2016-12-23 21:11:20.549323, training accuracy 0.29000, ave validation accuracy 0.27707
# << best model so far is saved in ckpt_model_02_run01/best/model-28100 >> ave validation accuracy 0.28080
# << best model so far is saved in ckpt_model_02_run01/best/model-28200 >> ave validation accuracy 0.28334
# << best model so far is saved in ckpt_model_02_run01/best/model-28300 >> ave validation accuracy 0.28460
# << best model so far is saved in ckpt_model_02_run01/best/model-28400 >> ave validation accuracy 0.29114
# << best model so far is saved in ckpt_model_02_run01/best/model-28500 >> ave validation accuracy 0.29394
# << best model so far is saved in ckpt_model_02_run01/best/model-28600 >> ave validation accuracy 0.30085
# << best model so far is saved in ckpt_model_02_run01/best/model-28700 >> ave validation accuracy 0.30640
# << best model so far is saved in ckpt_model_02_run01/best/model-28800 >> ave validation accuracy 0.31629
# << best model so far is saved in ckpt_model_02_run01/best/model-28900 >> ave validation accuracy 0.31900
# << best model so far is saved in ckpt_model_02_run01/best/model-29000 >> ave validation accuracy 0.32532
# STEP   29000 END @ 2016-12-23 21:12:25.739258, training accuracy 0.37500, ave validation accuracy 0.32532
# << best model so far is saved in ckpt_model_02_run01/best/model-29100 >> ave validation accuracy 0.33244
# << best model so far is saved in ckpt_model_02_run01/best/model-29200 >> ave validation accuracy 0.33730
# << best model so far is saved in ckpt_model_02_run01/best/model-29300 >> ave validation accuracy 0.34332
# << best model so far is saved in ckpt_model_02_run01/best/model-29400 >> ave validation accuracy 0.34749
# << best model so far is saved in ckpt_model_02_run01/best/model-29500 >> ave validation accuracy 0.35294
# << best model so far is saved in ckpt_model_02_run01/best/model-29600 >> ave validation accuracy 0.35645
# << best model so far is saved in ckpt_model_02_run01/best/model-29700 >> ave validation accuracy 0.36052
# << best model so far is saved in ckpt_model_02_run01/best/model-29800 >> ave validation accuracy 0.36512
# << best model so far is saved in ckpt_model_02_run01/best/model-29900 >> ave validation accuracy 0.36984
# << best model so far is saved in ckpt_model_02_run01/best/model-30000 >> ave validation accuracy 0.37429
# STEP   30000 END @ 2016-12-23 21:13:31.026794, training accuracy 0.38500, ave validation accuracy 0.37429
# << best model so far is saved in ckpt_model_02_run01/best/model-30100 >> ave validation accuracy 0.37626
# << best model so far is saved in ckpt_model_02_run01/best/model-30200 >> ave validation accuracy 0.37889
# << best model so far is saved in ckpt_model_02_run01/best/model-30300 >> ave validation accuracy 0.38039
# << best model so far is saved in ckpt_model_02_run01/best/model-30400 >> ave validation accuracy 0.38250
# << best model so far is saved in ckpt_model_02_run01/best/model-30500 >> ave validation accuracy 0.38765
# << best model so far is saved in ckpt_model_02_run01/best/model-30600 >> ave validation accuracy 0.39071
# << best model so far is saved in ckpt_model_02_run01/best/model-30900 >> ave validation accuracy 0.39235
# << best model so far is saved in ckpt_model_02_run01/best/model-31000 >> ave validation accuracy 0.39472
# STEP   31000 END @ 2016-12-23 21:14:34.218687, training accuracy 0.44000, ave validation accuracy 0.39472
# << best model so far is saved in ckpt_model_02_run01/best/model-31100 >> ave validation accuracy 0.39664
# << best model so far is saved in ckpt_model_02_run01/best/model-31200 >> ave validation accuracy 0.39917
# << best model so far is saved in ckpt_model_02_run01/best/model-31300 >> ave validation accuracy 0.40094
# << best model so far is saved in ckpt_model_02_run01/best/model-31400 >> ave validation accuracy 0.40454
# << best model so far is saved in ckpt_model_02_run01/best/model-31500 >> ave validation accuracy 0.40682
# << best model so far is saved in ckpt_model_02_run01/best/model-31600 >> ave validation accuracy 0.41187
# << best model so far is saved in ckpt_model_02_run01/best/model-31700 >> ave validation accuracy 0.41612
# << best model so far is saved in ckpt_model_02_run01/best/model-31800 >> ave validation accuracy 0.41944
# << best model so far is saved in ckpt_model_02_run01/best/model-31900 >> ave validation accuracy 0.42356
# << best model so far is saved in ckpt_model_02_run01/best/model-32000 >> ave validation accuracy 0.42711
# STEP   32000 END @ 2016-12-23 21:15:38.121372, training accuracy 0.38000, ave validation accuracy 0.42711
# << best model so far is saved in ckpt_model_02_run01/best/model-32100 >> ave validation accuracy 0.42892
# << best model so far is saved in ckpt_model_02_run01/best/model-32300 >> ave validation accuracy 0.43232
# << best model so far is saved in ckpt_model_02_run01/best/model-32400 >> ave validation accuracy 0.43504
# << best model so far is saved in ckpt_model_02_run01/best/model-32500 >> ave validation accuracy 0.43616
# << best model so far is saved in ckpt_model_02_run01/best/model-32600 >> ave validation accuracy 0.43892
# << best model so far is saved in ckpt_model_02_run01/best/model-32800 >> ave validation accuracy 0.44120
# << best model so far is saved in ckpt_model_02_run01/best/model-32900 >> ave validation accuracy 0.44486
# << best model so far is saved in ckpt_model_02_run01/best/model-33000 >> ave validation accuracy 0.44911
# STEP   33000 END @ 2016-12-23 21:16:41.566670, training accuracy 0.54500, ave validation accuracy 0.44911
# << best model so far is saved in ckpt_model_02_run01/best/model-33100 >> ave validation accuracy 0.45282
# << best model so far is saved in ckpt_model_02_run01/best/model-33200 >> ave validation accuracy 0.45580
# << best model so far is saved in ckpt_model_02_run01/best/model-33300 >> ave validation accuracy 0.45904
# << best model so far is saved in ckpt_model_02_run01/best/model-33400 >> ave validation accuracy 0.45982
# << best model so far is saved in ckpt_model_02_run01/best/model-33500 >> ave validation accuracy 0.46355
# << best model so far is saved in ckpt_model_02_run01/best/model-33600 >> ave validation accuracy 0.46545
# << best model so far is saved in ckpt_model_02_run01/best/model-33700 >> ave validation accuracy 0.46655
# << best model so far is saved in ckpt_model_02_run01/best/model-33800 >> ave validation accuracy 0.46860
# << best model so far is saved in ckpt_model_02_run01/best/model-33900 >> ave validation accuracy 0.47150
# << best model so far is saved in ckpt_model_02_run01/best/model-34000 >> ave validation accuracy 0.47327
# STEP   34000 END @ 2016-12-23 21:17:46.749922, training accuracy 0.52500, ave validation accuracy 0.47327
# << best model so far is saved in ckpt_model_02_run01/best/model-34100 >> ave validation accuracy 0.47602
# << best model so far is saved in ckpt_model_02_run01/best/model-34200 >> ave validation accuracy 0.47935
# << best model so far is saved in ckpt_model_02_run01/best/model-34400 >> ave validation accuracy 0.48230
# << best model so far is saved in ckpt_model_02_run01/best/model-34500 >> ave validation accuracy 0.48450
# << best model so far is saved in ckpt_model_02_run01/best/model-34600 >> ave validation accuracy 0.48616
# << best model so far is saved in ckpt_model_02_run01/best/model-34700 >> ave validation accuracy 0.48794
# << best model so far is saved in ckpt_model_02_run01/best/model-34800 >> ave validation accuracy 0.49142
# << best model so far is saved in ckpt_model_02_run01/best/model-34900 >> ave validation accuracy 0.49555
# << best model so far is saved in ckpt_model_02_run01/best/model-35000 >> ave validation accuracy 0.49687
# STEP   35000 END @ 2016-12-23 21:18:50.259039, training accuracy 0.46000, ave validation accuracy 0.49687
# << best model so far is saved in ckpt_model_02_run01/best/model-35100 >> ave validation accuracy 0.50350
# << best model so far is saved in ckpt_model_02_run01/best/model-35200 >> ave validation accuracy 0.50485
# << best model so far is saved in ckpt_model_02_run01/best/model-35300 >> ave validation accuracy 0.50920
# << best model so far is saved in ckpt_model_02_run01/best/model-35400 >> ave validation accuracy 0.51229
# << best model so far is saved in ckpt_model_02_run01/best/model-35500 >> ave validation accuracy 0.51514
# << best model so far is saved in ckpt_model_02_run01/best/model-35600 >> ave validation accuracy 0.51579
# << best model so far is saved in ckpt_model_02_run01/best/model-35700 >> ave validation accuracy 0.51664
# << best model so far is saved in ckpt_model_02_run01/best/model-35900 >> ave validation accuracy 0.51700
# << best model so far is saved in ckpt_model_02_run01/best/model-36000 >> ave validation accuracy 0.51970
# STEP   36000 END @ 2016-12-23 21:19:53.928622, training accuracy 0.58000, ave validation accuracy 0.51970
# << best model so far is saved in ckpt_model_02_run01/best/model-36100 >> ave validation accuracy 0.52044
# << best model so far is saved in ckpt_model_02_run01/best/model-36200 >> ave validation accuracy 0.52447
# << best model so far is saved in ckpt_model_02_run01/best/model-36300 >> ave validation accuracy 0.52730
# << best model so far is saved in ckpt_model_02_run01/best/model-36400 >> ave validation accuracy 0.53124
# << best model so far is saved in ckpt_model_02_run01/best/model-36500 >> ave validation accuracy 0.53514
# << best model so far is saved in ckpt_model_02_run01/best/model-36600 >> ave validation accuracy 0.54160
# << best model so far is saved in ckpt_model_02_run01/best/model-36700 >> ave validation accuracy 0.54431
# << best model so far is saved in ckpt_model_02_run01/best/model-36800 >> ave validation accuracy 0.54476
# << best model so far is saved in ckpt_model_02_run01/best/model-36900 >> ave validation accuracy 0.54785
# << best model so far is saved in ckpt_model_02_run01/best/model-37000 >> ave validation accuracy 0.54982
# STEP   37000 END @ 2016-12-23 21:20:59.271082, training accuracy 0.58000, ave validation accuracy 0.54982
# << best model so far is saved in ckpt_model_02_run01/best/model-37400 >> ave validation accuracy 0.55031
# << best model so far is saved in ckpt_model_02_run01/best/model-37500 >> ave validation accuracy 0.55192
# << best model so far is saved in ckpt_model_02_run01/best/model-37600 >> ave validation accuracy 0.55649
# << best model so far is saved in ckpt_model_02_run01/best/model-37700 >> ave validation accuracy 0.55856
# << best model so far is saved in ckpt_model_02_run01/best/model-37800 >> ave validation accuracy 0.56149
# << best model so far is saved in ckpt_model_02_run01/best/model-37900 >> ave validation accuracy 0.56767
# << best model so far is saved in ckpt_model_02_run01/best/model-38000 >> ave validation accuracy 0.57231
# STEP   38000 END @ 2016-12-23 21:22:00.850905, training accuracy 0.56000, ave validation accuracy 0.57231
# << best model so far is saved in ckpt_model_02_run01/best/model-38100 >> ave validation accuracy 0.57481
# << best model so far is saved in ckpt_model_02_run01/best/model-38200 >> ave validation accuracy 0.57896
# << best model so far is saved in ckpt_model_02_run01/best/model-38300 >> ave validation accuracy 0.58307
# << best model so far is saved in ckpt_model_02_run01/best/model-38400 >> ave validation accuracy 0.58472
# << best model so far is saved in ckpt_model_02_run01/best/model-38500 >> ave validation accuracy 0.58835
# << best model so far is saved in ckpt_model_02_run01/best/model-38600 >> ave validation accuracy 0.58859
# << best model so far is saved in ckpt_model_02_run01/best/model-38700 >> ave validation accuracy 0.58989
# << best model so far is saved in ckpt_model_02_run01/best/model-38800 >> ave validation accuracy 0.59070
# << best model so far is saved in ckpt_model_02_run01/best/model-38900 >> ave validation accuracy 0.59281
# << best model so far is saved in ckpt_model_02_run01/best/model-39000 >> ave validation accuracy 0.59341
# STEP   39000 END @ 2016-12-23 21:23:06.242829, training accuracy 0.65500, ave validation accuracy 0.59341
# << best model so far is saved in ckpt_model_02_run01/best/model-39100 >> ave validation accuracy 0.59366
# << best model so far is saved in ckpt_model_02_run01/best/model-39200 >> ave validation accuracy 0.59489
# << best model so far is saved in ckpt_model_02_run01/best/model-39600 >> ave validation accuracy 0.59621
# << best model so far is saved in ckpt_model_02_run01/best/model-39700 >> ave validation accuracy 0.59681
# << best model so far is saved in ckpt_model_02_run01/best/model-39800 >> ave validation accuracy 0.59857
# << best model so far is saved in ckpt_model_02_run01/best/model-39900 >> ave validation accuracy 0.60067
# << best model so far is saved in ckpt_model_02_run01/best/model-40000 >> ave validation accuracy 0.60452
# STEP   40000 END @ 2016-12-23 21:24:07.778813, training accuracy 0.60000, ave validation accuracy 0.60452
# << best model so far is saved in ckpt_model_02_run01/best/model-40100 >> ave validation accuracy 0.61335
# << best model so far is saved in ckpt_model_02_run01/best/model-40200 >> ave validation accuracy 0.61465
# << best model so far is saved in ckpt_model_02_run01/best/model-40300 >> ave validation accuracy 0.61962
# << best model so far is saved in ckpt_model_02_run01/best/model-40400 >> ave validation accuracy 0.61992
# << best model so far is saved in ckpt_model_02_run01/best/model-40500 >> ave validation accuracy 0.62106
# << best model so far is saved in ckpt_model_02_run01/best/model-40600 >> ave validation accuracy 0.62215
# << best model so far is saved in ckpt_model_02_run01/best/model-40700 >> ave validation accuracy 0.62412
# << best model so far is saved in ckpt_model_02_run01/best/model-40800 >> ave validation accuracy 0.62526
# STEP   41000 END @ 2016-12-23 21:25:11.001442, training accuracy 0.65000, ave validation accuracy 0.62407
# << best model so far is saved in ckpt_model_02_run01/best/model-41100 >> ave validation accuracy 0.62601
# << best model so far is saved in ckpt_model_02_run01/best/model-41200 >> ave validation accuracy 0.62787
# << best model so far is saved in ckpt_model_02_run01/best/model-41300 >> ave validation accuracy 0.62884
# << best model so far is saved in ckpt_model_02_run01/best/model-41400 >> ave validation accuracy 0.63272
# << best model so far is saved in ckpt_model_02_run01/best/model-41500 >> ave validation accuracy 0.63500
# << best model so far is saved in ckpt_model_02_run01/best/model-41600 >> ave validation accuracy 0.63734
# << best model so far is saved in ckpt_model_02_run01/best/model-41700 >> ave validation accuracy 0.63930
# << best model so far is saved in ckpt_model_02_run01/best/model-41800 >> ave validation accuracy 0.64254
# << best model so far is saved in ckpt_model_02_run01/best/model-41900 >> ave validation accuracy 0.64286
# << best model so far is saved in ckpt_model_02_run01/best/model-42000 >> ave validation accuracy 0.64622
# STEP   42000 END @ 2016-12-23 21:26:16.237412, training accuracy 0.68000, ave validation accuracy 0.64622
# << best model so far is saved in ckpt_model_02_run01/best/model-42100 >> ave validation accuracy 0.65061
# << best model so far is saved in ckpt_model_02_run01/best/model-42700 >> ave validation accuracy 0.65091
# << best model so far is saved in ckpt_model_02_run01/best/model-42800 >> ave validation accuracy 0.65126
# << best model so far is saved in ckpt_model_02_run01/best/model-43000 >> ave validation accuracy 0.65786
# STEP   43000 END @ 2016-12-23 21:27:12.823743, training accuracy 0.72000, ave validation accuracy 0.65786
# << best model so far is saved in ckpt_model_02_run01/best/model-43100 >> ave validation accuracy 0.65894
# << best model so far is saved in ckpt_model_02_run01/best/model-43200 >> ave validation accuracy 0.65942
# << best model so far is saved in ckpt_model_02_run01/best/model-43300 >> ave validation accuracy 0.66111
# << best model so far is saved in ckpt_model_02_run01/best/model-43400 >> ave validation accuracy 0.66165
# << best model so far is saved in ckpt_model_02_run01/best/model-43500 >> ave validation accuracy 0.66449
# << best model so far is saved in ckpt_model_02_run01/best/model-43600 >> ave validation accuracy 0.66451
# << best model so far is saved in ckpt_model_02_run01/best/model-43700 >> ave validation accuracy 0.66731
# << best model so far is saved in ckpt_model_02_run01/best/model-43800 >> ave validation accuracy 0.66865
# << best model so far is saved in ckpt_model_02_run01/best/model-43900 >> ave validation accuracy 0.66887
# << best model so far is saved in ckpt_model_02_run01/best/model-44000 >> ave validation accuracy 0.67125
# STEP   44000 END @ 2016-12-23 21:28:18.039650, training accuracy 0.72500, ave validation accuracy 0.67125
# << best model so far is saved in ckpt_model_02_run01/best/model-44100 >> ave validation accuracy 0.67187
# << best model so far is saved in ckpt_model_02_run01/best/model-44200 >> ave validation accuracy 0.67324
# << best model so far is saved in ckpt_model_02_run01/best/model-44300 >> ave validation accuracy 0.67525
# << best model so far is saved in ckpt_model_02_run01/best/model-44400 >> ave validation accuracy 0.67582
# << best model so far is saved in ckpt_model_02_run01/best/model-44500 >> ave validation accuracy 0.67831
# << best model so far is saved in ckpt_model_02_run01/best/model-44600 >> ave validation accuracy 0.67955
# << best model so far is saved in ckpt_model_02_run01/best/model-44700 >> ave validation accuracy 0.68144
# << best model so far is saved in ckpt_model_02_run01/best/model-44800 >> ave validation accuracy 0.68276
# << best model so far is saved in ckpt_model_02_run01/best/model-44900 >> ave validation accuracy 0.68394
# STEP   45000 END @ 2016-12-23 21:29:23.154646, training accuracy 0.71500, ave validation accuracy 0.68390
# << best model so far is saved in ckpt_model_02_run01/best/model-45100 >> ave validation accuracy 0.68561
# << best model so far is saved in ckpt_model_02_run01/best/model-45200 >> ave validation accuracy 0.68814
# STEP   46000 END @ 2016-12-23 21:30:17.765708, training accuracy 0.79000, ave validation accuracy 0.68716
# << best model so far is saved in ckpt_model_02_run01/best/model-46200 >> ave validation accuracy 0.68957
# << best model so far is saved in ckpt_model_02_run01/best/model-46800 >> ave validation accuracy 0.69049
# << best model so far is saved in ckpt_model_02_run01/best/model-46900 >> ave validation accuracy 0.69317
# << best model so far is saved in ckpt_model_02_run01/best/model-47000 >> ave validation accuracy 0.69414
# STEP   47000 END @ 2016-12-23 21:31:15.892353, training accuracy 0.78000, ave validation accuracy 0.69414
# << best model so far is saved in ckpt_model_02_run01/best/model-47100 >> ave validation accuracy 0.69605
# << best model so far is saved in ckpt_model_02_run01/best/model-47200 >> ave validation accuracy 0.69876
# << best model so far is saved in ckpt_model_02_run01/best/model-47300 >> ave validation accuracy 0.69961
# << best model so far is saved in ckpt_model_02_run01/best/model-47400 >> ave validation accuracy 0.70166
# << best model so far is saved in ckpt_model_02_run01/best/model-47700 >> ave validation accuracy 0.70234
# << best model so far is saved in ckpt_model_02_run01/best/model-47800 >> ave validation accuracy 0.70274
# << best model so far is saved in ckpt_model_02_run01/best/model-47900 >> ave validation accuracy 0.70679
# STEP   48000 END @ 2016-12-23 21:32:17.590821, training accuracy 0.80500, ave validation accuracy 0.70639
# << best model so far is saved in ckpt_model_02_run01/best/model-48100 >> ave validation accuracy 0.70754
# << best model so far is saved in ckpt_model_02_run01/best/model-48300 >> ave validation accuracy 0.70856
# << best model so far is saved in ckpt_model_02_run01/best/model-48500 >> ave validation accuracy 0.70909
# << best model so far is saved in ckpt_model_02_run01/best/model-48800 >> ave validation accuracy 0.70927
# STEP   49000 END @ 2016-12-23 21:33:15.684202, training accuracy 0.84500, ave validation accuracy 0.70894
# STEP   50000 END @ 2016-12-23 21:34:08.388894, training accuracy 0.79500, ave validation accuracy 0.70502
# << best model so far is saved in ckpt_model_02_run01/best/model-50300 >> ave validation accuracy 0.71109
# << best model so far is saved in ckpt_model_02_run01/best/model-50600 >> ave validation accuracy 0.71409
# << best model so far is saved in ckpt_model_02_run01/best/model-50700 >> ave validation accuracy 0.71419
# << best model so far is saved in ckpt_model_02_run01/best/model-50800 >> ave validation accuracy 0.71705
# << best model so far is saved in ckpt_model_02_run01/best/model-50900 >> ave validation accuracy 0.71819
# << best model so far is saved in ckpt_model_02_run01/best/model-51000 >> ave validation accuracy 0.72079
# STEP   51000 END @ 2016-12-23 21:35:08.420889, training accuracy 0.86500, ave validation accuracy 0.72079
# << best model so far is saved in ckpt_model_02_run01/best/model-51100 >> ave validation accuracy 0.72224
# << best model so far is saved in ckpt_model_02_run01/best/model-51200 >> ave validation accuracy 0.72462
# STEP   52000 END @ 2016-12-23 21:36:03.026666, training accuracy 0.87000, ave validation accuracy 0.72211
# << best model so far is saved in ckpt_model_02_run01/best/model-52200 >> ave validation accuracy 0.72710
# STEP   53000 END @ 2016-12-23 21:36:57.291163, training accuracy 0.90500, ave validation accuracy 0.72139
# << best model so far is saved in ckpt_model_02_run01/best/model-53300 >> ave validation accuracy 0.72760
# << best model so far is saved in ckpt_model_02_run01/best/model-53400 >> ave validation accuracy 0.73007
# << best model so far is saved in ckpt_model_02_run01/best/model-53500 >> ave validation accuracy 0.73130
# STEP   54000 END @ 2016-12-23 21:37:53.659727, training accuracy 0.91000, ave validation accuracy 0.72414
# STEP   55000 END @ 2016-12-23 21:38:46.184566, training accuracy 0.92500, ave validation accuracy 0.72831
# << best model so far is saved in ckpt_model_02_run01/best/model-55500 >> ave validation accuracy 0.73411
# << best model so far is saved in ckpt_model_02_run01/best/model-55600 >> ave validation accuracy 0.73504
# << best model so far is saved in ckpt_model_02_run01/best/model-55800 >> ave validation accuracy 0.73639
# << best model so far is saved in ckpt_model_02_run01/best/model-55900 >> ave validation accuracy 0.73682
# STEP   56000 END @ 2016-12-23 21:39:44.067172, training accuracy 0.94500, ave validation accuracy 0.73550
# << best model so far is saved in ckpt_model_02_run01/best/model-56100 >> ave validation accuracy 0.73692
# STEP   57000 END @ 2016-12-23 21:40:37.031265, training accuracy 0.97000, ave validation accuracy 0.72626
# STEP   58000 END @ 2016-12-23 21:41:29.711156, training accuracy 0.97000, ave validation accuracy 0.72941
# STEP   59000 END @ 2016-12-23 21:42:22.374649, training accuracy 0.96500, ave validation accuracy 0.73225
# STEP   60000 END @ 2016-12-23 21:43:14.983900, training accuracy 0.96500, ave validation accuracy 0.71802
# << best model so far is saved in ckpt_model_02_run01/best/model-60500 >> ave validation accuracy 0.73785
# << best model so far is saved in ckpt_model_02_run01/best/model-60900 >> ave validation accuracy 0.73880
# STEP   61000 END @ 2016-12-23 21:44:10.972669, training accuracy 0.99500, ave validation accuracy 0.73869
# << best model so far is saved in ckpt_model_02_run01/best/model-61200 >> ave validation accuracy 0.73880
# STEP   62000 END @ 2016-12-23 21:45:05.319186, training accuracy 1.00000, ave validation accuracy 0.71855
# << hourly save at ckpt_model_02_run01/hourly/model-62500 and pickle_model_02_run01 >>
# << best model so far is saved in ckpt_model_02_run01/best/model-62700 >> ave validation accuracy 0.73956
# << best model so far is saved in ckpt_model_02_run01/best/model-62800 >> ave validation accuracy 0.73989
# << best model so far is saved in ckpt_model_02_run01/best/model-62900 >> ave validation accuracy 0.74080
# STEP   63000 END @ 2016-12-23 21:46:02.095395, training accuracy 0.86500, ave validation accuracy 0.73309
# << best model so far is saved in ckpt_model_02_run01/best/model-63800 >> ave validation accuracy 0.74272
# << best model so far is saved in ckpt_model_02_run01/best/model-63900 >> ave validation accuracy 0.74300
# << best model so far is saved in ckpt_model_02_run01/best/model-64000 >> ave validation accuracy 0.74320
# STEP   64000 END @ 2016-12-23 21:46:58.389457, training accuracy 1.00000, ave validation accuracy 0.74320
# << best model so far is saved in ckpt_model_02_run01/best/model-64100 >> ave validation accuracy 0.74330
# << best model so far is saved in ckpt_model_02_run01/best/model-64400 >> ave validation accuracy 0.74337
# << best model so far is saved in ckpt_model_02_run01/best/model-64500 >> ave validation accuracy 0.74417
# STEP   65000 END @ 2016-12-23 21:47:55.770438, training accuracy 1.00000, ave validation accuracy 0.74415
# STEP   66000 END @ 2016-12-23 21:48:48.310538, training accuracy 1.00000, ave validation accuracy 0.73774
# STEP   67000 END @ 2016-12-23 21:49:40.969664, training accuracy 1.00000, ave validation accuracy 0.74358
# STEP   68000 END @ 2016-12-23 21:50:33.540764, training accuracy 1.00000, ave validation accuracy 0.74367
# STEP   69000 END @ 2016-12-23 21:51:26.093432, training accuracy 1.00000, ave validation accuracy 0.74232
# STEP   70000 END @ 2016-12-23 21:52:18.703063, training accuracy 1.00000, ave validation accuracy 0.74314
# STEP   71000 END @ 2016-12-23 21:53:11.210713, training accuracy 1.00000, ave validation accuracy 0.74309
# STEP   72000 END @ 2016-12-23 21:54:03.683027, training accuracy 1.00000, ave validation accuracy 0.74276
# STEP   73000 END @ 2016-12-23 21:54:56.270503, training accuracy 1.00000, ave validation accuracy 0.74291
# STEP   74000 END @ 2016-12-23 21:55:48.796460, training accuracy 1.00000, ave validation accuracy 0.74215
# STEP   75000 END @ 2016-12-23 21:56:41.337451, training accuracy 1.00000, ave validation accuracy 0.74262
# STEP   76000 END @ 2016-12-23 21:57:33.965223, training accuracy 1.00000, ave validation accuracy 0.74292
# STEP   77000 END @ 2016-12-23 21:58:26.589629, training accuracy 1.00000, ave validation accuracy 0.74271
# STEP   78000 END @ 2016-12-23 21:59:19.145228, training accuracy 1.00000, ave validation accuracy 0.74200
# STEP   79000 END @ 2016-12-23 22:00:11.619166, training accuracy 1.00000, ave validation accuracy 0.74254
# STEP   80000 END @ 2016-12-23 22:01:04.074630, training accuracy 1.00000, ave validation accuracy 0.74231
# STEP   81000 END @ 2016-12-23 22:01:56.518975, training accuracy 1.00000, ave validation accuracy 0.74251
# STEP   82000 END @ 2016-12-23 22:02:49.066209, training accuracy 1.00000, ave validation accuracy 0.74235
# STEP   83000 END @ 2016-12-23 22:03:41.629932, training accuracy 1.00000, ave validation accuracy 0.74246
# STEP   84000 END @ 2016-12-23 22:04:34.107212, training accuracy 1.00000, ave validation accuracy 0.74214
# STEP   85000 END @ 2016-12-23 22:05:26.650042, training accuracy 1.00000, ave validation accuracy 0.74236
# STEP   86000 END @ 2016-12-23 22:06:19.122061, training accuracy 1.00000, ave validation accuracy 0.74227
# STEP   87000 END @ 2016-12-23 22:07:11.758438, training accuracy 1.00000, ave validation accuracy 0.74242
# STEP   88000 END @ 2016-12-23 22:08:04.344043, training accuracy 1.00000, ave validation accuracy 0.74233
# STEP   89000 END @ 2016-12-23 22:08:56.846842, training accuracy 1.00000, ave validation accuracy 0.74236
# STEP   90000 END @ 2016-12-23 22:09:49.422279, training accuracy 1.00000, ave validation accuracy 0.74240
# STEP   91000 END @ 2016-12-23 22:10:41.961981, training accuracy 1.00000, ave validation accuracy 0.74245
# STEP   92000 END @ 2016-12-23 22:11:34.457553, training accuracy 1.00000, ave validation accuracy 0.74243
# STEP   93000 END @ 2016-12-23 22:12:26.929206, training accuracy 1.00000, ave validation accuracy 0.74216
# STEP   94000 END @ 2016-12-23 22:13:19.560099, training accuracy 1.00000, ave validation accuracy 0.74248
# STEP   95000 END @ 2016-12-23 22:14:11.987176, training accuracy 1.00000, ave validation accuracy 0.74246
# STEP   96000 END @ 2016-12-23 22:15:04.485984, training accuracy 1.00000, ave validation accuracy 0.74237
# STEP   97000 END @ 2016-12-23 22:15:56.918701, training accuracy 1.00000, ave validation accuracy 0.74221
# STEP   98000 END @ 2016-12-23 22:16:49.507918, training accuracy 1.00000, ave validation accuracy 0.74231
# STEP   99000 END @ 2016-12-23 22:17:42.113107, training accuracy 1.00000, ave validation accuracy 0.74251
# STEP  100000 END @ 2016-12-23 22:18:34.666202, training accuracy 1.00000, ave validation accuracy 0.74259
# STEP  101000 END @ 2016-12-23 22:19:27.116161, training accuracy 1.00000, ave validation accuracy 0.74252
# STEP  102000 END @ 2016-12-23 22:20:19.725811, training accuracy 1.00000, ave validation accuracy 0.74237
# STEP  103000 END @ 2016-12-23 22:21:12.287754, training accuracy 1.00000, ave validation accuracy 0.74235
# STEP  104000 END @ 2016-12-23 22:22:04.887224, training accuracy 1.00000, ave validation accuracy 0.74251
# STEP  105000 END @ 2016-12-23 22:22:57.552443, training accuracy 1.00000, ave validation accuracy 0.74270
# STEP  106000 END @ 2016-12-23 22:23:50.029961, training accuracy 1.00000, ave validation accuracy 0.74262
# STEP  107000 END @ 2016-12-23 22:24:42.596313, training accuracy 1.00000, ave validation accuracy 0.74251
# STEP  108000 END @ 2016-12-23 22:25:35.155584, training accuracy 1.00000, ave validation accuracy 0.74272
# STEP  109000 END @ 2016-12-23 22:26:27.628902, training accuracy 1.00000, ave validation accuracy 0.74273
# STEP  110000 END @ 2016-12-23 22:27:20.199167, training accuracy 1.00000, ave validation accuracy 0.74258
# STEP  111000 END @ 2016-12-23 22:28:12.659823, training accuracy 1.00000, ave validation accuracy 0.74273
# STEP  112000 END @ 2016-12-23 22:29:05.312268, training accuracy 1.00000, ave validation accuracy 0.74252
# STEP  113000 END @ 2016-12-23 22:29:57.915865, training accuracy 1.00000, ave validation accuracy 0.74243
# STEP  114000 END @ 2016-12-23 22:30:50.386299, training accuracy 1.00000, ave validation accuracy 0.74257
# STEP  115000 END @ 2016-12-23 22:31:42.888507, training accuracy 1.00000, ave validation accuracy 0.74270
# STEP  116000 END @ 2016-12-23 22:32:35.439666, training accuracy 1.00000, ave validation accuracy 0.74241
# STEP  117000 END @ 2016-12-23 22:33:27.997675, training accuracy 1.00000, ave validation accuracy 0.74256
# STEP  118000 END @ 2016-12-23 22:34:20.614365, training accuracy 1.00000, ave validation accuracy 0.74246
# STEP  119000 END @ 2016-12-23 22:35:13.266944, training accuracy 1.00000, ave validation accuracy 0.74270
# STEP  120000 END @ 2016-12-23 22:36:05.806599, training accuracy 1.00000, ave validation accuracy 0.74269
# STEP  121000 END @ 2016-12-23 22:36:58.388963, training accuracy 1.00000, ave validation accuracy 0.74271
# STEP  122000 END @ 2016-12-23 22:37:50.823482, training accuracy 1.00000, ave validation accuracy 0.74256
# STEP  123000 END @ 2016-12-23 22:38:43.432096, training accuracy 1.00000, ave validation accuracy 0.74247
# STEP  124000 END @ 2016-12-23 22:39:35.979141, training accuracy 1.00000, ave validation accuracy 0.74232
# STEP  125000 END @ 2016-12-23 22:40:28.618039, training accuracy 1.00000, ave validation accuracy 0.74244
# STEP  126000 END @ 2016-12-23 22:41:21.251679, training accuracy 1.00000, ave validation accuracy 0.74221
# STEP  127000 END @ 2016-12-23 22:42:13.805723, training accuracy 1.00000, ave validation accuracy 0.74216
# STEP  128000 END @ 2016-12-23 22:43:06.322088, training accuracy 1.00000, ave validation accuracy 0.74229
# STEP  129000 END @ 2016-12-23 22:43:58.761766, training accuracy 1.00000, ave validation accuracy 0.74216
# STEP  130000 END @ 2016-12-23 22:44:51.309071, training accuracy 1.00000, ave validation accuracy 0.74230
# << hourly save at ckpt_model_02_run01/hourly/model-130800 and pickle_model_02_run01 >>
# STEP  131000 END @ 2016-12-23 22:45:44.134884, training accuracy 1.00000, ave validation accuracy 0.74247
# STEP  132000 END @ 2016-12-23 22:46:36.642558, training accuracy 1.00000, ave validation accuracy 0.74238
# STEP  133000 END @ 2016-12-23 22:47:29.169680, training accuracy 1.00000, ave validation accuracy 0.74214
# STEP  134000 END @ 2016-12-23 22:48:21.609737, training accuracy 1.00000, ave validation accuracy 0.74251
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-feafc4fc8124> in <module>()
#       1 #Train the model
# ----> 2 train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#
# /home/kumiko/cifar10/helper_functions.pyc in train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#     251             _, summary = sess.run([graph_variables['optimizer'], graph_variables['summarizer']],
#     252                                   feed_dict={graph_variables['data']: batch_data, graph_variables['labels']: batch_labels,
# --> 253                                              graph_variables['keep_prob']: accuracy_log['variables']['dropout_train_keep_prob'], graph_variables['is_training']: True})
#     254
#     255             if i % accuracy_log['variables']['log_every'] == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Test accuracy
test_accuracy(graph_variables, accuracy_log, test_data, test_labels)
# Out:
# << test accuracy 0.74070 >>
