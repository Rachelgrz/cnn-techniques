# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from helper_functions import *

# %%
#Continueing training?
continued = False
checkpoint_file_to_use = None #Example: 'ckpt_model_01_run01/hourly/model-9350'

#If training from step 0
#############################
naming = 'model_03_run01'
#############################
variables = {
    'modify_images': False,
    'crop_images': False,
    'enlarge_images': False,
    'before_flatten_image_side_size': 4, #Need to calculate
    'first_hidden_layer_features': 384,
    'weights_stddev': 0.015,
    'biases_initial': 0.1,
    'dropout_train_keep_prob': 1.0,
    'learning_rate_initial': 0.01,
    'learning_rate_decay_steps': int(10000000),
    'learning_rate_decay': 1.0,
    'start_step_early_stopping': 150000,
    'early_stopping_patience': 0.1,
    'batch_size': 200,
    'max_steps': 100000000,
    'average_n_validation_accuracy': 8
}

# %%
#Create accuracy_log to pickle and directories for TensorBoard and checkpoint
accuracy_log = prep_accuracy_log(continued, checkpoint_file_to_use, naming, variables)

# %%
#Get data and labels
(train_data, validation_data, test_data, train_labels, validation_labels, test_labels) = get_data_and_labels(accuracy_log)

# %%
#Build a model
crop_images = accuracy_log['variables']['crop_images']
modify_images = accuracy_log['variables']['modify_images']
weights_stddev = accuracy_log['variables']['weights_stddev']
biases_initial = accuracy_log['variables']['biases_initial']
input_image_side_size = accuracy_log['variables']['input_image_side_size']
crop_to_side_size = accuracy_log['variables']['crop_to_side_size']
before_flatten_image_side_size = accuracy_log['variables']['before_flatten_image_side_size']
first_hidden_layer_features = accuracy_log['variables']['first_hidden_layer_features']
learning_rate_initial = accuracy_log['variables']['learning_rate_initial']
learning_rate_decay_steps = accuracy_log['variables']['learning_rate_decay_steps']
learning_rate_decay = accuracy_log['variables']['learning_rate_decay']

graph = tf.Graph()
with graph.as_default():
    global_step = tf.Variable(0, trainable=False)
    is_training = tf.placeholder(tf.bool)
    keep_prob = tf.placeholder(tf.float32)

    data = tf.placeholder(tf.float32, [None, input_image_side_size, input_image_side_size, 3])
    labels = tf.placeholder(tf.float32, [None, 10])
    
    if crop_images & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    elif (not crop_images) & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify_no_crop(data), lambda: tf.identity(data))
    elif crop_images & (not modify_images):
        data_v2 = tf.cond(is_training, lambda: random_crop(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    else:
        data_v2 = tf.identity(data)
        
    W_conv1 = weight_variable([3, 3, 3, 64], weights_stddev, 'W_conv1')
    b_conv1 = bias_variable(biases_initial, [64], 'b_conv1')
    conv1 = conv2d(data_v2, W_conv1) + b_conv1
    conv1_relu = tf.nn.relu(conv1)
    pool1 = max_pool_3x3_stride2(conv1_relu)
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    W_conv2 = weight_variable([3, 3, 64, 64], weights_stddev, 'W_conv2')
    b_conv2 = bias_variable(biases_initial, [64], 'b_conv2')
    conv2 = conv2d(norm1, W_conv2) + b_conv2
    conv2_relu = tf.nn.relu(conv2)
    pool2 = max_pool_3x3_stride2(conv2_relu)
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)
    
    W_conv3 = weight_variable([3, 3, 64, 128], weights_stddev, 'W_conv3')
    b_conv3 = bias_variable(biases_initial, [128], 'b_conv3')
    conv3 = conv2d(norm2, W_conv3) + b_conv3
    conv3_relu = tf.nn.relu(conv3)
    pool3 = max_pool_3x3_stride2(conv3_relu)
    norm3 = tf.nn.lrn(pool3, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)
    
    norm3_flat = tf.reshape(norm3, [-1, before_flatten_image_side_size*before_flatten_image_side_size*128])

    W_fc1 = weight_variable([before_flatten_image_side_size*before_flatten_image_side_size*128, first_hidden_layer_features], weights_stddev, 'W_fc1')
    b_fc1 = bias_variable(biases_initial, [first_hidden_layer_features], 'b_fc1')
    fc1 = tf.matmul(norm3_flat, W_fc1) + b_fc1
    fc1_relu = tf.nn.relu(fc1)
    
    W_fc2 = weight_variable([first_hidden_layer_features, int(first_hidden_layer_features/2)], weights_stddev, 'W_fc2')
    b_fc2 = bias_variable(biases_initial, [first_hidden_layer_features/2], 'b_fc2')
    fc2 = tf.matmul(fc1_relu, W_fc2) + b_fc2
    fc2_relu = tf.nn.relu(fc2)
    
    W_fc3 = weight_variable([int(first_hidden_layer_features/2), 10], weights_stddev, 'W_fc3')
    b_fc3 = bias_variable(biases_initial, [10], 'b_fc3')
    logits = tf.matmul(fc2_relu, W_fc3) + b_fc3

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))
    
    learning_rate = tf.train.exponential_decay(learning_rate_initial, global_step, learning_rate_decay_steps, 
                                               learning_rate_decay, staircase=True)
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    tf.summary.scalar('loss', loss)
    tf.summary.scalar('learning_rate', learning_rate)
    tf.summary.scalar('training_accuracy', accuracy)
    
    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name, var)
    
    summarizer = tf.summary.merge_all()
    
graph_variables = {'graph': graph, 
                   'optimizer': optimizer, 
                   'summarizer': summarizer, 
                   'data': data, 
                   'labels': labels, 
                   'keep_prob': keep_prob, 
                   'is_training': is_training, 
                   'correct_prediction': correct_prediction,
                   'accuracy': accuracy}

# %%
#Train the model
train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
# Out:
# TRAINING   START @ 2016-12-23 22:49:24.954304
# << best model so far is saved in ckpt_model_03_run01/best/model-0 >> ave validation accuracy 0.09970
# STEP       0 END @ 2016-12-23 22:49:30.333739, training accuracy 0.14500, ave validation accuracy 0.09970
# STEP    1000 END @ 2016-12-23 22:50:27.477381, training accuracy 0.11000, ave validation accuracy 0.09695
# STEP    2000 END @ 2016-12-23 22:51:24.582015, training accuracy 0.06500, ave validation accuracy 0.09551
# STEP    3000 END @ 2016-12-23 22:52:21.789537, training accuracy 0.10500, ave validation accuracy 0.09586
# STEP    4000 END @ 2016-12-23 22:53:18.943973, training accuracy 0.13500, ave validation accuracy 0.09551
# STEP    5000 END @ 2016-12-23 22:54:15.995964, training accuracy 0.10000, ave validation accuracy 0.09551
# STEP    6000 END @ 2016-12-23 22:55:13.070396, training accuracy 0.09500, ave validation accuracy 0.09551
# STEP    7000 END @ 2016-12-23 22:56:10.199752, training accuracy 0.10500, ave validation accuracy 0.09555
# STEP    8000 END @ 2016-12-23 22:57:07.219859, training accuracy 0.09000, ave validation accuracy 0.09551
# STEP    9000 END @ 2016-12-23 22:58:04.198691, training accuracy 0.14000, ave validation accuracy 0.09551
# << best model so far is saved in ckpt_model_03_run01/best/model-9900 >> ave validation accuracy 0.10154
# << best model so far is saved in ckpt_model_03_run01/best/model-10000 >> ave validation accuracy 0.10154
# STEP   10000 END @ 2016-12-23 22:59:03.138487, training accuracy 0.12000, ave validation accuracy 0.10154
# STEP   11000 END @ 2016-12-23 23:00:00.017536, training accuracy 0.12500, ave validation accuracy 0.09555
# STEP   12000 END @ 2016-12-23 23:00:56.869902, training accuracy 0.09500, ave validation accuracy 0.09551
# STEP   13000 END @ 2016-12-23 23:01:53.857633, training accuracy 0.10000, ave validation accuracy 0.09597
# STEP   14000 END @ 2016-12-23 23:02:50.789227, training accuracy 0.06000, ave validation accuracy 0.09520
# STEP   15000 END @ 2016-12-23 23:03:47.766736, training accuracy 0.09500, ave validation accuracy 0.09520
# STEP   16000 END @ 2016-12-23 23:04:44.461393, training accuracy 0.08000, ave validation accuracy 0.09586
# STEP   17000 END @ 2016-12-23 23:05:41.227663, training accuracy 0.14000, ave validation accuracy 0.09586
# STEP   18000 END @ 2016-12-23 23:06:38.207600, training accuracy 0.12000, ave validation accuracy 0.09551
# STEP   19000 END @ 2016-12-23 23:07:35.179677, training accuracy 0.10000, ave validation accuracy 0.09680
# STEP   20000 END @ 2016-12-23 23:08:32.058892, training accuracy 0.11500, ave validation accuracy 0.09551
# << best model so far is saved in ckpt_model_03_run01/best/model-20300 >> ave validation accuracy 0.10339
# << best model so far is saved in ckpt_model_03_run01/best/model-20400 >> ave validation accuracy 0.10339
# << best model so far is saved in ckpt_model_03_run01/best/model-21000 >> ave validation accuracy 0.10339
# STEP   21000 END @ 2016-12-23 23:09:32.764872, training accuracy 0.10000, ave validation accuracy 0.10339
# STEP   22000 END @ 2016-12-23 23:10:29.814127, training accuracy 0.09000, ave validation accuracy 0.09681
# STEP   23000 END @ 2016-12-23 23:11:26.662576, training accuracy 0.10000, ave validation accuracy 0.10005
# << best model so far is saved in ckpt_model_03_run01/best/model-23600 >> ave validation accuracy 0.10467
# << best model so far is saved in ckpt_model_03_run01/best/model-23700 >> ave validation accuracy 0.10885
# << best model so far is saved in ckpt_model_03_run01/best/model-23900 >> ave validation accuracy 0.11605
# << best model so far is saved in ckpt_model_03_run01/best/model-24000 >> ave validation accuracy 0.11699
# STEP   24000 END @ 2016-12-23 23:12:29.136356, training accuracy 0.12500, ave validation accuracy 0.11699
# << best model so far is saved in ckpt_model_03_run01/best/model-24100 >> ave validation accuracy 0.12221
# << best model so far is saved in ckpt_model_03_run01/best/model-24200 >> ave validation accuracy 0.12635
# << best model so far is saved in ckpt_model_03_run01/best/model-24300 >> ave validation accuracy 0.13147
# << best model so far is saved in ckpt_model_03_run01/best/model-24400 >> ave validation accuracy 0.13310
# << best model so far is saved in ckpt_model_03_run01/best/model-24500 >> ave validation accuracy 0.13871
# << best model so far is saved in ckpt_model_03_run01/best/model-24600 >> ave validation accuracy 0.14604
# << best model so far is saved in ckpt_model_03_run01/best/model-24800 >> ave validation accuracy 0.15309
# << best model so far is saved in ckpt_model_03_run01/best/model-24900 >> ave validation accuracy 0.15581
# << best model so far is saved in ckpt_model_03_run01/best/model-25000 >> ave validation accuracy 0.16142
# STEP   25000 END @ 2016-12-23 23:13:38.666274, training accuracy 0.16000, ave validation accuracy 0.16142
# << best model so far is saved in ckpt_model_03_run01/best/model-25100 >> ave validation accuracy 0.16441
# << best model so far is saved in ckpt_model_03_run01/best/model-25200 >> ave validation accuracy 0.16839
# << best model so far is saved in ckpt_model_03_run01/best/model-25300 >> ave validation accuracy 0.16927
# << best model so far is saved in ckpt_model_03_run01/best/model-25400 >> ave validation accuracy 0.17127
# << best model so far is saved in ckpt_model_03_run01/best/model-25500 >> ave validation accuracy 0.17435
# << best model so far is saved in ckpt_model_03_run01/best/model-25700 >> ave validation accuracy 0.17609
# STEP   26000 END @ 2016-12-23 23:14:42.996625, training accuracy 0.14500, ave validation accuracy 0.17496
# << best model so far is saved in ckpt_model_03_run01/best/model-26300 >> ave validation accuracy 0.17621
# << best model so far is saved in ckpt_model_03_run01/best/model-26400 >> ave validation accuracy 0.17934
# << best model so far is saved in ckpt_model_03_run01/best/model-26500 >> ave validation accuracy 0.18339
# << best model so far is saved in ckpt_model_03_run01/best/model-26600 >> ave validation accuracy 0.18751
# << best model so far is saved in ckpt_model_03_run01/best/model-26700 >> ave validation accuracy 0.19302
# << best model so far is saved in ckpt_model_03_run01/best/model-26800 >> ave validation accuracy 0.19994
# << best model so far is saved in ckpt_model_03_run01/best/model-26900 >> ave validation accuracy 0.20644
# << best model so far is saved in ckpt_model_03_run01/best/model-27000 >> ave validation accuracy 0.21247
# STEP   27000 END @ 2016-12-23 23:15:50.823894, training accuracy 0.23000, ave validation accuracy 0.21247
# << best model so far is saved in ckpt_model_03_run01/best/model-27100 >> ave validation accuracy 0.21882
# << best model so far is saved in ckpt_model_03_run01/best/model-27200 >> ave validation accuracy 0.22416
# << best model so far is saved in ckpt_model_03_run01/best/model-27300 >> ave validation accuracy 0.22769
# << best model so far is saved in ckpt_model_03_run01/best/model-27400 >> ave validation accuracy 0.23299
# << best model so far is saved in ckpt_model_03_run01/best/model-27500 >> ave validation accuracy 0.23671
# << best model so far is saved in ckpt_model_03_run01/best/model-27600 >> ave validation accuracy 0.23935
# << best model so far is saved in ckpt_model_03_run01/best/model-27700 >> ave validation accuracy 0.24299
# << best model so far is saved in ckpt_model_03_run01/best/model-27800 >> ave validation accuracy 0.24742
# << best model so far is saved in ckpt_model_03_run01/best/model-27900 >> ave validation accuracy 0.24876
# << best model so far is saved in ckpt_model_03_run01/best/model-28000 >> ave validation accuracy 0.25171
# STEP   28000 END @ 2016-12-23 23:17:00.889361, training accuracy 0.24500, ave validation accuracy 0.25171
# << best model so far is saved in ckpt_model_03_run01/best/model-28100 >> ave validation accuracy 0.25540
# << best model so far is saved in ckpt_model_03_run01/best/model-28200 >> ave validation accuracy 0.25756
# << best model so far is saved in ckpt_model_03_run01/best/model-28300 >> ave validation accuracy 0.26039
# << best model so far is saved in ckpt_model_03_run01/best/model-28400 >> ave validation accuracy 0.26325
# << best model so far is saved in ckpt_model_03_run01/best/model-28500 >> ave validation accuracy 0.26395
# << best model so far is saved in ckpt_model_03_run01/best/model-28600 >> ave validation accuracy 0.26590
# << best model so far is saved in ckpt_model_03_run01/best/model-28700 >> ave validation accuracy 0.26766
# << best model so far is saved in ckpt_model_03_run01/best/model-28800 >> ave validation accuracy 0.26936
# STEP   29000 END @ 2016-12-23 23:18:07.307450, training accuracy 0.22000, ave validation accuracy 0.26315
# << best model so far is saved in ckpt_model_03_run01/best/model-29300 >> ave validation accuracy 0.27162
# << best model so far is saved in ckpt_model_03_run01/best/model-29400 >> ave validation accuracy 0.27365
# << best model so far is saved in ckpt_model_03_run01/best/model-29500 >> ave validation accuracy 0.27491
# << best model so far is saved in ckpt_model_03_run01/best/model-29700 >> ave validation accuracy 0.28595
# << best model so far is saved in ckpt_model_03_run01/best/model-29800 >> ave validation accuracy 0.28970
# << best model so far is saved in ckpt_model_03_run01/best/model-29900 >> ave validation accuracy 0.29056
# << best model so far is saved in ckpt_model_03_run01/best/model-30000 >> ave validation accuracy 0.29486
# STEP   30000 END @ 2016-12-23 23:19:13.482385, training accuracy 0.34500, ave validation accuracy 0.29486
# << best model so far is saved in ckpt_model_03_run01/best/model-30100 >> ave validation accuracy 0.29884
# << best model so far is saved in ckpt_model_03_run01/best/model-30200 >> ave validation accuracy 0.30386
# << best model so far is saved in ckpt_model_03_run01/best/model-30300 >> ave validation accuracy 0.31116
# << best model so far is saved in ckpt_model_03_run01/best/model-30400 >> ave validation accuracy 0.31922
# << best model so far is saved in ckpt_model_03_run01/best/model-30600 >> ave validation accuracy 0.32214
# << best model so far is saved in ckpt_model_03_run01/best/model-30700 >> ave validation accuracy 0.32749
# << best model so far is saved in ckpt_model_03_run01/best/model-30800 >> ave validation accuracy 0.33181
# << best model so far is saved in ckpt_model_03_run01/best/model-30900 >> ave validation accuracy 0.33330
# << best model so far is saved in ckpt_model_03_run01/best/model-31000 >> ave validation accuracy 0.33640
# STEP   31000 END @ 2016-12-23 23:20:22.854611, training accuracy 0.37500, ave validation accuracy 0.33640
# << best model so far is saved in ckpt_model_03_run01/best/model-31100 >> ave validation accuracy 0.33795
# << best model so far is saved in ckpt_model_03_run01/best/model-31300 >> ave validation accuracy 0.34471
# << best model so far is saved in ckpt_model_03_run01/best/model-31400 >> ave validation accuracy 0.34812
# << best model so far is saved in ckpt_model_03_run01/best/model-31500 >> ave validation accuracy 0.35045
# << best model so far is saved in ckpt_model_03_run01/best/model-31600 >> ave validation accuracy 0.35480
# << best model so far is saved in ckpt_model_03_run01/best/model-31700 >> ave validation accuracy 0.36169
# << best model so far is saved in ckpt_model_03_run01/best/model-31900 >> ave validation accuracy 0.36176
# << best model so far is saved in ckpt_model_03_run01/best/model-32000 >> ave validation accuracy 0.37016
# STEP   32000 END @ 2016-12-23 23:21:29.358359, training accuracy 0.37000, ave validation accuracy 0.37016
# << best model so far is saved in ckpt_model_03_run01/best/model-32100 >> ave validation accuracy 0.37274
# << best model so far is saved in ckpt_model_03_run01/best/model-32200 >> ave validation accuracy 0.37609
# << best model so far is saved in ckpt_model_03_run01/best/model-32300 >> ave validation accuracy 0.38130
# << best model so far is saved in ckpt_model_03_run01/best/model-32400 >> ave validation accuracy 0.38365
# << best model so far is saved in ckpt_model_03_run01/best/model-32500 >> ave validation accuracy 0.38441
# << best model so far is saved in ckpt_model_03_run01/best/model-32600 >> ave validation accuracy 0.38987
# << best model so far is saved in ckpt_model_03_run01/best/model-32700 >> ave validation accuracy 0.39664
# << best model so far is saved in ckpt_model_03_run01/best/model-32800 >> ave validation accuracy 0.40312
# << best model so far is saved in ckpt_model_03_run01/best/model-32900 >> ave validation accuracy 0.40616
# << best model so far is saved in ckpt_model_03_run01/best/model-33000 >> ave validation accuracy 0.40791
# STEP   33000 END @ 2016-12-23 23:22:38.983446, training accuracy 0.48000, ave validation accuracy 0.40791
# << best model so far is saved in ckpt_model_03_run01/best/model-33100 >> ave validation accuracy 0.41169
# << best model so far is saved in ckpt_model_03_run01/best/model-33200 >> ave validation accuracy 0.41540
# << best model so far is saved in ckpt_model_03_run01/best/model-33300 >> ave validation accuracy 0.41925
# << best model so far is saved in ckpt_model_03_run01/best/model-33400 >> ave validation accuracy 0.42541
# << best model so far is saved in ckpt_model_03_run01/best/model-33500 >> ave validation accuracy 0.42897
# << best model so far is saved in ckpt_model_03_run01/best/model-33600 >> ave validation accuracy 0.43205
# << best model so far is saved in ckpt_model_03_run01/best/model-33700 >> ave validation accuracy 0.43564
# << best model so far is saved in ckpt_model_03_run01/best/model-33800 >> ave validation accuracy 0.43967
# << best model so far is saved in ckpt_model_03_run01/best/model-33900 >> ave validation accuracy 0.44042
# << best model so far is saved in ckpt_model_03_run01/best/model-34000 >> ave validation accuracy 0.44259
# STEP   34000 END @ 2016-12-23 23:23:50.301921, training accuracy 0.52500, ave validation accuracy 0.44259
# << best model so far is saved in ckpt_model_03_run01/best/model-34100 >> ave validation accuracy 0.44415
# << best model so far is saved in ckpt_model_03_run01/best/model-34200 >> ave validation accuracy 0.44581
# << best model so far is saved in ckpt_model_03_run01/best/model-34300 >> ave validation accuracy 0.44846
# << best model so far is saved in ckpt_model_03_run01/best/model-34400 >> ave validation accuracy 0.45090
# << best model so far is saved in ckpt_model_03_run01/best/model-34500 >> ave validation accuracy 0.45212
# << best model so far is saved in ckpt_model_03_run01/best/model-34600 >> ave validation accuracy 0.45471
# << best model so far is saved in ckpt_model_03_run01/best/model-34700 >> ave validation accuracy 0.45856
# << best model so far is saved in ckpt_model_03_run01/best/model-34800 >> ave validation accuracy 0.46054
# << best model so far is saved in ckpt_model_03_run01/best/model-34900 >> ave validation accuracy 0.46462
# << best model so far is saved in ckpt_model_03_run01/best/model-35000 >> ave validation accuracy 0.46730
# STEP   35000 END @ 2016-12-23 23:25:00.049665, training accuracy 0.51500, ave validation accuracy 0.46730
# << best model so far is saved in ckpt_model_03_run01/best/model-35100 >> ave validation accuracy 0.46987
# << best model so far is saved in ckpt_model_03_run01/best/model-35200 >> ave validation accuracy 0.47136
# << best model so far is saved in ckpt_model_03_run01/best/model-35300 >> ave validation accuracy 0.47386
# << best model so far is saved in ckpt_model_03_run01/best/model-35400 >> ave validation accuracy 0.47660
# << best model so far is saved in ckpt_model_03_run01/best/model-35500 >> ave validation accuracy 0.47827
# << best model so far is saved in ckpt_model_03_run01/best/model-35600 >> ave validation accuracy 0.48237
# << best model so far is saved in ckpt_model_03_run01/best/model-35700 >> ave validation accuracy 0.48592
# << best model so far is saved in ckpt_model_03_run01/best/model-35800 >> ave validation accuracy 0.48779
# << best model so far is saved in ckpt_model_03_run01/best/model-35900 >> ave validation accuracy 0.48975
# << best model so far is saved in ckpt_model_03_run01/best/model-36000 >> ave validation accuracy 0.49227
# STEP   36000 END @ 2016-12-23 23:26:09.737610, training accuracy 0.55500, ave validation accuracy 0.49227
# << best model so far is saved in ckpt_model_03_run01/best/model-36100 >> ave validation accuracy 0.49471
# << best model so far is saved in ckpt_model_03_run01/best/model-36200 >> ave validation accuracy 0.49702
# << best model so far is saved in ckpt_model_03_run01/best/model-36300 >> ave validation accuracy 0.49832
# << best model so far is saved in ckpt_model_03_run01/best/model-36400 >> ave validation accuracy 0.49931
# << best model so far is saved in ckpt_model_03_run01/best/model-36600 >> ave validation accuracy 0.50221
# << best model so far is saved in ckpt_model_03_run01/best/model-36700 >> ave validation accuracy 0.50530
# << best model so far is saved in ckpt_model_03_run01/best/model-36800 >> ave validation accuracy 0.50987
# << best model so far is saved in ckpt_model_03_run01/best/model-36900 >> ave validation accuracy 0.51182
# STEP   37000 END @ 2016-12-23 23:27:16.270130, training accuracy 0.53500, ave validation accuracy 0.51171
# << best model so far is saved in ckpt_model_03_run01/best/model-37100 >> ave validation accuracy 0.51546
# << best model so far is saved in ckpt_model_03_run01/best/model-37200 >> ave validation accuracy 0.51732
# << best model so far is saved in ckpt_model_03_run01/best/model-37300 >> ave validation accuracy 0.52322
# << best model so far is saved in ckpt_model_03_run01/best/model-37400 >> ave validation accuracy 0.52495
# << best model so far is saved in ckpt_model_03_run01/best/model-37500 >> ave validation accuracy 0.52720
# << best model so far is saved in ckpt_model_03_run01/best/model-37600 >> ave validation accuracy 0.52830
# << best model so far is saved in ckpt_model_03_run01/best/model-37700 >> ave validation accuracy 0.53149
# << best model so far is saved in ckpt_model_03_run01/best/model-37800 >> ave validation accuracy 0.53537
# << best model so far is saved in ckpt_model_03_run01/best/model-37900 >> ave validation accuracy 0.53759
# << best model so far is saved in ckpt_model_03_run01/best/model-38000 >> ave validation accuracy 0.54099
# STEP   38000 END @ 2016-12-23 23:28:27.339546, training accuracy 0.57500, ave validation accuracy 0.54099
# << best model so far is saved in ckpt_model_03_run01/best/model-38400 >> ave validation accuracy 0.54236
# << best model so far is saved in ckpt_model_03_run01/best/model-38500 >> ave validation accuracy 0.54455
# << best model so far is saved in ckpt_model_03_run01/best/model-38600 >> ave validation accuracy 0.54816
# << best model so far is saved in ckpt_model_03_run01/best/model-38700 >> ave validation accuracy 0.55144
# << best model so far is saved in ckpt_model_03_run01/best/model-38900 >> ave validation accuracy 0.55707
# << best model so far is saved in ckpt_model_03_run01/best/model-39000 >> ave validation accuracy 0.55724
# STEP   39000 END @ 2016-12-23 23:29:31.650293, training accuracy 0.59000, ave validation accuracy 0.55724
# << best model so far is saved in ckpt_model_03_run01/best/model-39100 >> ave validation accuracy 0.55997
# << best model so far is saved in ckpt_model_03_run01/best/model-39200 >> ave validation accuracy 0.56199
# << best model so far is saved in ckpt_model_03_run01/best/model-39300 >> ave validation accuracy 0.56549
# << best model so far is saved in ckpt_model_03_run01/best/model-39400 >> ave validation accuracy 0.56692
# << best model so far is saved in ckpt_model_03_run01/best/model-39500 >> ave validation accuracy 0.56824
# << best model so far is saved in ckpt_model_03_run01/best/model-39600 >> ave validation accuracy 0.57345
# << best model so far is saved in ckpt_model_03_run01/best/model-39700 >> ave validation accuracy 0.57471
# << best model so far is saved in ckpt_model_03_run01/best/model-39800 >> ave validation accuracy 0.58151
# << best model so far is saved in ckpt_model_03_run01/best/model-40000 >> ave validation accuracy 0.58247
# STEP   40000 END @ 2016-12-23 23:30:39.850986, training accuracy 0.59000, ave validation accuracy 0.58247
# << best model so far is saved in ckpt_model_03_run01/best/model-40100 >> ave validation accuracy 0.58366
# << best model so far is saved in ckpt_model_03_run01/best/model-40300 >> ave validation accuracy 0.58672
# << best model so far is saved in ckpt_model_03_run01/best/model-40400 >> ave validation accuracy 0.58889
# << best model so far is saved in ckpt_model_03_run01/best/model-40500 >> ave validation accuracy 0.58922
# << best model so far is saved in ckpt_model_03_run01/best/model-40700 >> ave validation accuracy 0.59427
# << best model so far is saved in ckpt_model_03_run01/best/model-40800 >> ave validation accuracy 0.59662
# << best model so far is saved in ckpt_model_03_run01/best/model-40900 >> ave validation accuracy 0.59672
# << best model so far is saved in ckpt_model_03_run01/best/model-41000 >> ave validation accuracy 0.59937
# STEP   41000 END @ 2016-12-23 23:31:47.649945, training accuracy 0.61000, ave validation accuracy 0.59937
# << best model so far is saved in ckpt_model_03_run01/best/model-41100 >> ave validation accuracy 0.60001
# << best model so far is saved in ckpt_model_03_run01/best/model-41200 >> ave validation accuracy 0.60299
# << best model so far is saved in ckpt_model_03_run01/best/model-41300 >> ave validation accuracy 0.60799
# << best model so far is saved in ckpt_model_03_run01/best/model-41400 >> ave validation accuracy 0.60951
# << best model so far is saved in ckpt_model_03_run01/best/model-41500 >> ave validation accuracy 0.61042
# << best model so far is saved in ckpt_model_03_run01/best/model-41700 >> ave validation accuracy 0.61416
# << best model so far is saved in ckpt_model_03_run01/best/model-41800 >> ave validation accuracy 0.61610
# << best model so far is saved in ckpt_model_03_run01/best/model-41900 >> ave validation accuracy 0.61976
# STEP   42000 END @ 2016-12-23 23:32:55.691680, training accuracy 0.62500, ave validation accuracy 0.61955
# << best model so far is saved in ckpt_model_03_run01/best/model-42200 >> ave validation accuracy 0.61989
# << best model so far is saved in ckpt_model_03_run01/best/model-42300 >> ave validation accuracy 0.62155
# << best model so far is saved in ckpt_model_03_run01/best/model-42400 >> ave validation accuracy 0.62469
# << best model so far is saved in ckpt_model_03_run01/best/model-42500 >> ave validation accuracy 0.62680
# << best model so far is saved in ckpt_model_03_run01/best/model-42600 >> ave validation accuracy 0.62762
# << best model so far is saved in ckpt_model_03_run01/best/model-42700 >> ave validation accuracy 0.62866
# << best model so far is saved in ckpt_model_03_run01/best/model-42800 >> ave validation accuracy 0.63011
# << best model so far is saved in ckpt_model_03_run01/best/model-42900 >> ave validation accuracy 0.63712
# << best model so far is saved in ckpt_model_03_run01/best/model-43000 >> ave validation accuracy 0.63834
# STEP   43000 END @ 2016-12-23 23:34:03.884179, training accuracy 0.68000, ave validation accuracy 0.63834
# << best model so far is saved in ckpt_model_03_run01/best/model-43100 >> ave validation accuracy 0.63880
# << best model so far is saved in ckpt_model_03_run01/best/model-43200 >> ave validation accuracy 0.64154
# << best model so far is saved in ckpt_model_03_run01/best/model-43300 >> ave validation accuracy 0.64229
# << best model so far is saved in ckpt_model_03_run01/best/model-43400 >> ave validation accuracy 0.64670
# << best model so far is saved in ckpt_model_03_run01/best/model-43500 >> ave validation accuracy 0.64826
# << best model so far is saved in ckpt_model_03_run01/best/model-43600 >> ave validation accuracy 0.65092
# << best model so far is saved in ckpt_model_03_run01/best/model-43700 >> ave validation accuracy 0.65097
# << best model so far is saved in ckpt_model_03_run01/best/model-43800 >> ave validation accuracy 0.65299
# << best model so far is saved in ckpt_model_03_run01/best/model-43900 >> ave validation accuracy 0.65467
# << best model so far is saved in ckpt_model_03_run01/best/model-44000 >> ave validation accuracy 0.65494
# STEP   44000 END @ 2016-12-23 23:35:13.949467, training accuracy 0.69500, ave validation accuracy 0.65494
# << best model so far is saved in ckpt_model_03_run01/best/model-44100 >> ave validation accuracy 0.65685
# << best model so far is saved in ckpt_model_03_run01/best/model-44300 >> ave validation accuracy 0.65839
# << best model so far is saved in ckpt_model_03_run01/best/model-44400 >> ave validation accuracy 0.66072
# << best model so far is saved in ckpt_model_03_run01/best/model-44500 >> ave validation accuracy 0.66371
# << best model so far is saved in ckpt_model_03_run01/best/model-44600 >> ave validation accuracy 0.66645
# << best model so far is saved in ckpt_model_03_run01/best/model-44700 >> ave validation accuracy 0.66881
# << best model so far is saved in ckpt_model_03_run01/best/model-45000 >> ave validation accuracy 0.67039
# STEP   45000 END @ 2016-12-23 23:36:20.187659, training accuracy 0.79500, ave validation accuracy 0.67039
# << best model so far is saved in ckpt_model_03_run01/best/model-45100 >> ave validation accuracy 0.67172
# << best model so far is saved in ckpt_model_03_run01/best/model-45200 >> ave validation accuracy 0.67294
# << best model so far is saved in ckpt_model_03_run01/best/model-45300 >> ave validation accuracy 0.67302
# << best model so far is saved in ckpt_model_03_run01/best/model-45500 >> ave validation accuracy 0.67527
# << best model so far is saved in ckpt_model_03_run01/best/model-45600 >> ave validation accuracy 0.68040
# << best model so far is saved in ckpt_model_03_run01/best/model-45700 >> ave validation accuracy 0.68284
# << best model so far is saved in ckpt_model_03_run01/best/model-45800 >> ave validation accuracy 0.68359
# << best model so far is saved in ckpt_model_03_run01/best/model-45900 >> ave validation accuracy 0.68505
# << best model so far is saved in ckpt_model_03_run01/best/model-46000 >> ave validation accuracy 0.68624
# STEP   46000 END @ 2016-12-23 23:37:29.852714, training accuracy 0.76000, ave validation accuracy 0.68624
# << best model so far is saved in ckpt_model_03_run01/best/model-46100 >> ave validation accuracy 0.68885
# << best model so far is saved in ckpt_model_03_run01/best/model-46200 >> ave validation accuracy 0.69169
# << best model so far is saved in ckpt_model_03_run01/best/model-46300 >> ave validation accuracy 0.69304
# << best model so far is saved in ckpt_model_03_run01/best/model-46400 >> ave validation accuracy 0.69415
# << best model so far is saved in ckpt_model_03_run01/best/model-46500 >> ave validation accuracy 0.69854
# STEP   47000 END @ 2016-12-23 23:38:32.710874, training accuracy 0.75500, ave validation accuracy 0.69531
# << best model so far is saved in ckpt_model_03_run01/best/model-47600 >> ave validation accuracy 0.69895
# STEP   48000 END @ 2016-12-23 23:39:31.226883, training accuracy 0.81500, ave validation accuracy 0.69771
# << best model so far is saved in ckpt_model_03_run01/best/model-48200 >> ave validation accuracy 0.69910
# << best model so far is saved in ckpt_model_03_run01/best/model-48300 >> ave validation accuracy 0.70465
# << best model so far is saved in ckpt_model_03_run01/best/model-48500 >> ave validation accuracy 0.70646
# << best model so far is saved in ckpt_model_03_run01/best/model-48600 >> ave validation accuracy 0.70909
# << best model so far is saved in ckpt_model_03_run01/best/model-48700 >> ave validation accuracy 0.71051
# << best model so far is saved in ckpt_model_03_run01/best/model-48800 >> ave validation accuracy 0.71297
# << best model so far is saved in ckpt_model_03_run01/best/model-49000 >> ave validation accuracy 0.71334
# STEP   49000 END @ 2016-12-23 23:40:37.417103, training accuracy 0.79000, ave validation accuracy 0.71334
# << best model so far is saved in ckpt_model_03_run01/best/model-49200 >> ave validation accuracy 0.71406
# << best model so far is saved in ckpt_model_03_run01/best/model-49700 >> ave validation accuracy 0.71576
# << best model so far is saved in ckpt_model_03_run01/best/model-49800 >> ave validation accuracy 0.71784
# STEP   50000 END @ 2016-12-23 23:41:38.085500, training accuracy 0.81000, ave validation accuracy 0.71636
# << best model so far is saved in ckpt_model_03_run01/best/model-50100 >> ave validation accuracy 0.71924
# << best model so far is saved in ckpt_model_03_run01/best/model-50200 >> ave validation accuracy 0.71964
# << best model so far is saved in ckpt_model_03_run01/best/model-50300 >> ave validation accuracy 0.72051
# << best model so far is saved in ckpt_model_03_run01/best/model-50400 >> ave validation accuracy 0.72092
# << best model so far is saved in ckpt_model_03_run01/best/model-50500 >> ave validation accuracy 0.72114
# STEP   51000 END @ 2016-12-23 23:42:42.160701, training accuracy 0.81500, ave validation accuracy 0.71835
# << best model so far is saved in ckpt_model_03_run01/best/model-51200 >> ave validation accuracy 0.72154
# << best model so far is saved in ckpt_model_03_run01/best/model-51400 >> ave validation accuracy 0.72226
# << best model so far is saved in ckpt_model_03_run01/best/model-51500 >> ave validation accuracy 0.72454
# << best model so far is saved in ckpt_model_03_run01/best/model-51600 >> ave validation accuracy 0.72670
# << best model so far is saved in ckpt_model_03_run01/best/model-51700 >> ave validation accuracy 0.72786
# << best model so far is saved in ckpt_model_03_run01/best/model-51800 >> ave validation accuracy 0.73137
# STEP   52000 END @ 2016-12-23 23:43:46.430876, training accuracy 0.88000, ave validation accuracy 0.73085
# STEP   53000 END @ 2016-12-23 23:44:43.441900, training accuracy 0.89000, ave validation accuracy 0.72661
# STEP   54000 END @ 2016-12-23 23:45:40.623736, training accuracy 0.80000, ave validation accuracy 0.72362
# << best model so far is saved in ckpt_model_03_run01/best/model-54800 >> ave validation accuracy 0.73195
# << best model so far is saved in ckpt_model_03_run01/best/model-54900 >> ave validation accuracy 0.73284
# STEP   55000 END @ 2016-12-23 23:46:39.779494, training accuracy 0.91500, ave validation accuracy 0.73262
# << best model so far is saved in ckpt_model_03_run01/best/model-55100 >> ave validation accuracy 0.73637
# << best model so far is saved in ckpt_model_03_run01/best/model-55200 >> ave validation accuracy 0.74144
# << best model so far is saved in ckpt_model_03_run01/best/model-55300 >> ave validation accuracy 0.74156
# << best model so far is saved in ckpt_model_03_run01/best/model-55400 >> ave validation accuracy 0.74192
# << best model so far is saved in ckpt_model_03_run01/best/model-55500 >> ave validation accuracy 0.74226
# STEP   56000 END @ 2016-12-23 23:47:44.119026, training accuracy 0.89500, ave validation accuracy 0.74016
# STEP   57000 END @ 2016-12-23 23:48:40.856776, training accuracy 0.95500, ave validation accuracy 0.73507
# << hourly save at ckpt_model_03_run01/hourly/model-57800 and pickle_model_03_run01 >>
# STEP   58000 END @ 2016-12-23 23:49:39.767474, training accuracy 0.97500, ave validation accuracy 0.73889
# STEP   59000 END @ 2016-12-23 23:50:36.886032, training accuracy 0.97500, ave validation accuracy 0.73992
# STEP   60000 END @ 2016-12-23 23:51:33.864005, training accuracy 0.97000, ave validation accuracy 0.73884
# << best model so far is saved in ckpt_model_03_run01/best/model-60300 >> ave validation accuracy 0.74321
# << best model so far is saved in ckpt_model_03_run01/best/model-60400 >> ave validation accuracy 0.74530
# STEP   61000 END @ 2016-12-23 23:52:32.960683, training accuracy 1.00000, ave validation accuracy 0.74161
# STEP   62000 END @ 2016-12-23 23:53:29.956225, training accuracy 0.99500, ave validation accuracy 0.73850
# << best model so far is saved in ckpt_model_03_run01/best/model-62200 >> ave validation accuracy 0.74645
# << best model so far is saved in ckpt_model_03_run01/best/model-62300 >> ave validation accuracy 0.74901
# << best model so far is saved in ckpt_model_03_run01/best/model-62400 >> ave validation accuracy 0.74925
# << best model so far is saved in ckpt_model_03_run01/best/model-62500 >> ave validation accuracy 0.74951
# << best model so far is saved in ckpt_model_03_run01/best/model-62600 >> ave validation accuracy 0.75002
# << best model so far is saved in ckpt_model_03_run01/best/model-62900 >> ave validation accuracy 0.75023
# STEP   63000 END @ 2016-12-23 23:54:34.428619, training accuracy 1.00000, ave validation accuracy 0.75005
# << best model so far is saved in ckpt_model_03_run01/best/model-63200 >> ave validation accuracy 0.75071
# << best model so far is saved in ckpt_model_03_run01/best/model-63300 >> ave validation accuracy 0.75155
# STEP   64000 END @ 2016-12-23 23:55:34.947166, training accuracy 1.00000, ave validation accuracy 0.74551
# STEP   65000 END @ 2016-12-23 23:56:32.003065, training accuracy 1.00000, ave validation accuracy 0.74966
# << best model so far is saved in ckpt_model_03_run01/best/model-66000 >> ave validation accuracy 0.75282
# STEP   66000 END @ 2016-12-23 23:57:30.761678, training accuracy 1.00000, ave validation accuracy 0.75282
# << best model so far is saved in ckpt_model_03_run01/best/model-66100 >> ave validation accuracy 0.75314
# << best model so far is saved in ckpt_model_03_run01/best/model-67000 >> ave validation accuracy 0.75341
# STEP   67000 END @ 2016-12-23 23:58:29.743028, training accuracy 1.00000, ave validation accuracy 0.75341
# << best model so far is saved in ckpt_model_03_run01/best/model-67100 >> ave validation accuracy 0.75409
# << best model so far is saved in ckpt_model_03_run01/best/model-67500 >> ave validation accuracy 0.75419
# << best model so far is saved in ckpt_model_03_run01/best/model-67600 >> ave validation accuracy 0.75429
# << best model so far is saved in ckpt_model_03_run01/best/model-67700 >> ave validation accuracy 0.75455
# STEP   68000 END @ 2016-12-23 23:59:32.349148, training accuracy 1.00000, ave validation accuracy 0.75400
# STEP   69000 END @ 2016-12-24 00:00:29.265319, training accuracy 1.00000, ave validation accuracy 0.75344
# STEP   70000 END @ 2016-12-24 00:01:26.192350, training accuracy 1.00000, ave validation accuracy 0.75359
# STEP   71000 END @ 2016-12-24 00:02:23.161348, training accuracy 1.00000, ave validation accuracy 0.75331
# STEP   72000 END @ 2016-12-24 00:03:20.023474, training accuracy 1.00000, ave validation accuracy 0.75206
# STEP   73000 END @ 2016-12-24 00:04:17.013615, training accuracy 1.00000, ave validation accuracy 0.75236
# STEP   74000 END @ 2016-12-24 00:05:14.036510, training accuracy 1.00000, ave validation accuracy 0.75207
# STEP   75000 END @ 2016-12-24 00:06:10.938666, training accuracy 1.00000, ave validation accuracy 0.75203
# STEP   76000 END @ 2016-12-24 00:07:07.928196, training accuracy 1.00000, ave validation accuracy 0.75199
# STEP   77000 END @ 2016-12-24 00:08:04.863660, training accuracy 1.00000, ave validation accuracy 0.75206
# STEP   78000 END @ 2016-12-24 00:09:01.704325, training accuracy 1.00000, ave validation accuracy 0.75161
# STEP   79000 END @ 2016-12-24 00:09:58.703217, training accuracy 1.00000, ave validation accuracy 0.75154
# STEP   80000 END @ 2016-12-24 00:10:55.680595, training accuracy 1.00000, ave validation accuracy 0.75197
# STEP   81000 END @ 2016-12-24 00:11:52.547968, training accuracy 1.00000, ave validation accuracy 0.75173
# STEP   82000 END @ 2016-12-24 00:12:49.352054, training accuracy 1.00000, ave validation accuracy 0.75164
# STEP   83000 END @ 2016-12-24 00:13:46.169240, training accuracy 1.00000, ave validation accuracy 0.75150
# STEP   84000 END @ 2016-12-24 00:14:43.163548, training accuracy 1.00000, ave validation accuracy 0.75172
# STEP   85000 END @ 2016-12-24 00:15:40.143205, training accuracy 1.00000, ave validation accuracy 0.75150
# STEP   86000 END @ 2016-12-24 00:16:37.075899, training accuracy 1.00000, ave validation accuracy 0.75175
# STEP   87000 END @ 2016-12-24 00:17:33.988809, training accuracy 1.00000, ave validation accuracy 0.75169
# STEP   88000 END @ 2016-12-24 00:18:30.897344, training accuracy 1.00000, ave validation accuracy 0.75107
# STEP   89000 END @ 2016-12-24 00:19:27.864486, training accuracy 1.00000, ave validation accuracy 0.75144
# STEP   90000 END @ 2016-12-24 00:20:24.751724, training accuracy 1.00000, ave validation accuracy 0.75134
# STEP   91000 END @ 2016-12-24 00:21:21.887696, training accuracy 1.00000, ave validation accuracy 0.75170
# STEP   92000 END @ 2016-12-24 00:22:18.837305, training accuracy 1.00000, ave validation accuracy 0.75109
# STEP   93000 END @ 2016-12-24 00:23:15.628569, training accuracy 1.00000, ave validation accuracy 0.75140
# STEP   94000 END @ 2016-12-24 00:24:12.660190, training accuracy 1.00000, ave validation accuracy 0.75099
# STEP   95000 END @ 2016-12-24 00:25:09.564647, training accuracy 1.00000, ave validation accuracy 0.75125
# STEP   96000 END @ 2016-12-24 00:26:06.537170, training accuracy 1.00000, ave validation accuracy 0.75172
# STEP   97000 END @ 2016-12-24 00:27:03.526985, training accuracy 1.00000, ave validation accuracy 0.75115
# STEP   98000 END @ 2016-12-24 00:28:00.517202, training accuracy 1.00000, ave validation accuracy 0.75164
# STEP   99000 END @ 2016-12-24 00:28:57.679166, training accuracy 1.00000, ave validation accuracy 0.75122
# STEP  100000 END @ 2016-12-24 00:29:54.757897, training accuracy 1.00000, ave validation accuracy 0.75151
# STEP  101000 END @ 2016-12-24 00:30:51.694132, training accuracy 1.00000, ave validation accuracy 0.75147
# STEP  102000 END @ 2016-12-24 00:31:48.622079, training accuracy 1.00000, ave validation accuracy 0.75110
# STEP  103000 END @ 2016-12-24 00:32:45.527608, training accuracy 1.00000, ave validation accuracy 0.75140
# STEP  104000 END @ 2016-12-24 00:33:42.623582, training accuracy 1.00000, ave validation accuracy 0.75117
# STEP  105000 END @ 2016-12-24 00:34:39.347950, training accuracy 1.00000, ave validation accuracy 0.75123
# STEP  106000 END @ 2016-12-24 00:35:36.334377, training accuracy 1.00000, ave validation accuracy 0.75130
# STEP  107000 END @ 2016-12-24 00:36:33.406645, training accuracy 1.00000, ave validation accuracy 0.75149
# STEP  108000 END @ 2016-12-24 00:37:30.372887, training accuracy 1.00000, ave validation accuracy 0.75142
# STEP  109000 END @ 2016-12-24 00:38:27.330832, training accuracy 1.00000, ave validation accuracy 0.75100
# STEP  110000 END @ 2016-12-24 00:39:24.274896, training accuracy 1.00000, ave validation accuracy 0.75095
# STEP  111000 END @ 2016-12-24 00:40:21.398028, training accuracy 1.00000, ave validation accuracy 0.75112
# STEP  112000 END @ 2016-12-24 00:41:18.390700, training accuracy 1.00000, ave validation accuracy 0.75129
# STEP  113000 END @ 2016-12-24 00:42:15.465302, training accuracy 1.00000, ave validation accuracy 0.75107
# STEP  114000 END @ 2016-12-24 00:43:12.505171, training accuracy 1.00000, ave validation accuracy 0.75120
# STEP  115000 END @ 2016-12-24 00:44:09.580613, training accuracy 1.00000, ave validation accuracy 0.75128
# STEP  116000 END @ 2016-12-24 00:45:06.596469, training accuracy 1.00000, ave validation accuracy 0.75112
# STEP  117000 END @ 2016-12-24 00:46:03.665938, training accuracy 1.00000, ave validation accuracy 0.75084
# STEP  118000 END @ 2016-12-24 00:47:00.636799, training accuracy 1.00000, ave validation accuracy 0.75129
# STEP  119000 END @ 2016-12-24 00:47:57.690371, training accuracy 1.00000, ave validation accuracy 0.75104
# STEP  120000 END @ 2016-12-24 00:48:54.678540, training accuracy 1.00000, ave validation accuracy 0.75098
# << hourly save at ckpt_model_03_run01/hourly/model-120600 and pickle_model_03_run01 >>
# STEP  121000 END @ 2016-12-24 00:49:53.276531, training accuracy 1.00000, ave validation accuracy 0.75094
# STEP  122000 END @ 2016-12-24 00:50:50.160985, training accuracy 1.00000, ave validation accuracy 0.75085
# STEP  123000 END @ 2016-12-24 00:51:46.974111, training accuracy 1.00000, ave validation accuracy 0.75084
# STEP  124000 END @ 2016-12-24 00:52:44.010259, training accuracy 1.00000, ave validation accuracy 0.75111
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-feafc4fc8124> in <module>()
#       1 #Train the model
# ----> 2 train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#
# /home/kumiko/cifar10/helper_functions.pyc in train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#     251             _, summary = sess.run([graph_variables['optimizer'], graph_variables['summarizer']],
#     252                                   feed_dict={graph_variables['data']: batch_data, graph_variables['labels']: batch_labels,
# --> 253                                              graph_variables['keep_prob']: accuracy_log['variables']['dropout_train_keep_prob'], graph_variables['is_training']: True})
#     254
#     255             if i % accuracy_log['variables']['log_every'] == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Test accuracy
test_accuracy(graph_variables, accuracy_log, test_data, test_labels)
# Out:
# << test accuracy 0.74510 >>
