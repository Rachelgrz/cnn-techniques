# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from helper_functions import *

# %%
#Continueing training?
continued = False
checkpoint_file_to_use = None #Example: 'ckpt_model_01_run01/hourly/model-9350'

#If training from step 0
#############################
naming = 'model_08_run01'
#############################
variables = {
    'modify_images': True,
    'crop_images': False,
    'enlarge_images': True,
    'before_flatten_image_side_size': 4, #Need to calculate
    'first_hidden_layer_features': 384,
    'weights_stddev': 0.015,
    'biases_initial': 0.1,
    'dropout_train_keep_prob': 0.5,
    'learning_rate_initial': 0.1,
    'learning_rate_decay_steps': int(10000000),
    'learning_rate_decay': 1.0,
    'start_step_early_stopping': 150000,
    'early_stopping_patience': 0.1,
    'batch_size': 200,
    'max_steps': 100000000,
    'average_n_validation_accuracy': 8
}

# %%
#Create accuracy_log to pickle and directories for TensorBoard and checkpoint
accuracy_log = prep_accuracy_log(continued, checkpoint_file_to_use, naming, variables)

# %%
#Get data and labels
(train_data, validation_data, test_data, train_labels, validation_labels, test_labels) = get_data_and_labels(accuracy_log)

# %%
#Build a model
crop_images = accuracy_log['variables']['crop_images']
modify_images = accuracy_log['variables']['modify_images']
weights_stddev = accuracy_log['variables']['weights_stddev']
biases_initial = accuracy_log['variables']['biases_initial']
input_image_side_size = accuracy_log['variables']['input_image_side_size']
crop_to_side_size = accuracy_log['variables']['crop_to_side_size']
before_flatten_image_side_size = accuracy_log['variables']['before_flatten_image_side_size']
first_hidden_layer_features = accuracy_log['variables']['first_hidden_layer_features']
learning_rate_initial = accuracy_log['variables']['learning_rate_initial']
learning_rate_decay_steps = accuracy_log['variables']['learning_rate_decay_steps']
learning_rate_decay = accuracy_log['variables']['learning_rate_decay']

graph = tf.Graph()
with graph.as_default():
    global_step = tf.Variable(0, trainable=False)
    is_training = tf.placeholder(tf.bool)
    keep_prob = tf.placeholder(tf.float32)

    data = tf.placeholder(tf.float32, [None, input_image_side_size, input_image_side_size, 3])
    labels = tf.placeholder(tf.float32, [None, 10])

    if crop_images & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    elif (not crop_images) & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify_no_crop(data), lambda: tf.identity(data))
    elif crop_images & (not modify_images):
        data_v2 = tf.cond(is_training, lambda: random_crop(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    else:
        data_v2 = tf.identity(data)

    data_v2 = batch_normalize(data_v2, is_training=is_training, global_step=global_step, scope='bn_data_v2')
    W_conv1 = weight_variable([3, 3, 3, 64], weights_stddev, 'W_conv1')
    b_conv1 = bias_variable(biases_initial, [64], 'b_conv1')
    conv1 = conv2d(data_v2, W_conv1) + b_conv1
    conv1_relu = tf.nn.relu(conv1)
    pool1 = max_pool_3x3_stride2(conv1_relu)
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm1 = batch_normalize(norm1, is_training=is_training, global_step=global_step, scope='bn_norm1')
    W_conv2 = weight_variable([3, 3, 64, 64], weights_stddev, 'W_conv2')
    b_conv2 = bias_variable(biases_initial, [64], 'b_conv2')
    conv2 = conv2d(norm1, W_conv2) + b_conv2
    conv2_relu = tf.nn.relu(conv2)
    pool2 = max_pool_3x3_stride2(conv2_relu)
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm2 = batch_normalize(norm2, is_training=is_training, global_step=global_step, scope='bn_norm2')
    W_conv3 = weight_variable([3, 3, 64, 128], weights_stddev, 'W_conv3')
    b_conv3 = bias_variable(biases_initial, [128], 'b_conv3')
    conv3 = conv2d(norm2, W_conv3) + b_conv3
    conv3_relu = tf.nn.relu(conv3)
    pool3 = max_pool_3x3_stride2(conv3_relu)
    norm3 = tf.nn.lrn(pool3, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm3 = batch_normalize(norm3, is_training=is_training, global_step=global_step, scope='bn_norm3')
    W_conv4 = weight_variable([3, 3, 128, 128], weights_stddev, 'W_conv4')
    b_conv4 = bias_variable(biases_initial, [128], 'b_conv4')
    conv4 = conv2d(norm3, W_conv4) + b_conv4
    conv4_relu = tf.nn.relu(conv4)
    pool4 = max_pool_3x3_stride2(conv4_relu)
    norm4 = tf.nn.lrn(pool4, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm4_flat = tf.reshape(norm4, [-1, before_flatten_image_side_size*before_flatten_image_side_size*128])

    norm4_flat = batch_normalize(norm4_flat, is_training=is_training, global_step=global_step, scope='bn_norm4_flat')
    norm4_flat_drop = tf.nn.dropout(norm4_flat, keep_prob)
    W_fc1 = weight_variable([before_flatten_image_side_size*before_flatten_image_side_size*128, first_hidden_layer_features], weights_stddev, 'W_fc1')
    b_fc1 = bias_variable(biases_initial, [first_hidden_layer_features], 'b_fc1')
    fc1 = tf.matmul(norm4_flat_drop, W_fc1) + b_fc1
    fc1_relu = tf.nn.relu(fc1)

    fc1_relu = batch_normalize(fc1_relu, is_training=is_training, global_step=global_step, scope='bn_fc1_relu')    
    fc1_relu_drop = tf.nn.dropout(fc1_relu, keep_prob)
    W_fc2 = weight_variable([first_hidden_layer_features, int(first_hidden_layer_features/2)], weights_stddev, 'W_fc2')
    b_fc2 = bias_variable(biases_initial, [first_hidden_layer_features/2], 'b_fc2')
    fc2 = tf.matmul(fc1_relu_drop, W_fc2) + b_fc2
    fc2_relu = tf.nn.relu(fc2)

    fc2_relu = batch_normalize(fc2_relu, is_training=is_training, global_step=global_step, scope='bn_fc2_relu')
    fc2_relu_drop = tf.nn.dropout(fc2_relu, keep_prob)
    W_fc3 = weight_variable([int(first_hidden_layer_features/2), 10], weights_stddev, 'W_fc3')
    b_fc3 = bias_variable(biases_initial, [10], 'b_fc3')
    logits = tf.matmul(fc2_relu_drop, W_fc3) + b_fc3

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))

    learning_rate = tf.train.exponential_decay(learning_rate_initial, global_step, learning_rate_decay_steps, 
                                               learning_rate_decay, staircase=True)

    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    tf.summary.scalar('loss', loss)
    tf.summary.scalar('learning_rate', learning_rate)
    tf.summary.scalar('training_accuracy', accuracy)

    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name, var)

    summarizer = tf.summary.merge_all()
    
graph_variables = {'graph': graph, 
                   'optimizer': optimizer, 
                   'summarizer': summarizer, 
                   'data': data, 
                   'labels': labels, 
                   'keep_prob': keep_prob, 
                   'is_training': is_training, 
                   'correct_prediction': correct_prediction,
                   'accuracy': accuracy}

# %%
#Train the model
train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
# Out:
# TRAINING   START @ 2016-12-27 17:41:45.966771
# << best model so far is saved in ckpt_model_08_run01/best/model-0 >> ave validation accuracy 0.10140
# STEP       0 END @ 2016-12-27 17:41:58.581995, training accuracy 0.10000, ave validation accuracy 0.10140
# << best model so far is saved in ckpt_model_08_run01/best/model-100 >> ave validation accuracy 0.10145
# << best model so far is saved in ckpt_model_08_run01/best/model-300 >> ave validation accuracy 0.11673
# << best model so far is saved in ckpt_model_08_run01/best/model-400 >> ave validation accuracy 0.13236
# << best model so far is saved in ckpt_model_08_run01/best/model-600 >> ave validation accuracy 0.13401
# << best model so far is saved in ckpt_model_08_run01/best/model-700 >> ave validation accuracy 0.14630
# << best model so far is saved in ckpt_model_08_run01/best/model-800 >> ave validation accuracy 0.14813
# << best model so far is saved in ckpt_model_08_run01/best/model-900 >> ave validation accuracy 0.15373
# << best model so far is saved in ckpt_model_08_run01/best/model-1000 >> ave validation accuracy 0.16030
# STEP    1000 END @ 2016-12-27 17:45:49.729717, training accuracy 0.14500, ave validation accuracy 0.16030
# << best model so far is saved in ckpt_model_08_run01/best/model-1100 >> ave validation accuracy 0.16435
# << best model so far is saved in ckpt_model_08_run01/best/model-1200 >> ave validation accuracy 0.17055
# << best model so far is saved in ckpt_model_08_run01/best/model-1300 >> ave validation accuracy 0.18926
# << best model so far is saved in ckpt_model_08_run01/best/model-1400 >> ave validation accuracy 0.19176
# << best model so far is saved in ckpt_model_08_run01/best/model-1500 >> ave validation accuracy 0.21122
# << best model so far is saved in ckpt_model_08_run01/best/model-1600 >> ave validation accuracy 0.25340
# << best model so far is saved in ckpt_model_08_run01/best/model-1700 >> ave validation accuracy 0.29321
# << best model so far is saved in ckpt_model_08_run01/best/model-1800 >> ave validation accuracy 0.34169
# << best model so far is saved in ckpt_model_08_run01/best/model-1900 >> ave validation accuracy 0.38994
# << best model so far is saved in ckpt_model_08_run01/best/model-2000 >> ave validation accuracy 0.44281
# STEP    2000 END @ 2016-12-27 17:49:55.497456, training accuracy 0.73500, ave validation accuracy 0.44281
# << best model so far is saved in ckpt_model_08_run01/best/model-2100 >> ave validation accuracy 0.50119
# << best model so far is saved in ckpt_model_08_run01/best/model-2200 >> ave validation accuracy 0.56551
# << best model so far is saved in ckpt_model_08_run01/best/model-2300 >> ave validation accuracy 0.60446
# << best model so far is saved in ckpt_model_08_run01/best/model-2400 >> ave validation accuracy 0.63886
# << best model so far is saved in ckpt_model_08_run01/best/model-2500 >> ave validation accuracy 0.67471
# << best model so far is saved in ckpt_model_08_run01/best/model-2600 >> ave validation accuracy 0.70483
# << best model so far is saved in ckpt_model_08_run01/best/model-2700 >> ave validation accuracy 0.72951
# << best model so far is saved in ckpt_model_08_run01/best/model-2800 >> ave validation accuracy 0.74544
# << best model so far is saved in ckpt_model_08_run01/best/model-2900 >> ave validation accuracy 0.75467
# << best model so far is saved in ckpt_model_08_run01/best/model-3000 >> ave validation accuracy 0.76513
# STEP    3000 END @ 2016-12-27 17:54:00.460442, training accuracy 0.87500, ave validation accuracy 0.76513
# << best model so far is saved in ckpt_model_08_run01/best/model-3100 >> ave validation accuracy 0.77744
# << best model so far is saved in ckpt_model_08_run01/best/model-3200 >> ave validation accuracy 0.78663
# << best model so far is saved in ckpt_model_08_run01/best/model-3300 >> ave validation accuracy 0.79396
# << best model so far is saved in ckpt_model_08_run01/best/model-3400 >> ave validation accuracy 0.79806
# << best model so far is saved in ckpt_model_08_run01/best/model-3500 >> ave validation accuracy 0.80214
# << best model so far is saved in ckpt_model_08_run01/best/model-3600 >> ave validation accuracy 0.80409
# << best model so far is saved in ckpt_model_08_run01/best/model-3700 >> ave validation accuracy 0.80681
# << best model so far is saved in ckpt_model_08_run01/best/model-3800 >> ave validation accuracy 0.80970
# << best model so far is saved in ckpt_model_08_run01/best/model-3900 >> ave validation accuracy 0.81175
# << best model so far is saved in ckpt_model_08_run01/best/model-4000 >> ave validation accuracy 0.81347
# STEP    4000 END @ 2016-12-27 17:58:05.264914, training accuracy 0.89000, ave validation accuracy 0.81347
# << best model so far is saved in ckpt_model_08_run01/best/model-4100 >> ave validation accuracy 0.81409
# << best model so far is saved in ckpt_model_08_run01/best/model-4200 >> ave validation accuracy 0.81522
# << best model so far is saved in ckpt_model_08_run01/best/model-4300 >> ave validation accuracy 0.81698
# << best model so far is saved in ckpt_model_08_run01/best/model-4400 >> ave validation accuracy 0.81754
# << best model so far is saved in ckpt_model_08_run01/best/model-4500 >> ave validation accuracy 0.81840
# << best model so far is saved in ckpt_model_08_run01/best/model-4600 >> ave validation accuracy 0.81922
# << best model so far is saved in ckpt_model_08_run01/best/model-4700 >> ave validation accuracy 0.82055
# << best model so far is saved in ckpt_model_08_run01/best/model-4800 >> ave validation accuracy 0.82211
# << best model so far is saved in ckpt_model_08_run01/best/model-4900 >> ave validation accuracy 0.82393
# << best model so far is saved in ckpt_model_08_run01/best/model-5000 >> ave validation accuracy 0.82539
# STEP    5000 END @ 2016-12-27 18:02:09.697917, training accuracy 0.90500, ave validation accuracy 0.82539
# << best model so far is saved in ckpt_model_08_run01/best/model-5100 >> ave validation accuracy 0.82573
# << best model so far is saved in ckpt_model_08_run01/best/model-5200 >> ave validation accuracy 0.82816
# << best model so far is saved in ckpt_model_08_run01/best/model-5300 >> ave validation accuracy 0.83010
# << best model so far is saved in ckpt_model_08_run01/best/model-5400 >> ave validation accuracy 0.83060
# << best model so far is saved in ckpt_model_08_run01/best/model-5500 >> ave validation accuracy 0.83139
# << best model so far is saved in ckpt_model_08_run01/best/model-5600 >> ave validation accuracy 0.83175
# << best model so far is saved in ckpt_model_08_run01/best/model-5700 >> ave validation accuracy 0.83246
# << best model so far is saved in ckpt_model_08_run01/best/model-5800 >> ave validation accuracy 0.83274
# << best model so far is saved in ckpt_model_08_run01/best/model-5900 >> ave validation accuracy 0.83346
# << best model so far is saved in ckpt_model_08_run01/best/model-6000 >> ave validation accuracy 0.83398
# STEP    6000 END @ 2016-12-27 18:06:12.507780, training accuracy 0.96000, ave validation accuracy 0.83398
# << best model so far is saved in ckpt_model_08_run01/best/model-6100 >> ave validation accuracy 0.83495
# << best model so far is saved in ckpt_model_08_run01/best/model-6200 >> ave validation accuracy 0.83735
# << best model so far is saved in ckpt_model_08_run01/best/model-6300 >> ave validation accuracy 0.83796
# << best model so far is saved in ckpt_model_08_run01/best/model-6400 >> ave validation accuracy 0.83920
# << best model so far is saved in ckpt_model_08_run01/best/model-6500 >> ave validation accuracy 0.83941
# << best model so far is saved in ckpt_model_08_run01/best/model-6600 >> ave validation accuracy 0.83965
# << best model so far is saved in ckpt_model_08_run01/best/model-6700 >> ave validation accuracy 0.84011
# << best model so far is saved in ckpt_model_08_run01/best/model-6800 >> ave validation accuracy 0.84081
# << best model so far is saved in ckpt_model_08_run01/best/model-6900 >> ave validation accuracy 0.84114
# STEP    7000 END @ 2016-12-27 18:10:10.010933, training accuracy 0.95000, ave validation accuracy 0.84004
# << best model so far is saved in ckpt_model_08_run01/best/model-7100 >> ave validation accuracy 0.84135
# << best model so far is saved in ckpt_model_08_run01/best/model-7200 >> ave validation accuracy 0.84170
# << best model so far is saved in ckpt_model_08_run01/best/model-7300 >> ave validation accuracy 0.84280
# << best model so far is saved in ckpt_model_08_run01/best/model-7400 >> ave validation accuracy 0.84436
# << best model so far is saved in ckpt_model_08_run01/best/model-7500 >> ave validation accuracy 0.84492
# << best model so far is saved in ckpt_model_08_run01/best/model-7900 >> ave validation accuracy 0.84498
# << best model so far is saved in ckpt_model_08_run01/best/model-8000 >> ave validation accuracy 0.84516
# STEP    8000 END @ 2016-12-27 18:13:55.837893, training accuracy 0.93000, ave validation accuracy 0.84516
# << best model so far is saved in ckpt_model_08_run01/best/model-8100 >> ave validation accuracy 0.84519
# << best model so far is saved in ckpt_model_08_run01/best/model-8300 >> ave validation accuracy 0.84566
# << best model so far is saved in ckpt_model_08_run01/best/model-8400 >> ave validation accuracy 0.84713
# << best model so far is saved in ckpt_model_08_run01/best/model-8500 >> ave validation accuracy 0.84828
# << best model so far is saved in ckpt_model_08_run01/best/model-8800 >> ave validation accuracy 0.84853
# << best model so far is saved in ckpt_model_08_run01/best/model-9000 >> ave validation accuracy 0.84918
# STEP    9000 END @ 2016-12-27 18:17:36.781339, training accuracy 0.97500, ave validation accuracy 0.84918
# << best model so far is saved in ckpt_model_08_run01/best/model-9300 >> ave validation accuracy 0.84970
# << best model so far is saved in ckpt_model_08_run01/best/model-9400 >> ave validation accuracy 0.85071
# << best model so far is saved in ckpt_model_08_run01/best/model-9500 >> ave validation accuracy 0.85085
# << best model so far is saved in ckpt_model_08_run01/best/model-9700 >> ave validation accuracy 0.85110
# STEP   10000 END @ 2016-12-27 18:21:04.996621, training accuracy 0.97500, ave validation accuracy 0.85090
# << best model so far is saved in ckpt_model_08_run01/best/model-10200 >> ave validation accuracy 0.85152
# << best model so far is saved in ckpt_model_08_run01/best/model-10300 >> ave validation accuracy 0.85216
# << best model so far is saved in ckpt_model_08_run01/best/model-10600 >> ave validation accuracy 0.85244
# << best model so far is saved in ckpt_model_08_run01/best/model-10700 >> ave validation accuracy 0.85247
# << best model so far is saved in ckpt_model_08_run01/best/model-10900 >> ave validation accuracy 0.85315
# << best model so far is saved in ckpt_model_08_run01/best/model-11000 >> ave validation accuracy 0.85349
# STEP   11000 END @ 2016-12-27 18:24:44.521251, training accuracy 0.95500, ave validation accuracy 0.85349
# << best model so far is saved in ckpt_model_08_run01/best/model-11200 >> ave validation accuracy 0.85459
# << best model so far is saved in ckpt_model_08_run01/best/model-11500 >> ave validation accuracy 0.85520
# << best model so far is saved in ckpt_model_08_run01/best/model-11600 >> ave validation accuracy 0.85580
# << best model so far is saved in ckpt_model_08_run01/best/model-11800 >> ave validation accuracy 0.85623
# << best model so far is saved in ckpt_model_08_run01/best/model-11900 >> ave validation accuracy 0.85630
# << best model so far is saved in ckpt_model_08_run01/best/model-12000 >> ave validation accuracy 0.85649
# STEP   12000 END @ 2016-12-27 18:28:24.338062, training accuracy 0.98000, ave validation accuracy 0.85649
# << best model so far is saved in ckpt_model_08_run01/best/model-12100 >> ave validation accuracy 0.85688
# << best model so far is saved in ckpt_model_08_run01/best/model-12200 >> ave validation accuracy 0.85726
# STEP   13000 END @ 2016-12-27 18:31:40.507784, training accuracy 0.98500, ave validation accuracy 0.85669
# << best model so far is saved in ckpt_model_08_run01/best/model-13100 >> ave validation accuracy 0.85813
# << best model so far is saved in ckpt_model_08_run01/best/model-13200 >> ave validation accuracy 0.85831
# << best model so far is saved in ckpt_model_08_run01/best/model-13300 >> ave validation accuracy 0.85892
# << best model so far is saved in ckpt_model_08_run01/best/model-13400 >> ave validation accuracy 0.85960
# << best model so far is saved in ckpt_model_08_run01/best/model-13500 >> ave validation accuracy 0.85981
# << best model so far is saved in ckpt_model_08_run01/best/model-13700 >> ave validation accuracy 0.85996
# STEP   14000 END @ 2016-12-27 18:35:21.058630, training accuracy 0.96500, ave validation accuracy 0.85894
# STEP   15000 END @ 2016-12-27 18:38:25.701877, training accuracy 0.97500, ave validation accuracy 0.85813
# << best model so far is saved in ckpt_model_08_run01/best/model-15700 >> ave validation accuracy 0.86029
# << best model so far is saved in ckpt_model_08_run01/best/model-15800 >> ave validation accuracy 0.86112
# STEP   16000 END @ 2016-12-27 18:41:41.526293, training accuracy 0.99500, ave validation accuracy 0.86105
# << hourly save at ckpt_model_08_run01/hourly/model-16100 and pickle_model_08_run01 >>
# STEP   17000 END @ 2016-12-27 18:44:51.873852, training accuracy 0.99500, ave validation accuracy 0.86031
# << best model so far is saved in ckpt_model_08_run01/best/model-17700 >> ave validation accuracy 0.86126
# << best model so far is saved in ckpt_model_08_run01/best/model-17800 >> ave validation accuracy 0.86204
# << best model so far is saved in ckpt_model_08_run01/best/model-18000 >> ave validation accuracy 0.86223
# STEP   18000 END @ 2016-12-27 18:48:14.226875, training accuracy 0.97000, ave validation accuracy 0.86223
# << best model so far is saved in ckpt_model_08_run01/best/model-18200 >> ave validation accuracy 0.86249
# << best model so far is saved in ckpt_model_08_run01/best/model-18400 >> ave validation accuracy 0.86271
# << best model so far is saved in ckpt_model_08_run01/best/model-18500 >> ave validation accuracy 0.86303
# STEP   19000 END @ 2016-12-27 18:51:35.857017, training accuracy 0.99500, ave validation accuracy 0.86145
# << best model so far is saved in ckpt_model_08_run01/best/model-19800 >> ave validation accuracy 0.86333
# STEP   20000 END @ 2016-12-27 18:54:46.118282, training accuracy 0.98000, ave validation accuracy 0.86280
# << best model so far is saved in ckpt_model_08_run01/best/model-20700 >> ave validation accuracy 0.86350
# << best model so far is saved in ckpt_model_08_run01/best/model-20800 >> ave validation accuracy 0.86358
# << best model so far is saved in ckpt_model_08_run01/best/model-20900 >> ave validation accuracy 0.86376
# STEP   21000 END @ 2016-12-27 18:58:08.617512, training accuracy 0.98500, ave validation accuracy 0.86376
# << best model so far is saved in ckpt_model_08_run01/best/model-21100 >> ave validation accuracy 0.86391
# STEP   22000 END @ 2016-12-27 19:01:20.611315, training accuracy 0.99500, ave validation accuracy 0.86135
# << best model so far is saved in ckpt_model_08_run01/best/model-22800 >> ave validation accuracy 0.86476
# STEP   23000 END @ 2016-12-27 19:04:30.797158, training accuracy 0.99000, ave validation accuracy 0.86429
# << best model so far is saved in ckpt_model_08_run01/best/model-23200 >> ave validation accuracy 0.86499
# << best model so far is saved in ckpt_model_08_run01/best/model-23500 >> ave validation accuracy 0.86501
# << best model so far is saved in ckpt_model_08_run01/best/model-23700 >> ave validation accuracy 0.86509
# << best model so far is saved in ckpt_model_08_run01/best/model-23800 >> ave validation accuracy 0.86567
# STEP   24000 END @ 2016-12-27 19:07:58.706720, training accuracy 0.99000, ave validation accuracy 0.86450
# << best model so far is saved in ckpt_model_08_run01/best/model-24700 >> ave validation accuracy 0.86570
# STEP   25000 END @ 2016-12-27 19:11:10.235601, training accuracy 0.98500, ave validation accuracy 0.86530
# << best model so far is saved in ckpt_model_08_run01/best/model-25500 >> ave validation accuracy 0.86596
# << best model so far is saved in ckpt_model_08_run01/best/model-25600 >> ave validation accuracy 0.86647
# << best model so far is saved in ckpt_model_08_run01/best/model-25700 >> ave validation accuracy 0.86657
# STEP   26000 END @ 2016-12-27 19:14:32.632567, training accuracy 1.00000, ave validation accuracy 0.86612
# STEP   27000 END @ 2016-12-27 19:17:37.516352, training accuracy 0.99000, ave validation accuracy 0.86441
# STEP   28000 END @ 2016-12-27 19:20:42.442378, training accuracy 1.00000, ave validation accuracy 0.86527
# STEP   29000 END @ 2016-12-27 19:23:47.150007, training accuracy 0.99500, ave validation accuracy 0.86478
# STEP   30000 END @ 2016-12-27 19:26:52.188654, training accuracy 0.99500, ave validation accuracy 0.86581
# STEP   31000 END @ 2016-12-27 19:29:56.997111, training accuracy 1.00000, ave validation accuracy 0.86526
# STEP   32000 END @ 2016-12-27 19:33:01.822159, training accuracy 0.99500, ave validation accuracy 0.86588
# << best model so far is saved in ckpt_model_08_run01/best/model-32300 >> ave validation accuracy 0.86659
# STEP   33000 END @ 2016-12-27 19:36:12.193383, training accuracy 1.00000, ave validation accuracy 0.86525
# STEP   34000 END @ 2016-12-27 19:39:17.120134, training accuracy 1.00000, ave validation accuracy 0.86496
# << hourly save at ckpt_model_08_run01/hourly/model-35000 and pickle_model_08_run01 >>
# STEP   35000 END @ 2016-12-27 19:42:28.442551, training accuracy 0.99000, ave validation accuracy 0.86576
# << best model so far is saved in ckpt_model_08_run01/best/model-35600 >> ave validation accuracy 0.86664
# << best model so far is saved in ckpt_model_08_run01/best/model-35700 >> ave validation accuracy 0.86679
# STEP   36000 END @ 2016-12-27 19:45:45.542356, training accuracy 1.00000, ave validation accuracy 0.86649
# << best model so far is saved in ckpt_model_08_run01/best/model-36800 >> ave validation accuracy 0.86683
# STEP   37000 END @ 2016-12-27 19:48:55.495468, training accuracy 1.00000, ave validation accuracy 0.86664
# << best model so far is saved in ckpt_model_08_run01/best/model-37100 >> ave validation accuracy 0.86692
# << best model so far is saved in ckpt_model_08_run01/best/model-37300 >> ave validation accuracy 0.86693
# << best model so far is saved in ckpt_model_08_run01/best/model-37700 >> ave validation accuracy 0.86700
# << best model so far is saved in ckpt_model_08_run01/best/model-37800 >> ave validation accuracy 0.86719
# STEP   38000 END @ 2016-12-27 19:52:23.593974, training accuracy 1.00000, ave validation accuracy 0.86652
# STEP   39000 END @ 2016-12-27 19:55:28.503223, training accuracy 0.99500, ave validation accuracy 0.86529
# STEP   40000 END @ 2016-12-27 19:58:33.184801, training accuracy 1.00000, ave validation accuracy 0.86612
# STEP   41000 END @ 2016-12-27 20:01:37.980535, training accuracy 1.00000, ave validation accuracy 0.86627
# << best model so far is saved in ckpt_model_08_run01/best/model-41400 >> ave validation accuracy 0.86741
# << best model so far is saved in ckpt_model_08_run01/best/model-41700 >> ave validation accuracy 0.86760
# << best model so far is saved in ckpt_model_08_run01/best/model-41800 >> ave validation accuracy 0.86792
# STEP   42000 END @ 2016-12-27 20:05:00.494329, training accuracy 1.00000, ave validation accuracy 0.86759
# STEP   43000 END @ 2016-12-27 20:08:05.136100, training accuracy 1.00000, ave validation accuracy 0.86749
# << best model so far is saved in ckpt_model_08_run01/best/model-43100 >> ave validation accuracy 0.86797
# << best model so far is saved in ckpt_model_08_run01/best/model-43200 >> ave validation accuracy 0.86870
# STEP   44000 END @ 2016-12-27 20:11:20.714901, training accuracy 1.00000, ave validation accuracy 0.86677
# STEP   45000 END @ 2016-12-27 20:14:25.438133, training accuracy 1.00000, ave validation accuracy 0.86665
# STEP   46000 END @ 2016-12-27 20:17:30.326875, training accuracy 0.99500, ave validation accuracy 0.86761
# STEP   47000 END @ 2016-12-27 20:20:35.119406, training accuracy 1.00000, ave validation accuracy 0.86489
# STEP   48000 END @ 2016-12-27 20:23:40.114461, training accuracy 1.00000, ave validation accuracy 0.86521
# STEP   49000 END @ 2016-12-27 20:26:44.884420, training accuracy 1.00000, ave validation accuracy 0.86727
# STEP   50000 END @ 2016-12-27 20:29:49.614025, training accuracy 1.00000, ave validation accuracy 0.86567
# STEP   51000 END @ 2016-12-27 20:32:54.365714, training accuracy 1.00000, ave validation accuracy 0.86670
# STEP   52000 END @ 2016-12-27 20:35:58.990233, training accuracy 1.00000, ave validation accuracy 0.86688
# STEP   53000 END @ 2016-12-27 20:39:03.627999, training accuracy 1.00000, ave validation accuracy 0.86617
# STEP   54000 END @ 2016-12-27 20:42:08.292743, training accuracy 1.00000, ave validation accuracy 0.86530
# << hourly save at ckpt_model_08_run01/hourly/model-54200 and pickle_model_08_run01 >>
# STEP   55000 END @ 2016-12-27 20:45:19.741720, training accuracy 1.00000, ave validation accuracy 0.86485
# STEP   56000 END @ 2016-12-27 20:48:24.015152, training accuracy 1.00000, ave validation accuracy 0.86620
# STEP   57000 END @ 2016-12-27 20:51:28.890543, training accuracy 1.00000, ave validation accuracy 0.86664
# STEP   58000 END @ 2016-12-27 20:54:33.565142, training accuracy 1.00000, ave validation accuracy 0.86531
# STEP   59000 END @ 2016-12-27 20:57:38.944259, training accuracy 1.00000, ave validation accuracy 0.86499
# STEP   60000 END @ 2016-12-27 21:00:43.573953, training accuracy 1.00000, ave validation accuracy 0.86469
# STEP   61000 END @ 2016-12-27 21:03:48.472338, training accuracy 1.00000, ave validation accuracy 0.86654
# STEP   62000 END @ 2016-12-27 21:06:52.981510, training accuracy 1.00000, ave validation accuracy 0.86510
# STEP   63000 END @ 2016-12-27 21:09:57.783329, training accuracy 1.00000, ave validation accuracy 0.86727
# STEP   64000 END @ 2016-12-27 21:13:02.293897, training accuracy 1.00000, ave validation accuracy 0.86566
# STEP   65000 END @ 2016-12-27 21:16:07.309304, training accuracy 1.00000, ave validation accuracy 0.86421
# STEP   66000 END @ 2016-12-27 21:19:11.973093, training accuracy 1.00000, ave validation accuracy 0.86615
# STEP   67000 END @ 2016-12-27 21:22:17.042768, training accuracy 1.00000, ave validation accuracy 0.86567
# STEP   68000 END @ 2016-12-27 21:25:21.808412, training accuracy 1.00000, ave validation accuracy 0.86567
# STEP   69000 END @ 2016-12-27 21:28:26.960745, training accuracy 1.00000, ave validation accuracy 0.86729
# STEP   70000 END @ 2016-12-27 21:31:31.850995, training accuracy 1.00000, ave validation accuracy 0.86704
# STEP   71000 END @ 2016-12-27 21:34:36.415959, training accuracy 1.00000, ave validation accuracy 0.86571
# STEP   72000 END @ 2016-12-27 21:37:41.632912, training accuracy 1.00000, ave validation accuracy 0.86644
# STEP   73000 END @ 2016-12-27 21:40:45.804100, training accuracy 1.00000, ave validation accuracy 0.86698
# << hourly save at ckpt_model_08_run01/hourly/model-73700 and pickle_model_08_run01 >>
# STEP   74000 END @ 2016-12-27 21:43:57.382401, training accuracy 1.00000, ave validation accuracy 0.86522
# STEP   75000 END @ 2016-12-27 21:47:01.849993, training accuracy 1.00000, ave validation accuracy 0.86585
# STEP   76000 END @ 2016-12-27 21:50:06.299732, training accuracy 1.00000, ave validation accuracy 0.86579
# STEP   77000 END @ 2016-12-27 21:53:11.130247, training accuracy 1.00000, ave validation accuracy 0.86599
# STEP   78000 END @ 2016-12-27 21:56:15.771377, training accuracy 1.00000, ave validation accuracy 0.86696
# STEP   79000 END @ 2016-12-27 21:59:20.462717, training accuracy 1.00000, ave validation accuracy 0.86618
# STEP   80000 END @ 2016-12-27 22:02:25.020742, training accuracy 1.00000, ave validation accuracy 0.86639
# STEP   81000 END @ 2016-12-27 22:05:30.028226, training accuracy 1.00000, ave validation accuracy 0.86610
# STEP   82000 END @ 2016-12-27 22:08:34.958052, training accuracy 1.00000, ave validation accuracy 0.86549
# STEP   83000 END @ 2016-12-27 22:11:39.252735, training accuracy 1.00000, ave validation accuracy 0.86644
# STEP   84000 END @ 2016-12-27 22:14:44.672527, training accuracy 1.00000, ave validation accuracy 0.86585
# STEP   85000 END @ 2016-12-27 22:17:49.480503, training accuracy 1.00000, ave validation accuracy 0.86560
# STEP   86000 END @ 2016-12-27 22:20:54.063928, training accuracy 1.00000, ave validation accuracy 0.86454
# STEP   87000 END @ 2016-12-27 22:23:58.786800, training accuracy 1.00000, ave validation accuracy 0.86620
# STEP   88000 END @ 2016-12-27 22:27:03.358227, training accuracy 1.00000, ave validation accuracy 0.86611
# STEP   89000 END @ 2016-12-27 22:30:08.098893, training accuracy 1.00000, ave validation accuracy 0.86544
# STEP   90000 END @ 2016-12-27 22:33:13.041805, training accuracy 1.00000, ave validation accuracy 0.86546
# STEP   91000 END @ 2016-12-27 22:36:18.024546, training accuracy 1.00000, ave validation accuracy 0.86539
# STEP   92000 END @ 2016-12-27 22:39:22.675862, training accuracy 1.00000, ave validation accuracy 0.86491
# STEP   93000 END @ 2016-12-27 22:42:27.826592, training accuracy 1.00000, ave validation accuracy 0.86524
# << hourly save at ckpt_model_08_run01/hourly/model-93200 and pickle_model_08_run01 >>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-feafc4fc8124> in <module>()
#       1 #Train the model
# ----> 2 train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#
# /home/kumiko/cifar10/helper_functions.pyc in train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#     259             _, summary = sess.run([graph_variables['optimizer'], graph_variables['summarizer']],
#     260                                   feed_dict={graph_variables['data']: batch_data, graph_variables['labels']: batch_labels,
# --> 261                                              graph_variables['keep_prob']: accuracy_log['variables']['dropout_train_keep_prob'], graph_variables['is_training']: True})
#     262
#     263             if i % accuracy_log['variables']['log_every'] == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Test accuracy
test_accuracy(graph_variables, accuracy_log, test_data, test_labels)
# Out:
# << test accuracy 0.86150 >>
