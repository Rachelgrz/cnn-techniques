# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from helper_functions import *

# %%
#Continueing training?
continued = False
checkpoint_file_to_use = None #Example: 'ckpt_model_01_run01/hourly/model-9350'

#If training from step 0
#############################
naming = 'model_01_run01'
#############################
variables = {
    'modify_images': False,
    'crop_images': False,
    'enlarge_images': False,
    'before_flatten_image_side_size': 4, #Need to calculate
    'first_hidden_layer_features': 384,
    'weights_stddev': 0.015,
    'biases_initial': 0.1,
    'dropout_train_keep_prob': 1.0,
    'learning_rate_initial': 0.01,
    'learning_rate_decay_steps': int(10000000),
    'learning_rate_decay': 1.0,
    'start_step_early_stopping': 150000,
    'early_stopping_patience': 0.1,
    'batch_size': 200,
    'max_steps': 100000000,
    'average_n_validation_accuracy': 8
}

# %%
#Create accuracy_log to pickle and directories for TensorBoard and checkpoint
accuracy_log = prep_accuracy_log(continued, checkpoint_file_to_use, naming, variables)

# %%
#Get data and labels
(train_data, validation_data, test_data, train_labels, validation_labels, test_labels) = get_data_and_labels(accuracy_log)

# %%
#Build a model
crop_images = accuracy_log['variables']['crop_images']
modify_images = accuracy_log['variables']['modify_images']
weights_stddev = accuracy_log['variables']['weights_stddev']
biases_initial = accuracy_log['variables']['biases_initial']
input_image_side_size = accuracy_log['variables']['input_image_side_size']
crop_to_side_size = accuracy_log['variables']['crop_to_side_size']
before_flatten_image_side_size = accuracy_log['variables']['before_flatten_image_side_size']
first_hidden_layer_features = accuracy_log['variables']['first_hidden_layer_features']
learning_rate_initial = accuracy_log['variables']['learning_rate_initial']
learning_rate_decay_steps = accuracy_log['variables']['learning_rate_decay_steps']
learning_rate_decay = accuracy_log['variables']['learning_rate_decay']

graph = tf.Graph()
with graph.as_default():
    global_step = tf.Variable(0, trainable=False)
    is_training = tf.placeholder(tf.bool)
    keep_prob = tf.placeholder(tf.float32)

    data = tf.placeholder(tf.float32, [None, input_image_side_size, input_image_side_size, 3])
    labels = tf.placeholder(tf.float32, [None, 10])
    
    if crop_images & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    elif (not crop_images) & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify_no_crop(data), lambda: tf.identity(data))
    elif crop_images & (not modify_images):
        data_v2 = tf.cond(is_training, lambda: random_crop(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    else:
        data_v2 = tf.identity(data)
        
    W_conv1 = weight_variable([3, 3, 3, 64], weights_stddev, 'W_conv1')
    b_conv1 = bias_variable(biases_initial, [64], 'b_conv1')
    conv1 = conv2d(data_v2, W_conv1) + b_conv1
    conv1_relu = tf.nn.relu(conv1)
    resize1 = resize_stride2(conv1_relu)

    W_conv2 = weight_variable([3, 3, 64, 64], weights_stddev, 'W_conv2')
    b_conv2 = bias_variable(biases_initial, [64], 'b_conv2')
    conv2 = conv2d(resize1, W_conv2) + b_conv2
    conv2_relu = tf.nn.relu(conv2)
    resize2 = resize_stride2(conv2_relu)

    W_conv3 = weight_variable([3, 3, 64, 128], weights_stddev, 'W_conv3')
    b_conv3 = bias_variable(biases_initial, [128], 'b_conv3')
    conv3 = conv2d(resize2, W_conv3) + b_conv3
    conv3_relu = tf.nn.relu(conv3)
    resize3 = resize_stride2(conv3_relu)
    
    resize3_flat = tf.reshape(resize3, [-1, before_flatten_image_side_size*before_flatten_image_side_size*128])

    W_fc1 = weight_variable([before_flatten_image_side_size*before_flatten_image_side_size*128, first_hidden_layer_features], weights_stddev, 'W_fc1')
    b_fc1 = bias_variable(biases_initial, [first_hidden_layer_features], 'b_fc1')
    fc1 = tf.matmul(resize3_flat, W_fc1) + b_fc1
    fc1_relu = tf.nn.relu(fc1)
    
    W_fc2 = weight_variable([first_hidden_layer_features, int(first_hidden_layer_features/2)], weights_stddev, 'W_fc2')
    b_fc2 = bias_variable(biases_initial, [first_hidden_layer_features/2], 'b_fc2')
    fc2 = tf.matmul(fc1_relu, W_fc2) + b_fc2
    fc2_relu = tf.nn.relu(fc2)
    
    W_fc3 = weight_variable([int(first_hidden_layer_features/2), 10], weights_stddev, 'W_fc3')
    b_fc3 = bias_variable(biases_initial, [10], 'b_fc3')
    logits = tf.matmul(fc2_relu, W_fc3) + b_fc3

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))
    
    learning_rate = tf.train.exponential_decay(learning_rate_initial, global_step, learning_rate_decay_steps, 
                                               learning_rate_decay, staircase=True)
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    tf.summary.scalar('loss', loss)
    tf.summary.scalar('learning_rate', learning_rate)
    tf.summary.scalar('training_accuracy', accuracy)
    
    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name, var)
    
    summarizer = tf.summary.merge_all()
    
graph_variables = {'graph': graph, 
                   'optimizer': optimizer, 
                   'summarizer': summarizer, 
                   'data': data, 
                   'labels': labels, 
                   'keep_prob': keep_prob, 
                   'is_training': is_training, 
                   'correct_prediction': correct_prediction,
                   'accuracy': accuracy}

# %%
#Train the model
train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
# Out:
# TRAINING   START @ 2016-12-23 18:43:08.724840
# << best model so far is saved in ckpt_model_01_run01/best/model-0 >> ave validation accuracy 0.09800
# STEP       0 END @ 2016-12-23 18:43:13.842503, training accuracy 0.11000, ave validation accuracy 0.09800
# STEP    1000 END @ 2016-12-23 18:44:06.677149, training accuracy 0.12500, ave validation accuracy 0.09619
# STEP    2000 END @ 2016-12-23 18:44:59.289529, training accuracy 0.14000, ave validation accuracy 0.09590
# STEP    3000 END @ 2016-12-23 18:45:51.659474, training accuracy 0.12500, ave validation accuracy 0.09642
# STEP    4000 END @ 2016-12-23 18:46:44.281399, training accuracy 0.09000, ave validation accuracy 0.09555
# STEP    5000 END @ 2016-12-23 18:47:36.850361, training accuracy 0.09500, ave validation accuracy 0.09551
# STEP    6000 END @ 2016-12-23 18:48:29.399888, training accuracy 0.08000, ave validation accuracy 0.09551
# STEP    7000 END @ 2016-12-23 18:49:22.047292, training accuracy 0.08000, ave validation accuracy 0.09551
# STEP    8000 END @ 2016-12-23 18:50:14.549888, training accuracy 0.12000, ave validation accuracy 0.09551
# STEP    9000 END @ 2016-12-23 18:51:06.952362, training accuracy 0.14000, ave validation accuracy 0.09555
# STEP   10000 END @ 2016-12-23 18:51:59.377278, training accuracy 0.12500, ave validation accuracy 0.09551
# STEP   11000 END @ 2016-12-23 18:52:51.764342, training accuracy 0.12000, ave validation accuracy 0.09551
# STEP   12000 END @ 2016-12-23 18:53:44.102851, training accuracy 0.10000, ave validation accuracy 0.09584
# STEP   13000 END @ 2016-12-23 18:54:36.509654, training accuracy 0.08000, ave validation accuracy 0.09586
# STEP   14000 END @ 2016-12-23 18:55:28.930786, training accuracy 0.10000, ave validation accuracy 0.09661
# << best model so far is saved in ckpt_model_01_run01/best/model-14900 >> ave validation accuracy 0.09930
# << best model so far is saved in ckpt_model_01_run01/best/model-15000 >> ave validation accuracy 0.09930
# STEP   15000 END @ 2016-12-23 18:56:23.190021, training accuracy 0.10000, ave validation accuracy 0.09930
# STEP   16000 END @ 2016-12-23 18:57:15.746699, training accuracy 0.09000, ave validation accuracy 0.09555
# STEP   17000 END @ 2016-12-23 18:58:08.237172, training accuracy 0.08500, ave validation accuracy 0.09551
# STEP   18000 END @ 2016-12-23 18:59:00.592268, training accuracy 0.08500, ave validation accuracy 0.09555
# STEP   19000 END @ 2016-12-23 18:59:53.023964, training accuracy 0.10000, ave validation accuracy 0.09582
# << best model so far is saved in ckpt_model_01_run01/best/model-19700 >> ave validation accuracy 0.10174
# << best model so far is saved in ckpt_model_01_run01/best/model-19800 >> ave validation accuracy 0.10174
# STEP   20000 END @ 2016-12-23 19:00:48.723717, training accuracy 0.13000, ave validation accuracy 0.10174
# << best model so far is saved in ckpt_model_01_run01/best/model-20100 >> ave validation accuracy 0.10385
# << best model so far is saved in ckpt_model_01_run01/best/model-20200 >> ave validation accuracy 0.10385
# << best model so far is saved in ckpt_model_01_run01/best/model-20300 >> ave validation accuracy 0.10385
# << best model so far is saved in ckpt_model_01_run01/best/model-20400 >> ave validation accuracy 0.10385
# STEP   21000 END @ 2016-12-23 19:01:45.263231, training accuracy 0.09000, ave validation accuracy 0.09520
# STEP   22000 END @ 2016-12-23 19:02:37.624365, training accuracy 0.09500, ave validation accuracy 0.09815
# STEP   23000 END @ 2016-12-23 19:03:30.092473, training accuracy 0.08000, ave validation accuracy 0.10089
# << best model so far is saved in ckpt_model_01_run01/best/model-23200 >> ave validation accuracy 0.10609
# << best model so far is saved in ckpt_model_01_run01/best/model-23300 >> ave validation accuracy 0.10630
# << best model so far is saved in ckpt_model_01_run01/best/model-23400 >> ave validation accuracy 0.11096
# << best model so far is saved in ckpt_model_01_run01/best/model-23500 >> ave validation accuracy 0.11629
# << best model so far is saved in ckpt_model_01_run01/best/model-23600 >> ave validation accuracy 0.12252
# << best model so far is saved in ckpt_model_01_run01/best/model-23800 >> ave validation accuracy 0.12857
# << best model so far is saved in ckpt_model_01_run01/best/model-23900 >> ave validation accuracy 0.13109
# << best model so far is saved in ckpt_model_01_run01/best/model-24000 >> ave validation accuracy 0.13790
# STEP   24000 END @ 2016-12-23 19:04:33.302991, training accuracy 0.17500, ave validation accuracy 0.13790
# << best model so far is saved in ckpt_model_01_run01/best/model-24100 >> ave validation accuracy 0.14442
# << best model so far is saved in ckpt_model_01_run01/best/model-24200 >> ave validation accuracy 0.14751
# << best model so far is saved in ckpt_model_01_run01/best/model-24300 >> ave validation accuracy 0.15212
# << best model so far is saved in ckpt_model_01_run01/best/model-24400 >> ave validation accuracy 0.15567
# << best model so far is saved in ckpt_model_01_run01/best/model-24500 >> ave validation accuracy 0.16371
# << best model so far is saved in ckpt_model_01_run01/best/model-24600 >> ave validation accuracy 0.16442
# << best model so far is saved in ckpt_model_01_run01/best/model-24700 >> ave validation accuracy 0.16802
# << best model so far is saved in ckpt_model_01_run01/best/model-24800 >> ave validation accuracy 0.17014
# << best model so far is saved in ckpt_model_01_run01/best/model-24900 >> ave validation accuracy 0.17485
# << best model so far is saved in ckpt_model_01_run01/best/model-25000 >> ave validation accuracy 0.17776
# STEP   25000 END @ 2016-12-23 19:05:38.851348, training accuracy 0.16500, ave validation accuracy 0.17776
# << best model so far is saved in ckpt_model_01_run01/best/model-25200 >> ave validation accuracy 0.17830
# << best model so far is saved in ckpt_model_01_run01/best/model-25400 >> ave validation accuracy 0.17990
# << best model so far is saved in ckpt_model_01_run01/best/model-25500 >> ave validation accuracy 0.18271
# << best model so far is saved in ckpt_model_01_run01/best/model-25600 >> ave validation accuracy 0.18277
# << best model so far is saved in ckpt_model_01_run01/best/model-25700 >> ave validation accuracy 0.18377
# << best model so far is saved in ckpt_model_01_run01/best/model-25800 >> ave validation accuracy 0.18614
# << best model so far is saved in ckpt_model_01_run01/best/model-25900 >> ave validation accuracy 0.19026
# << best model so far is saved in ckpt_model_01_run01/best/model-26000 >> ave validation accuracy 0.19544
# STEP   26000 END @ 2016-12-23 19:06:40.724891, training accuracy 0.17000, ave validation accuracy 0.19544
# << best model so far is saved in ckpt_model_01_run01/best/model-26100 >> ave validation accuracy 0.20094
# << best model so far is saved in ckpt_model_01_run01/best/model-26200 >> ave validation accuracy 0.20484
# << best model so far is saved in ckpt_model_01_run01/best/model-26300 >> ave validation accuracy 0.20945
# << best model so far is saved in ckpt_model_01_run01/best/model-26400 >> ave validation accuracy 0.21480
# << best model so far is saved in ckpt_model_01_run01/best/model-26500 >> ave validation accuracy 0.21836
# << best model so far is saved in ckpt_model_01_run01/best/model-26600 >> ave validation accuracy 0.22197
# << best model so far is saved in ckpt_model_01_run01/best/model-26700 >> ave validation accuracy 0.22622
# << best model so far is saved in ckpt_model_01_run01/best/model-26800 >> ave validation accuracy 0.22832
# << best model so far is saved in ckpt_model_01_run01/best/model-26900 >> ave validation accuracy 0.23094
# << best model so far is saved in ckpt_model_01_run01/best/model-27000 >> ave validation accuracy 0.23215
# STEP   27000 END @ 2016-12-23 19:07:46.140020, training accuracy 0.26500, ave validation accuracy 0.23215
# << best model so far is saved in ckpt_model_01_run01/best/model-27100 >> ave validation accuracy 0.23530
# << best model so far is saved in ckpt_model_01_run01/best/model-27200 >> ave validation accuracy 0.23775
# << best model so far is saved in ckpt_model_01_run01/best/model-27300 >> ave validation accuracy 0.24104
# << best model so far is saved in ckpt_model_01_run01/best/model-27400 >> ave validation accuracy 0.24402
# << best model so far is saved in ckpt_model_01_run01/best/model-27500 >> ave validation accuracy 0.24619
# << best model so far is saved in ckpt_model_01_run01/best/model-27600 >> ave validation accuracy 0.24779
# << best model so far is saved in ckpt_model_01_run01/best/model-27700 >> ave validation accuracy 0.24922
# << best model so far is saved in ckpt_model_01_run01/best/model-27800 >> ave validation accuracy 0.25210
# << best model so far is saved in ckpt_model_01_run01/best/model-27900 >> ave validation accuracy 0.25320
# << best model so far is saved in ckpt_model_01_run01/best/model-28000 >> ave validation accuracy 0.25424
# STEP   28000 END @ 2016-12-23 19:08:51.513520, training accuracy 0.22000, ave validation accuracy 0.25424
# << best model so far is saved in ckpt_model_01_run01/best/model-28100 >> ave validation accuracy 0.25609
# << best model so far is saved in ckpt_model_01_run01/best/model-28200 >> ave validation accuracy 0.25761
# << best model so far is saved in ckpt_model_01_run01/best/model-28300 >> ave validation accuracy 0.25910
# << best model so far is saved in ckpt_model_01_run01/best/model-28400 >> ave validation accuracy 0.26141
# << best model so far is saved in ckpt_model_01_run01/best/model-28500 >> ave validation accuracy 0.26382
# << best model so far is saved in ckpt_model_01_run01/best/model-28600 >> ave validation accuracy 0.26622
# << best model so far is saved in ckpt_model_01_run01/best/model-28700 >> ave validation accuracy 0.26902
# << best model so far is saved in ckpt_model_01_run01/best/model-28800 >> ave validation accuracy 0.27104
# << best model so far is saved in ckpt_model_01_run01/best/model-28900 >> ave validation accuracy 0.27342
# << best model so far is saved in ckpt_model_01_run01/best/model-29000 >> ave validation accuracy 0.27527
# STEP   29000 END @ 2016-12-23 19:09:56.824151, training accuracy 0.23500, ave validation accuracy 0.27527
# << best model so far is saved in ckpt_model_01_run01/best/model-29100 >> ave validation accuracy 0.27739
# << best model so far is saved in ckpt_model_01_run01/best/model-29200 >> ave validation accuracy 0.27901
# << best model so far is saved in ckpt_model_01_run01/best/model-29300 >> ave validation accuracy 0.27981
# << best model so far is saved in ckpt_model_01_run01/best/model-29400 >> ave validation accuracy 0.28101
# << best model so far is saved in ckpt_model_01_run01/best/model-29500 >> ave validation accuracy 0.28155
# << best model so far is saved in ckpt_model_01_run01/best/model-29600 >> ave validation accuracy 0.28359
# << best model so far is saved in ckpt_model_01_run01/best/model-29700 >> ave validation accuracy 0.28466
# << best model so far is saved in ckpt_model_01_run01/best/model-29800 >> ave validation accuracy 0.28651
# << best model so far is saved in ckpt_model_01_run01/best/model-29900 >> ave validation accuracy 0.28784
# << best model so far is saved in ckpt_model_01_run01/best/model-30000 >> ave validation accuracy 0.28939
# STEP   30000 END @ 2016-12-23 19:11:01.999436, training accuracy 0.32500, ave validation accuracy 0.28939
# << best model so far is saved in ckpt_model_01_run01/best/model-30100 >> ave validation accuracy 0.29166
# << best model so far is saved in ckpt_model_01_run01/best/model-30200 >> ave validation accuracy 0.29315
# << best model so far is saved in ckpt_model_01_run01/best/model-30300 >> ave validation accuracy 0.29571
# << best model so far is saved in ckpt_model_01_run01/best/model-30400 >> ave validation accuracy 0.29734
# << best model so far is saved in ckpt_model_01_run01/best/model-30500 >> ave validation accuracy 0.29897
# << best model so far is saved in ckpt_model_01_run01/best/model-30600 >> ave validation accuracy 0.30084
# << best model so far is saved in ckpt_model_01_run01/best/model-30700 >> ave validation accuracy 0.30334
# << best model so far is saved in ckpt_model_01_run01/best/model-30800 >> ave validation accuracy 0.30521
# << best model so far is saved in ckpt_model_01_run01/best/model-30900 >> ave validation accuracy 0.30849
# << best model so far is saved in ckpt_model_01_run01/best/model-31000 >> ave validation accuracy 0.31207
# STEP   31000 END @ 2016-12-23 19:12:07.362276, training accuracy 0.33000, ave validation accuracy 0.31207
# << best model so far is saved in ckpt_model_01_run01/best/model-31100 >> ave validation accuracy 0.31487
# << best model so far is saved in ckpt_model_01_run01/best/model-31200 >> ave validation accuracy 0.31746
# << best model so far is saved in ckpt_model_01_run01/best/model-31300 >> ave validation accuracy 0.32215
# << best model so far is saved in ckpt_model_01_run01/best/model-31400 >> ave validation accuracy 0.32624
# << best model so far is saved in ckpt_model_01_run01/best/model-31500 >> ave validation accuracy 0.33044
# << best model so far is saved in ckpt_model_01_run01/best/model-31600 >> ave validation accuracy 0.33515
# << best model so far is saved in ckpt_model_01_run01/best/model-31700 >> ave validation accuracy 0.33875
# << best model so far is saved in ckpt_model_01_run01/best/model-31800 >> ave validation accuracy 0.34217
# << best model so far is saved in ckpt_model_01_run01/best/model-31900 >> ave validation accuracy 0.34594
# << best model so far is saved in ckpt_model_01_run01/best/model-32000 >> ave validation accuracy 0.34974
# STEP   32000 END @ 2016-12-23 19:13:12.538707, training accuracy 0.43500, ave validation accuracy 0.34974
# << best model so far is saved in ckpt_model_01_run01/best/model-32100 >> ave validation accuracy 0.35270
# << best model so far is saved in ckpt_model_01_run01/best/model-32200 >> ave validation accuracy 0.35637
# << best model so far is saved in ckpt_model_01_run01/best/model-32300 >> ave validation accuracy 0.35907
# << best model so far is saved in ckpt_model_01_run01/best/model-32400 >> ave validation accuracy 0.36234
# << best model so far is saved in ckpt_model_01_run01/best/model-32500 >> ave validation accuracy 0.36397
# << best model so far is saved in ckpt_model_01_run01/best/model-32600 >> ave validation accuracy 0.36625
# << best model so far is saved in ckpt_model_01_run01/best/model-32700 >> ave validation accuracy 0.36950
# << best model so far is saved in ckpt_model_01_run01/best/model-32800 >> ave validation accuracy 0.37295
# << best model so far is saved in ckpt_model_01_run01/best/model-32900 >> ave validation accuracy 0.37519
# << best model so far is saved in ckpt_model_01_run01/best/model-33000 >> ave validation accuracy 0.37746
# STEP   33000 END @ 2016-12-23 19:14:17.910874, training accuracy 0.38000, ave validation accuracy 0.37746
# << best model so far is saved in ckpt_model_01_run01/best/model-33100 >> ave validation accuracy 0.37754
# << best model so far is saved in ckpt_model_01_run01/best/model-33200 >> ave validation accuracy 0.37987
# << best model so far is saved in ckpt_model_01_run01/best/model-33300 >> ave validation accuracy 0.38354
# << best model so far is saved in ckpt_model_01_run01/best/model-33400 >> ave validation accuracy 0.38667
# << best model so far is saved in ckpt_model_01_run01/best/model-33500 >> ave validation accuracy 0.38741
# << best model so far is saved in ckpt_model_01_run01/best/model-33600 >> ave validation accuracy 0.38957
# << best model so far is saved in ckpt_model_01_run01/best/model-33700 >> ave validation accuracy 0.39172
# << best model so far is saved in ckpt_model_01_run01/best/model-33800 >> ave validation accuracy 0.39405
# << best model so far is saved in ckpt_model_01_run01/best/model-33900 >> ave validation accuracy 0.39650
# << best model so far is saved in ckpt_model_01_run01/best/model-34000 >> ave validation accuracy 0.39707
# STEP   34000 END @ 2016-12-23 19:15:22.959736, training accuracy 0.42500, ave validation accuracy 0.39707
# << best model so far is saved in ckpt_model_01_run01/best/model-34100 >> ave validation accuracy 0.39917
# << best model so far is saved in ckpt_model_01_run01/best/model-34200 >> ave validation accuracy 0.40056
# << best model so far is saved in ckpt_model_01_run01/best/model-34300 >> ave validation accuracy 0.40234
# << best model so far is saved in ckpt_model_01_run01/best/model-34400 >> ave validation accuracy 0.40459
# << best model so far is saved in ckpt_model_01_run01/best/model-34500 >> ave validation accuracy 0.40536
# << best model so far is saved in ckpt_model_01_run01/best/model-34600 >> ave validation accuracy 0.40675
# << best model so far is saved in ckpt_model_01_run01/best/model-34700 >> ave validation accuracy 0.41026
# << best model so far is saved in ckpt_model_01_run01/best/model-34800 >> ave validation accuracy 0.41327
# << best model so far is saved in ckpt_model_01_run01/best/model-35000 >> ave validation accuracy 0.41527
# STEP   35000 END @ 2016-12-23 19:16:26.397700, training accuracy 0.45000, ave validation accuracy 0.41527
# << best model so far is saved in ckpt_model_01_run01/best/model-35100 >> ave validation accuracy 0.41822
# << best model so far is saved in ckpt_model_01_run01/best/model-35200 >> ave validation accuracy 0.42016
# << best model so far is saved in ckpt_model_01_run01/best/model-35300 >> ave validation accuracy 0.42284
# << best model so far is saved in ckpt_model_01_run01/best/model-35400 >> ave validation accuracy 0.42551
# << best model so far is saved in ckpt_model_01_run01/best/model-35500 >> ave validation accuracy 0.42641
# << best model so far is saved in ckpt_model_01_run01/best/model-35700 >> ave validation accuracy 0.43007
# << best model so far is saved in ckpt_model_01_run01/best/model-35800 >> ave validation accuracy 0.43126
# << best model so far is saved in ckpt_model_01_run01/best/model-35900 >> ave validation accuracy 0.43304
# STEP   36000 END @ 2016-12-23 19:17:29.499383, training accuracy 0.46500, ave validation accuracy 0.43225
# << best model so far is saved in ckpt_model_01_run01/best/model-36100 >> ave validation accuracy 0.43364
# << best model so far is saved in ckpt_model_01_run01/best/model-36200 >> ave validation accuracy 0.43430
# << best model so far is saved in ckpt_model_01_run01/best/model-36300 >> ave validation accuracy 0.43674
# << best model so far is saved in ckpt_model_01_run01/best/model-36400 >> ave validation accuracy 0.43986
# << best model so far is saved in ckpt_model_01_run01/best/model-36500 >> ave validation accuracy 0.44200
# << best model so far is saved in ckpt_model_01_run01/best/model-36600 >> ave validation accuracy 0.44270
# << best model so far is saved in ckpt_model_01_run01/best/model-36700 >> ave validation accuracy 0.44405
# << best model so far is saved in ckpt_model_01_run01/best/model-36800 >> ave validation accuracy 0.44587
# << best model so far is saved in ckpt_model_01_run01/best/model-36900 >> ave validation accuracy 0.44805
# << best model so far is saved in ckpt_model_01_run01/best/model-37000 >> ave validation accuracy 0.44997
# STEP   37000 END @ 2016-12-23 19:18:34.690762, training accuracy 0.56000, ave validation accuracy 0.44997
# << best model so far is saved in ckpt_model_01_run01/best/model-37100 >> ave validation accuracy 0.45152
# << best model so far is saved in ckpt_model_01_run01/best/model-37200 >> ave validation accuracy 0.45351
# << best model so far is saved in ckpt_model_01_run01/best/model-37300 >> ave validation accuracy 0.45385
# << best model so far is saved in ckpt_model_01_run01/best/model-37400 >> ave validation accuracy 0.45627
# << best model so far is saved in ckpt_model_01_run01/best/model-37500 >> ave validation accuracy 0.45836
# << best model so far is saved in ckpt_model_01_run01/best/model-37600 >> ave validation accuracy 0.46179
# << best model so far is saved in ckpt_model_01_run01/best/model-37700 >> ave validation accuracy 0.46322
# << best model so far is saved in ckpt_model_01_run01/best/model-37800 >> ave validation accuracy 0.46436
# << best model so far is saved in ckpt_model_01_run01/best/model-37900 >> ave validation accuracy 0.46689
# STEP   38000 END @ 2016-12-23 19:19:38.326017, training accuracy 0.48000, ave validation accuracy 0.46569
# << best model so far is saved in ckpt_model_01_run01/best/model-38100 >> ave validation accuracy 0.46755
# << best model so far is saved in ckpt_model_01_run01/best/model-38200 >> ave validation accuracy 0.47017
# << best model so far is saved in ckpt_model_01_run01/best/model-38300 >> ave validation accuracy 0.47042
# << best model so far is saved in ckpt_model_01_run01/best/model-38400 >> ave validation accuracy 0.47235
# << best model so far is saved in ckpt_model_01_run01/best/model-38500 >> ave validation accuracy 0.47295
# << best model so far is saved in ckpt_model_01_run01/best/model-38600 >> ave validation accuracy 0.47476
# << best model so far is saved in ckpt_model_01_run01/best/model-38700 >> ave validation accuracy 0.47559
# << best model so far is saved in ckpt_model_01_run01/best/model-38800 >> ave validation accuracy 0.47869
# << best model so far is saved in ckpt_model_01_run01/best/model-38900 >> ave validation accuracy 0.48135
# << best model so far is saved in ckpt_model_01_run01/best/model-39000 >> ave validation accuracy 0.48201
# STEP   39000 END @ 2016-12-23 19:20:43.582866, training accuracy 0.54500, ave validation accuracy 0.48201
# << best model so far is saved in ckpt_model_01_run01/best/model-39100 >> ave validation accuracy 0.48465
# << best model so far is saved in ckpt_model_01_run01/best/model-39200 >> ave validation accuracy 0.48549
# << best model so far is saved in ckpt_model_01_run01/best/model-39300 >> ave validation accuracy 0.48781
# << best model so far is saved in ckpt_model_01_run01/best/model-39400 >> ave validation accuracy 0.48837
# << best model so far is saved in ckpt_model_01_run01/best/model-39500 >> ave validation accuracy 0.48886
# << best model so far is saved in ckpt_model_01_run01/best/model-39600 >> ave validation accuracy 0.49037
# << best model so far is saved in ckpt_model_01_run01/best/model-39700 >> ave validation accuracy 0.49175
# << best model so far is saved in ckpt_model_01_run01/best/model-39800 >> ave validation accuracy 0.49346
# << best model so far is saved in ckpt_model_01_run01/best/model-39900 >> ave validation accuracy 0.49487
# << best model so far is saved in ckpt_model_01_run01/best/model-40000 >> ave validation accuracy 0.49577
# STEP   40000 END @ 2016-12-23 19:21:48.903021, training accuracy 0.58500, ave validation accuracy 0.49577
# << best model so far is saved in ckpt_model_01_run01/best/model-40100 >> ave validation accuracy 0.49612
# << best model so far is saved in ckpt_model_01_run01/best/model-40200 >> ave validation accuracy 0.49721
# << best model so far is saved in ckpt_model_01_run01/best/model-40300 >> ave validation accuracy 0.49779
# << best model so far is saved in ckpt_model_01_run01/best/model-40400 >> ave validation accuracy 0.49880
# << best model so far is saved in ckpt_model_01_run01/best/model-40500 >> ave validation accuracy 0.49929
# << best model so far is saved in ckpt_model_01_run01/best/model-40600 >> ave validation accuracy 0.50011
# << best model so far is saved in ckpt_model_01_run01/best/model-40700 >> ave validation accuracy 0.50134
# << best model so far is saved in ckpt_model_01_run01/best/model-40800 >> ave validation accuracy 0.50287
# << best model so far is saved in ckpt_model_01_run01/best/model-40900 >> ave validation accuracy 0.50324
# << best model so far is saved in ckpt_model_01_run01/best/model-41000 >> ave validation accuracy 0.50537
# STEP   41000 END @ 2016-12-23 19:22:54.153789, training accuracy 0.57000, ave validation accuracy 0.50537
# << best model so far is saved in ckpt_model_01_run01/best/model-41100 >> ave validation accuracy 0.50821
# << best model so far is saved in ckpt_model_01_run01/best/model-41200 >> ave validation accuracy 0.50962
# << best model so far is saved in ckpt_model_01_run01/best/model-41300 >> ave validation accuracy 0.51101
# << best model so far is saved in ckpt_model_01_run01/best/model-41400 >> ave validation accuracy 0.51152
# << best model so far is saved in ckpt_model_01_run01/best/model-41500 >> ave validation accuracy 0.51296
# << best model so far is saved in ckpt_model_01_run01/best/model-41600 >> ave validation accuracy 0.51366
# << best model so far is saved in ckpt_model_01_run01/best/model-41700 >> ave validation accuracy 0.51632
# << best model so far is saved in ckpt_model_01_run01/best/model-41800 >> ave validation accuracy 0.51684
# << best model so far is saved in ckpt_model_01_run01/best/model-42000 >> ave validation accuracy 0.51727
# STEP   42000 END @ 2016-12-23 19:23:57.762408, training accuracy 0.57000, ave validation accuracy 0.51727
# << best model so far is saved in ckpt_model_01_run01/best/model-42100 >> ave validation accuracy 0.51741
# << best model so far is saved in ckpt_model_01_run01/best/model-42200 >> ave validation accuracy 0.51887
# << best model so far is saved in ckpt_model_01_run01/best/model-42900 >> ave validation accuracy 0.51902
# STEP   43000 END @ 2016-12-23 19:24:54.002866, training accuracy 0.56000, ave validation accuracy 0.51862
# << best model so far is saved in ckpt_model_01_run01/best/model-43200 >> ave validation accuracy 0.51970
# << best model so far is saved in ckpt_model_01_run01/best/model-43300 >> ave validation accuracy 0.52355
# << best model so far is saved in ckpt_model_01_run01/best/model-43400 >> ave validation accuracy 0.52505
# << best model so far is saved in ckpt_model_01_run01/best/model-43900 >> ave validation accuracy 0.52801
# STEP   44000 END @ 2016-12-23 19:25:51.938927, training accuracy 0.67000, ave validation accuracy 0.52795
# << best model so far is saved in ckpt_model_01_run01/best/model-44100 >> ave validation accuracy 0.52840
# << best model so far is saved in ckpt_model_01_run01/best/model-44200 >> ave validation accuracy 0.52964
# << best model so far is saved in ckpt_model_01_run01/best/model-44300 >> ave validation accuracy 0.53436
# << best model so far is saved in ckpt_model_01_run01/best/model-44400 >> ave validation accuracy 0.53542
# << best model so far is saved in ckpt_model_01_run01/best/model-44500 >> ave validation accuracy 0.53692
# << best model so far is saved in ckpt_model_01_run01/best/model-44600 >> ave validation accuracy 0.53851
# << best model so far is saved in ckpt_model_01_run01/best/model-44700 >> ave validation accuracy 0.53917
# << best model so far is saved in ckpt_model_01_run01/best/model-44800 >> ave validation accuracy 0.53965
# << best model so far is saved in ckpt_model_01_run01/best/model-44900 >> ave validation accuracy 0.54022
# STEP   45000 END @ 2016-12-23 19:26:55.610113, training accuracy 0.73000, ave validation accuracy 0.54009
# << best model so far is saved in ckpt_model_01_run01/best/model-45200 >> ave validation accuracy 0.54024
# << best model so far is saved in ckpt_model_01_run01/best/model-45300 >> ave validation accuracy 0.54077
# STEP   46000 END @ 2016-12-23 19:27:51.487268, training accuracy 0.66000, ave validation accuracy 0.54014
# << best model so far is saved in ckpt_model_01_run01/best/model-46700 >> ave validation accuracy 0.54087
# << best model so far is saved in ckpt_model_01_run01/best/model-46900 >> ave validation accuracy 0.54289
# STEP   47000 END @ 2016-12-23 19:28:45.978913, training accuracy 0.70500, ave validation accuracy 0.54270
# << best model so far is saved in ckpt_model_01_run01/best/model-47100 >> ave validation accuracy 0.54504
# << best model so far is saved in ckpt_model_01_run01/best/model-47200 >> ave validation accuracy 0.54730
# << best model so far is saved in ckpt_model_01_run01/best/model-47400 >> ave validation accuracy 0.54892
# STEP   48000 END @ 2016-12-23 19:29:42.310856, training accuracy 0.69500, ave validation accuracy 0.54317
# STEP   49000 END @ 2016-12-23 19:30:34.661500, training accuracy 0.78500, ave validation accuracy 0.54626
# STEP   50000 END @ 2016-12-23 19:31:27.060306, training accuracy 0.85500, ave validation accuracy 0.54745
# STEP   51000 END @ 2016-12-23 19:32:19.482032, training accuracy 0.77500, ave validation accuracy 0.54407
# STEP   52000 END @ 2016-12-23 19:33:12.015702, training accuracy 0.90500, ave validation accuracy 0.54047
# STEP   53000 END @ 2016-12-23 19:34:04.426018, training accuracy 0.82500, ave validation accuracy 0.53952
# STEP   54000 END @ 2016-12-23 19:34:56.855782, training accuracy 0.89500, ave validation accuracy 0.54147
# STEP   55000 END @ 2016-12-23 19:35:49.320371, training accuracy 0.90500, ave validation accuracy 0.54165
# STEP   56000 END @ 2016-12-23 19:36:41.833796, training accuracy 0.89000, ave validation accuracy 0.53682
# STEP   57000 END @ 2016-12-23 19:37:34.345929, training accuracy 0.89000, ave validation accuracy 0.54166
# STEP   58000 END @ 2016-12-23 19:38:26.686343, training accuracy 0.98500, ave validation accuracy 0.53769
# STEP   59000 END @ 2016-12-23 19:39:19.154467, training accuracy 0.98500, ave validation accuracy 0.53277
# STEP   60000 END @ 2016-12-23 19:40:11.536183, training accuracy 1.00000, ave validation accuracy 0.51832
# STEP   61000 END @ 2016-12-23 19:41:04.050322, training accuracy 1.00000, ave validation accuracy 0.50504
# STEP   62000 END @ 2016-12-23 19:41:56.509861, training accuracy 1.00000, ave validation accuracy 0.54217
# STEP   63000 END @ 2016-12-23 19:42:49.002381, training accuracy 1.00000, ave validation accuracy 0.53561
# << hourly save at ckpt_model_01_run01/hourly/model-63400 and pickle_model_01_run01 >>
# STEP   64000 END @ 2016-12-23 19:43:43.100566, training accuracy 1.00000, ave validation accuracy 0.54101
# STEP   65000 END @ 2016-12-23 19:44:35.455101, training accuracy 1.00000, ave validation accuracy 0.54386
# STEP   66000 END @ 2016-12-23 19:45:27.783009, training accuracy 1.00000, ave validation accuracy 0.54319
# STEP   67000 END @ 2016-12-23 19:46:20.178726, training accuracy 1.00000, ave validation accuracy 0.54399
# STEP   68000 END @ 2016-12-23 19:47:12.587992, training accuracy 1.00000, ave validation accuracy 0.54387
# STEP   69000 END @ 2016-12-23 19:48:05.083286, training accuracy 1.00000, ave validation accuracy 0.54317
# STEP   70000 END @ 2016-12-23 19:48:57.458254, training accuracy 1.00000, ave validation accuracy 0.54314
# STEP   71000 END @ 2016-12-23 19:49:49.948723, training accuracy 1.00000, ave validation accuracy 0.52721
# STEP   72000 END @ 2016-12-23 19:50:42.273458, training accuracy 1.00000, ave validation accuracy 0.54490
# STEP   73000 END @ 2016-12-23 19:51:34.536253, training accuracy 1.00000, ave validation accuracy 0.54615
# STEP   74000 END @ 2016-12-23 19:52:26.895064, training accuracy 1.00000, ave validation accuracy 0.54607
# STEP   75000 END @ 2016-12-23 19:53:19.276961, training accuracy 1.00000, ave validation accuracy 0.54641
# STEP   76000 END @ 2016-12-23 19:54:11.746474, training accuracy 1.00000, ave validation accuracy 0.54590
# STEP   77000 END @ 2016-12-23 19:55:04.079180, training accuracy 1.00000, ave validation accuracy 0.54606
# STEP   78000 END @ 2016-12-23 19:55:56.445458, training accuracy 1.00000, ave validation accuracy 0.54616
# STEP   79000 END @ 2016-12-23 19:56:48.851025, training accuracy 1.00000, ave validation accuracy 0.54552
# STEP   80000 END @ 2016-12-23 19:57:41.235100, training accuracy 1.00000, ave validation accuracy 0.54536
# STEP   81000 END @ 2016-12-23 19:58:33.584996, training accuracy 1.00000, ave validation accuracy 0.54541
# STEP   82000 END @ 2016-12-23 19:59:26.123221, training accuracy 1.00000, ave validation accuracy 0.54517
# STEP   83000 END @ 2016-12-23 20:00:18.545497, training accuracy 1.00000, ave validation accuracy 0.54554
# STEP   84000 END @ 2016-12-23 20:01:10.977518, training accuracy 1.00000, ave validation accuracy 0.54541
# STEP   85000 END @ 2016-12-23 20:02:03.339662, training accuracy 1.00000, ave validation accuracy 0.54545
# STEP   86000 END @ 2016-12-23 20:02:55.745429, training accuracy 1.00000, ave validation accuracy 0.54484
# STEP   87000 END @ 2016-12-23 20:03:48.057513, training accuracy 1.00000, ave validation accuracy 0.54500
# STEP   88000 END @ 2016-12-23 20:04:40.291237, training accuracy 1.00000, ave validation accuracy 0.54437
# STEP   89000 END @ 2016-12-23 20:05:32.676593, training accuracy 1.00000, ave validation accuracy 0.54399
# STEP   90000 END @ 2016-12-23 20:06:24.987821, training accuracy 1.00000, ave validation accuracy 0.54452
# STEP   91000 END @ 2016-12-23 20:07:17.419022, training accuracy 1.00000, ave validation accuracy 0.54447
# STEP   92000 END @ 2016-12-23 20:08:09.725319, training accuracy 1.00000, ave validation accuracy 0.54426
# STEP   93000 END @ 2016-12-23 20:09:02.184049, training accuracy 1.00000, ave validation accuracy 0.54436
# STEP   94000 END @ 2016-12-23 20:09:54.596858, training accuracy 1.00000, ave validation accuracy 0.54405
# STEP   95000 END @ 2016-12-23 20:10:47.020394, training accuracy 1.00000, ave validation accuracy 0.54376
# STEP   96000 END @ 2016-12-23 20:11:39.300312, training accuracy 1.00000, ave validation accuracy 0.54374
# STEP   97000 END @ 2016-12-23 20:12:31.763174, training accuracy 1.00000, ave validation accuracy 0.54385
# STEP   98000 END @ 2016-12-23 20:13:24.104801, training accuracy 1.00000, ave validation accuracy 0.54371
# STEP   99000 END @ 2016-12-23 20:14:16.623612, training accuracy 1.00000, ave validation accuracy 0.54361
# STEP  100000 END @ 2016-12-23 20:15:08.847261, training accuracy 1.00000, ave validation accuracy 0.54366
# STEP  101000 END @ 2016-12-23 20:16:01.151052, training accuracy 1.00000, ave validation accuracy 0.54379
# STEP  102000 END @ 2016-12-23 20:16:53.506540, training accuracy 1.00000, ave validation accuracy 0.54361
# STEP  103000 END @ 2016-12-23 20:17:45.916259, training accuracy 1.00000, ave validation accuracy 0.54357
# STEP  104000 END @ 2016-12-23 20:18:38.199409, training accuracy 1.00000, ave validation accuracy 0.54350
# STEP  105000 END @ 2016-12-23 20:19:30.509888, training accuracy 1.00000, ave validation accuracy 0.54395
# STEP  106000 END @ 2016-12-23 20:20:22.930431, training accuracy 1.00000, ave validation accuracy 0.54365
# STEP  107000 END @ 2016-12-23 20:21:15.328963, training accuracy 1.00000, ave validation accuracy 0.54350
# STEP  108000 END @ 2016-12-23 20:22:07.669282, training accuracy 1.00000, ave validation accuracy 0.54366
# STEP  109000 END @ 2016-12-23 20:23:00.075670, training accuracy 1.00000, ave validation accuracy 0.54339
# STEP  110000 END @ 2016-12-23 20:23:52.328737, training accuracy 1.00000, ave validation accuracy 0.54341
# STEP  111000 END @ 2016-12-23 20:24:44.660280, training accuracy 1.00000, ave validation accuracy 0.54359
# STEP  112000 END @ 2016-12-23 20:25:37.000628, training accuracy 1.00000, ave validation accuracy 0.54366
# STEP  113000 END @ 2016-12-23 20:26:29.335633, training accuracy 1.00000, ave validation accuracy 0.54364
# STEP  114000 END @ 2016-12-23 20:27:21.545799, training accuracy 1.00000, ave validation accuracy 0.54366
# STEP  115000 END @ 2016-12-23 20:28:13.917459, training accuracy 1.00000, ave validation accuracy 0.54360
# STEP  116000 END @ 2016-12-23 20:29:06.200741, training accuracy 1.00000, ave validation accuracy 0.54367
# STEP  117000 END @ 2016-12-23 20:29:58.529815, training accuracy 1.00000, ave validation accuracy 0.54362
# STEP  118000 END @ 2016-12-23 20:30:50.882790, training accuracy 1.00000, ave validation accuracy 0.54347
# STEP  119000 END @ 2016-12-23 20:31:43.236509, training accuracy 1.00000, ave validation accuracy 0.54361
# STEP  120000 END @ 2016-12-23 20:32:35.641862, training accuracy 1.00000, ave validation accuracy 0.54349
# STEP  121000 END @ 2016-12-23 20:33:27.956316, training accuracy 1.00000, ave validation accuracy 0.54355
# STEP  122000 END @ 2016-12-23 20:34:20.177004, training accuracy 1.00000, ave validation accuracy 0.54335
# STEP  123000 END @ 2016-12-23 20:35:12.546588, training accuracy 1.00000, ave validation accuracy 0.54345
# STEP  124000 END @ 2016-12-23 20:36:04.871656, training accuracy 1.00000, ave validation accuracy 0.54369
# STEP  125000 END @ 2016-12-23 20:36:57.393167, training accuracy 1.00000, ave validation accuracy 0.54344
# STEP  126000 END @ 2016-12-23 20:37:49.815015, training accuracy 1.00000, ave validation accuracy 0.54345
# STEP  127000 END @ 2016-12-23 20:38:42.203564, training accuracy 1.00000, ave validation accuracy 0.54339
# STEP  128000 END @ 2016-12-23 20:39:34.558659, training accuracy 1.00000, ave validation accuracy 0.54346
# STEP  129000 END @ 2016-12-23 20:40:27.009628, training accuracy 1.00000, ave validation accuracy 0.54330
# STEP  130000 END @ 2016-12-23 20:41:19.322365, training accuracy 1.00000, ave validation accuracy 0.54320
# STEP  131000 END @ 2016-12-23 20:42:11.648409, training accuracy 1.00000, ave validation accuracy 0.54321
# STEP  132000 END @ 2016-12-23 20:43:04.061096, training accuracy 1.00000, ave validation accuracy 0.54307
# << hourly save at ckpt_model_01_run01/hourly/model-132200 and pickle_model_01_run01 >>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-feafc4fc8124> in <module>()
#       1 #Train the model
# ----> 2 train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#
# /home/kumiko/cifar10/helper_functions.py in train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#     252                                   feed_dict={graph_variables['data']: batch_data, graph_variables['labels']: batch_labels,
#     253                                              graph_variables['keep_prob']: accuracy_log['variables']['dropout_train_keep_prob'], graph_variables['is_training']: True})
# --> 254
#     255             if i % accuracy_log['variables']['log_every'] == 0:
#     256                 writer.add_summary(summary, i)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Test accuracy
test_accuracy(graph_variables, accuracy_log, test_data, test_labels)
# Out:
# << test accuracy 0.54820 >>
