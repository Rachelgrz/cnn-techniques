# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import tensorflow as tf
from helper_functions import *

# %%
#Continueing training?
continued = False
checkpoint_file_to_use = None #Example: 'ckpt_model_01_run01/hourly/model-9350'

#If training from step 0
#############################
naming = 'model_07B_run01'
#############################
variables = {
    'modify_images': True,
    'crop_images': True,
    'enlarge_images': False,
    'before_flatten_image_side_size': 6, #Need to calculate
    'first_hidden_layer_features': 384,
    'weights_stddev': 0.015,
    'biases_initial': 0.1,
    'dropout_train_keep_prob': 0.5,
    'learning_rate_initial': 0.1,
    'learning_rate_decay_steps': int(10000000),
    'learning_rate_decay': 1.0,
    'start_step_early_stopping': 150000,
    'early_stopping_patience': 0.1,
    'batch_size': 200,
    'max_steps': 100000000,
    'average_n_validation_accuracy': 8
}

# %%
#Create accuracy_log to pickle and directories for TensorBoard and checkpoint
accuracy_log = prep_accuracy_log(continued, checkpoint_file_to_use, naming, variables)

# %%
#Get data and labels
(train_data, validation_data, test_data, train_labels, validation_labels, test_labels) = get_data_and_labels(accuracy_log)

# %%
#Build a model
crop_images = accuracy_log['variables']['crop_images']
modify_images = accuracy_log['variables']['modify_images']
weights_stddev = accuracy_log['variables']['weights_stddev']
biases_initial = accuracy_log['variables']['biases_initial']
input_image_side_size = accuracy_log['variables']['input_image_side_size']
crop_to_side_size = accuracy_log['variables']['crop_to_side_size']
before_flatten_image_side_size = accuracy_log['variables']['before_flatten_image_side_size']
first_hidden_layer_features = accuracy_log['variables']['first_hidden_layer_features']
learning_rate_initial = accuracy_log['variables']['learning_rate_initial']
learning_rate_decay_steps = accuracy_log['variables']['learning_rate_decay_steps']
learning_rate_decay = accuracy_log['variables']['learning_rate_decay']

graph = tf.Graph()
with graph.as_default():
    global_step = tf.Variable(0, trainable=False)
    is_training = tf.placeholder(tf.bool)
    keep_prob = tf.placeholder(tf.float32)

    data = tf.placeholder(tf.float32, [None, input_image_side_size, input_image_side_size, 3])
    labels = tf.placeholder(tf.float32, [None, 10])
    
    if crop_images & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    elif (not crop_images) & modify_images:
        data_v2 = tf.cond(is_training, lambda: random_modify_no_crop(data), lambda: tf.identity(data))
    elif crop_images & (not modify_images):
        data_v2 = tf.cond(is_training, lambda: random_crop(data, crop_to_side_size), lambda: crop_center(data, crop_to_side_size))
    else:
        data_v2 = tf.identity(data)

    data_v2 = batch_normalize(data_v2, is_training=is_training, global_step=global_step, scope='bn_data_v2')
    W_conv1 = weight_variable([3, 3, 3, 64], weights_stddev, 'W_conv1')
    b_conv1 = bias_variable(biases_initial, [64], 'b_conv1')
    conv1 = conv2d(data_v2, W_conv1) + b_conv1
    conv1_relu = tf.nn.relu(conv1)
    pool1 = max_pool_3x3_stride2(conv1_relu)
    norm1 = tf.nn.lrn(pool1, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm1 = batch_normalize(norm1, is_training=is_training, global_step=global_step, scope='bn_norm1')
    W_conv2 = weight_variable([3, 3, 64, 64], weights_stddev, 'W_conv2')
    b_conv2 = bias_variable(biases_initial, [64], 'b_conv2')
    conv2 = conv2d(norm1, W_conv2) + b_conv2
    conv2_relu = tf.nn.relu(conv2)
    pool2 = max_pool_3x3_stride2(conv2_relu)
    norm2 = tf.nn.lrn(pool2, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    norm2 = batch_normalize(norm2, is_training=is_training, global_step=global_step, scope='bn_norm2')
    W_conv3 = weight_variable([3, 3, 64, 128], weights_stddev, 'W_conv3')
    b_conv3 = bias_variable(biases_initial, [128], 'b_conv3')
    conv3 = conv2d(norm2, W_conv3) + b_conv3
    conv3_relu = tf.nn.relu(conv3)
    pool3 = max_pool_3x3_stride1(conv3_relu)
    norm3 = tf.nn.lrn(pool3, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)
    
    norm3_flat = tf.reshape(norm3, [-1, before_flatten_image_side_size*before_flatten_image_side_size*128])

    norm3_flat = batch_normalize(norm3_flat, is_training=is_training, global_step=global_step, scope='bn_norm3_flat')
    norm3_flat_drop = tf.nn.dropout(norm3_flat, keep_prob)
    W_fc1 = weight_variable([before_flatten_image_side_size*before_flatten_image_side_size*128, first_hidden_layer_features], weights_stddev, 'W_fc1')
    b_fc1 = bias_variable(biases_initial, [first_hidden_layer_features], 'b_fc1')
    fc1 = tf.matmul(norm3_flat_drop, W_fc1) + b_fc1
    fc1_relu = tf.nn.relu(fc1)

    fc1_relu = batch_normalize(fc1_relu, is_training=is_training, global_step=global_step, scope='bn_fc1_relu')    
    fc1_relu_drop = tf.nn.dropout(fc1_relu, keep_prob)
    W_fc2 = weight_variable([first_hidden_layer_features, int(first_hidden_layer_features/2)], weights_stddev, 'W_fc2')
    b_fc2 = bias_variable(biases_initial, [first_hidden_layer_features/2], 'b_fc2')
    fc2 = tf.matmul(fc1_relu_drop, W_fc2) + b_fc2
    fc2_relu = tf.nn.relu(fc2)

    fc2_relu = batch_normalize(fc2_relu, is_training=is_training, global_step=global_step, scope='bn_fc2_relu')
    fc2_relu_drop = tf.nn.dropout(fc2_relu, keep_prob)
    W_fc3 = weight_variable([int(first_hidden_layer_features/2), 10], weights_stddev, 'W_fc3')
    b_fc3 = bias_variable(biases_initial, [10], 'b_fc3')
    logits = tf.matmul(fc2_relu_drop, W_fc3) + b_fc3

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, labels))
    
    learning_rate = tf.train.exponential_decay(learning_rate_initial, global_step, learning_rate_decay_steps, 
                                               learning_rate_decay, staircase=True)
    
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
    correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    tf.summary.scalar('loss', loss)
    tf.summary.scalar('learning_rate', learning_rate)
    tf.summary.scalar('training_accuracy', accuracy)
    
    for var in tf.trainable_variables():
        tf.summary.histogram(var.op.name, var)
    
    summarizer = tf.summary.merge_all()
    
graph_variables = {'graph': graph, 
                   'optimizer': optimizer, 
                   'summarizer': summarizer, 
                   'data': data, 
                   'labels': labels, 
                   'keep_prob': keep_prob, 
                   'is_training': is_training, 
                   'correct_prediction': correct_prediction,
                   'accuracy': accuracy}

# %%
#Train the model
train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
# Out:
# TRAINING   START @ 2016-12-25 12:38:01.041517
# << best model so far is saved in ckpt_model_07B_run01/best/model-0 >> ave validation accuracy 0.10140
# STEP       0 END @ 2016-12-25 12:38:12.128706, training accuracy 0.10500, ave validation accuracy 0.10140
# << best model so far is saved in ckpt_model_07B_run01/best/model-100 >> ave validation accuracy 0.12570
# STEP    1000 END @ 2016-12-25 12:40:26.704082, training accuracy 0.10000, ave validation accuracy 0.10421
# << best model so far is saved in ckpt_model_07B_run01/best/model-1500 >> ave validation accuracy 0.13217
# << best model so far is saved in ckpt_model_07B_run01/best/model-1600 >> ave validation accuracy 0.14802
# << best model so far is saved in ckpt_model_07B_run01/best/model-1700 >> ave validation accuracy 0.18505
# << best model so far is saved in ckpt_model_07B_run01/best/model-1800 >> ave validation accuracy 0.21882
# << best model so far is saved in ckpt_model_07B_run01/best/model-1900 >> ave validation accuracy 0.25524
# << best model so far is saved in ckpt_model_07B_run01/best/model-2000 >> ave validation accuracy 0.30234
# STEP    2000 END @ 2016-12-25 12:43:10.432379, training accuracy 0.46000, ave validation accuracy 0.30234
# << best model so far is saved in ckpt_model_07B_run01/best/model-2100 >> ave validation accuracy 0.35527
# << best model so far is saved in ckpt_model_07B_run01/best/model-2200 >> ave validation accuracy 0.40074
# << best model so far is saved in ckpt_model_07B_run01/best/model-2300 >> ave validation accuracy 0.44845
# << best model so far is saved in ckpt_model_07B_run01/best/model-2400 >> ave validation accuracy 0.50181
# << best model so far is saved in ckpt_model_07B_run01/best/model-2500 >> ave validation accuracy 0.53647
# << best model so far is saved in ckpt_model_07B_run01/best/model-2600 >> ave validation accuracy 0.57656
# << best model so far is saved in ckpt_model_07B_run01/best/model-2700 >> ave validation accuracy 0.61409
# << best model so far is saved in ckpt_model_07B_run01/best/model-2800 >> ave validation accuracy 0.64212
# << best model so far is saved in ckpt_model_07B_run01/best/model-2900 >> ave validation accuracy 0.66371
# << best model so far is saved in ckpt_model_07B_run01/best/model-3000 >> ave validation accuracy 0.68205
# STEP    3000 END @ 2016-12-25 12:46:13.595086, training accuracy 0.73500, ave validation accuracy 0.68205
# << best model so far is saved in ckpt_model_07B_run01/best/model-3100 >> ave validation accuracy 0.69874
# << best model so far is saved in ckpt_model_07B_run01/best/model-3200 >> ave validation accuracy 0.70849
# << best model so far is saved in ckpt_model_07B_run01/best/model-3300 >> ave validation accuracy 0.71735
# << best model so far is saved in ckpt_model_07B_run01/best/model-3400 >> ave validation accuracy 0.72372
# << best model so far is saved in ckpt_model_07B_run01/best/model-3500 >> ave validation accuracy 0.73129
# << best model so far is saved in ckpt_model_07B_run01/best/model-3600 >> ave validation accuracy 0.73511
# << best model so far is saved in ckpt_model_07B_run01/best/model-3700 >> ave validation accuracy 0.73919
# << best model so far is saved in ckpt_model_07B_run01/best/model-3800 >> ave validation accuracy 0.74530
# << best model so far is saved in ckpt_model_07B_run01/best/model-3900 >> ave validation accuracy 0.74735
# << best model so far is saved in ckpt_model_07B_run01/best/model-4000 >> ave validation accuracy 0.75132
# STEP    4000 END @ 2016-12-25 12:49:15.417979, training accuracy 0.78000, ave validation accuracy 0.75132
# << best model so far is saved in ckpt_model_07B_run01/best/model-4100 >> ave validation accuracy 0.75201
# << best model so far is saved in ckpt_model_07B_run01/best/model-4200 >> ave validation accuracy 0.75455
# << best model so far is saved in ckpt_model_07B_run01/best/model-4300 >> ave validation accuracy 0.75632
# << best model so far is saved in ckpt_model_07B_run01/best/model-4400 >> ave validation accuracy 0.75863
# << best model so far is saved in ckpt_model_07B_run01/best/model-4500 >> ave validation accuracy 0.75999
# << best model so far is saved in ckpt_model_07B_run01/best/model-4600 >> ave validation accuracy 0.76289
# << best model so far is saved in ckpt_model_07B_run01/best/model-4700 >> ave validation accuracy 0.76576
# << best model so far is saved in ckpt_model_07B_run01/best/model-4800 >> ave validation accuracy 0.76615
# << best model so far is saved in ckpt_model_07B_run01/best/model-4900 >> ave validation accuracy 0.76695
# << best model so far is saved in ckpt_model_07B_run01/best/model-5000 >> ave validation accuracy 0.76713
# STEP    5000 END @ 2016-12-25 12:52:16.036782, training accuracy 0.80000, ave validation accuracy 0.76713
# << best model so far is saved in ckpt_model_07B_run01/best/model-5100 >> ave validation accuracy 0.76838
# << best model so far is saved in ckpt_model_07B_run01/best/model-5200 >> ave validation accuracy 0.77001
# << best model so far is saved in ckpt_model_07B_run01/best/model-5300 >> ave validation accuracy 0.77089
# << best model so far is saved in ckpt_model_07B_run01/best/model-5400 >> ave validation accuracy 0.77124
# << best model so far is saved in ckpt_model_07B_run01/best/model-5500 >> ave validation accuracy 0.77124
# << best model so far is saved in ckpt_model_07B_run01/best/model-5600 >> ave validation accuracy 0.77278
# << best model so far is saved in ckpt_model_07B_run01/best/model-5700 >> ave validation accuracy 0.77513
# << best model so far is saved in ckpt_model_07B_run01/best/model-5800 >> ave validation accuracy 0.77790
# << best model so far is saved in ckpt_model_07B_run01/best/model-5900 >> ave validation accuracy 0.77855
# << best model so far is saved in ckpt_model_07B_run01/best/model-6000 >> ave validation accuracy 0.77970
# STEP    6000 END @ 2016-12-25 12:55:19.319436, training accuracy 0.81500, ave validation accuracy 0.77970
# << best model so far is saved in ckpt_model_07B_run01/best/model-6100 >> ave validation accuracy 0.78203
# << best model so far is saved in ckpt_model_07B_run01/best/model-6200 >> ave validation accuracy 0.78335
# << best model so far is saved in ckpt_model_07B_run01/best/model-6300 >> ave validation accuracy 0.78486
# << best model so far is saved in ckpt_model_07B_run01/best/model-6400 >> ave validation accuracy 0.78611
# << best model so far is saved in ckpt_model_07B_run01/best/model-6500 >> ave validation accuracy 0.78668
# << best model so far is saved in ckpt_model_07B_run01/best/model-6700 >> ave validation accuracy 0.78735
# << best model so far is saved in ckpt_model_07B_run01/best/model-6800 >> ave validation accuracy 0.78781
# << best model so far is saved in ckpt_model_07B_run01/best/model-6900 >> ave validation accuracy 0.78844
# << best model so far is saved in ckpt_model_07B_run01/best/model-7000 >> ave validation accuracy 0.78900
# STEP    7000 END @ 2016-12-25 12:58:17.580688, training accuracy 0.85000, ave validation accuracy 0.78900
# << best model so far is saved in ckpt_model_07B_run01/best/model-7100 >> ave validation accuracy 0.78949
# << best model so far is saved in ckpt_model_07B_run01/best/model-7200 >> ave validation accuracy 0.79031
# << best model so far is saved in ckpt_model_07B_run01/best/model-7300 >> ave validation accuracy 0.79121
# << best model so far is saved in ckpt_model_07B_run01/best/model-7500 >> ave validation accuracy 0.79196
# << best model so far is saved in ckpt_model_07B_run01/best/model-7600 >> ave validation accuracy 0.79235
# << best model so far is saved in ckpt_model_07B_run01/best/model-7700 >> ave validation accuracy 0.79255
# << best model so far is saved in ckpt_model_07B_run01/best/model-7800 >> ave validation accuracy 0.79295
# << best model so far is saved in ckpt_model_07B_run01/best/model-7900 >> ave validation accuracy 0.79371
# << best model so far is saved in ckpt_model_07B_run01/best/model-8000 >> ave validation accuracy 0.79378
# STEP    8000 END @ 2016-12-25 13:01:12.962898, training accuracy 0.85000, ave validation accuracy 0.79378
# << best model so far is saved in ckpt_model_07B_run01/best/model-8200 >> ave validation accuracy 0.79553
# << best model so far is saved in ckpt_model_07B_run01/best/model-8300 >> ave validation accuracy 0.79560
# << best model so far is saved in ckpt_model_07B_run01/best/model-8400 >> ave validation accuracy 0.79598
# << best model so far is saved in ckpt_model_07B_run01/best/model-8500 >> ave validation accuracy 0.79643
# << best model so far is saved in ckpt_model_07B_run01/best/model-8700 >> ave validation accuracy 0.79680
# STEP    9000 END @ 2016-12-25 13:03:47.532999, training accuracy 0.89500, ave validation accuracy 0.79669
# << best model so far is saved in ckpt_model_07B_run01/best/model-9200 >> ave validation accuracy 0.79694
# << best model so far is saved in ckpt_model_07B_run01/best/model-9300 >> ave validation accuracy 0.79751
# << best model so far is saved in ckpt_model_07B_run01/best/model-9400 >> ave validation accuracy 0.79899
# << best model so far is saved in ckpt_model_07B_run01/best/model-9500 >> ave validation accuracy 0.79919
# << best model so far is saved in ckpt_model_07B_run01/best/model-9600 >> ave validation accuracy 0.80071
# << best model so far is saved in ckpt_model_07B_run01/best/model-9700 >> ave validation accuracy 0.80139
# << best model so far is saved in ckpt_model_07B_run01/best/model-9800 >> ave validation accuracy 0.80275
# << best model so far is saved in ckpt_model_07B_run01/best/model-9900 >> ave validation accuracy 0.80426
# << best model so far is saved in ckpt_model_07B_run01/best/model-10000 >> ave validation accuracy 0.80534
# STEP   10000 END @ 2016-12-25 13:06:44.365220, training accuracy 0.84500, ave validation accuracy 0.80534
# << best model so far is saved in ckpt_model_07B_run01/best/model-10100 >> ave validation accuracy 0.80583
# << best model so far is saved in ckpt_model_07B_run01/best/model-10200 >> ave validation accuracy 0.80609
# << best model so far is saved in ckpt_model_07B_run01/best/model-10300 >> ave validation accuracy 0.80726
# << best model so far is saved in ckpt_model_07B_run01/best/model-10400 >> ave validation accuracy 0.80793
# << best model so far is saved in ckpt_model_07B_run01/best/model-10800 >> ave validation accuracy 0.80885
# << best model so far is saved in ckpt_model_07B_run01/best/model-10900 >> ave validation accuracy 0.80949
# << best model so far is saved in ckpt_model_07B_run01/best/model-11000 >> ave validation accuracy 0.81023
# STEP   11000 END @ 2016-12-25 13:09:30.765554, training accuracy 0.86000, ave validation accuracy 0.81023
# << best model so far is saved in ckpt_model_07B_run01/best/model-11200 >> ave validation accuracy 0.81069
# << best model so far is saved in ckpt_model_07B_run01/best/model-11300 >> ave validation accuracy 0.81173
# << best model so far is saved in ckpt_model_07B_run01/best/model-11900 >> ave validation accuracy 0.81243
# << best model so far is saved in ckpt_model_07B_run01/best/model-12000 >> ave validation accuracy 0.81266
# STEP   12000 END @ 2016-12-25 13:12:00.415864, training accuracy 0.88000, ave validation accuracy 0.81266
# << best model so far is saved in ckpt_model_07B_run01/best/model-12100 >> ave validation accuracy 0.81304
# << best model so far is saved in ckpt_model_07B_run01/best/model-12200 >> ave validation accuracy 0.81409
# << best model so far is saved in ckpt_model_07B_run01/best/model-12300 >> ave validation accuracy 0.81508
# << best model so far is saved in ckpt_model_07B_run01/best/model-12400 >> ave validation accuracy 0.81576
# << best model so far is saved in ckpt_model_07B_run01/best/model-12500 >> ave validation accuracy 0.81655
# << best model so far is saved in ckpt_model_07B_run01/best/model-12900 >> ave validation accuracy 0.81743
# << best model so far is saved in ckpt_model_07B_run01/best/model-13000 >> ave validation accuracy 0.81798
# STEP   13000 END @ 2016-12-25 13:14:44.986728, training accuracy 0.90500, ave validation accuracy 0.81798
# << best model so far is saved in ckpt_model_07B_run01/best/model-13300 >> ave validation accuracy 0.81816
# << best model so far is saved in ckpt_model_07B_run01/best/model-13400 >> ave validation accuracy 0.81885
# << best model so far is saved in ckpt_model_07B_run01/best/model-13900 >> ave validation accuracy 0.81931
# << best model so far is saved in ckpt_model_07B_run01/best/model-14000 >> ave validation accuracy 0.81945
# STEP   14000 END @ 2016-12-25 13:17:14.090614, training accuracy 0.87500, ave validation accuracy 0.81945
# << best model so far is saved in ckpt_model_07B_run01/best/model-14300 >> ave validation accuracy 0.81946
# << best model so far is saved in ckpt_model_07B_run01/best/model-14400 >> ave validation accuracy 0.82009
# << best model so far is saved in ckpt_model_07B_run01/best/model-14500 >> ave validation accuracy 0.82094
# << best model so far is saved in ckpt_model_07B_run01/best/model-14900 >> ave validation accuracy 0.82135
# << best model so far is saved in ckpt_model_07B_run01/best/model-15000 >> ave validation accuracy 0.82194
# STEP   15000 END @ 2016-12-25 13:19:48.590825, training accuracy 0.87500, ave validation accuracy 0.82194
# << best model so far is saved in ckpt_model_07B_run01/best/model-15200 >> ave validation accuracy 0.82209
# << best model so far is saved in ckpt_model_07B_run01/best/model-15500 >> ave validation accuracy 0.82220
# << best model so far is saved in ckpt_model_07B_run01/best/model-15700 >> ave validation accuracy 0.82241
# << best model so far is saved in ckpt_model_07B_run01/best/model-15800 >> ave validation accuracy 0.82263
# << best model so far is saved in ckpt_model_07B_run01/best/model-15900 >> ave validation accuracy 0.82280
# << best model so far is saved in ckpt_model_07B_run01/best/model-16000 >> ave validation accuracy 0.82284
# STEP   16000 END @ 2016-12-25 13:22:28.143264, training accuracy 0.88500, ave validation accuracy 0.82284
# << best model so far is saved in ckpt_model_07B_run01/best/model-16100 >> ave validation accuracy 0.82339
# << best model so far is saved in ckpt_model_07B_run01/best/model-16200 >> ave validation accuracy 0.82351
# << best model so far is saved in ckpt_model_07B_run01/best/model-16300 >> ave validation accuracy 0.82405
# << best model so far is saved in ckpt_model_07B_run01/best/model-16400 >> ave validation accuracy 0.82423
# STEP   17000 END @ 2016-12-25 13:24:57.166626, training accuracy 0.90000, ave validation accuracy 0.82403
# << best model so far is saved in ckpt_model_07B_run01/best/model-17500 >> ave validation accuracy 0.82438
# << best model so far is saved in ckpt_model_07B_run01/best/model-17700 >> ave validation accuracy 0.82473
# << best model so far is saved in ckpt_model_07B_run01/best/model-17800 >> ave validation accuracy 0.82530
# << best model so far is saved in ckpt_model_07B_run01/best/model-17900 >> ave validation accuracy 0.82690
# << best model so far is saved in ckpt_model_07B_run01/best/model-18000 >> ave validation accuracy 0.82728
# STEP   18000 END @ 2016-12-25 13:27:30.814920, training accuracy 0.91000, ave validation accuracy 0.82728
# << best model so far is saved in ckpt_model_07B_run01/best/model-18100 >> ave validation accuracy 0.82729
# << best model so far is saved in ckpt_model_07B_run01/best/model-18200 >> ave validation accuracy 0.82790
# STEP   19000 END @ 2016-12-25 13:29:48.808807, training accuracy 0.90000, ave validation accuracy 0.82581
# STEP   20000 END @ 2016-12-25 13:31:55.252436, training accuracy 0.87000, ave validation accuracy 0.82728
# << best model so far is saved in ckpt_model_07B_run01/best/model-20100 >> ave validation accuracy 0.82809
# << best model so far is saved in ckpt_model_07B_run01/best/model-20200 >> ave validation accuracy 0.82825
# << best model so far is saved in ckpt_model_07B_run01/best/model-20300 >> ave validation accuracy 0.82915
# << best model so far is saved in ckpt_model_07B_run01/best/model-20400 >> ave validation accuracy 0.82929
# << best model so far is saved in ckpt_model_07B_run01/best/model-20500 >> ave validation accuracy 0.82979
# << best model so far is saved in ckpt_model_07B_run01/best/model-20600 >> ave validation accuracy 0.83028
# << best model so far is saved in ckpt_model_07B_run01/best/model-20700 >> ave validation accuracy 0.83060
# << best model so far is saved in ckpt_model_07B_run01/best/model-20800 >> ave validation accuracy 0.83103
# << best model so far is saved in ckpt_model_07B_run01/best/model-20900 >> ave validation accuracy 0.83126
# << best model so far is saved in ckpt_model_07B_run01/best/model-21000 >> ave validation accuracy 0.83188
# STEP   21000 END @ 2016-12-25 13:34:56.822695, training accuracy 0.87000, ave validation accuracy 0.83188
# << best model so far is saved in ckpt_model_07B_run01/best/model-21300 >> ave validation accuracy 0.83189
# << best model so far is saved in ckpt_model_07B_run01/best/model-21400 >> ave validation accuracy 0.83221
# << best model so far is saved in ckpt_model_07B_run01/best/model-21600 >> ave validation accuracy 0.83238
# STEP   22000 END @ 2016-12-25 13:37:18.584344, training accuracy 0.90500, ave validation accuracy 0.83215
# << best model so far is saved in ckpt_model_07B_run01/best/model-22300 >> ave validation accuracy 0.83245
# << hourly save at ckpt_model_07B_run01/hourly/model-22400 and pickle_model_07B_run01 >>
# << best model so far is saved in ckpt_model_07B_run01/best/model-22500 >> ave validation accuracy 0.83274
# << best model so far is saved in ckpt_model_07B_run01/best/model-22700 >> ave validation accuracy 0.83338
# << best model so far is saved in ckpt_model_07B_run01/best/model-22800 >> ave validation accuracy 0.83356
# << best model so far is saved in ckpt_model_07B_run01/best/model-22900 >> ave validation accuracy 0.83361
# STEP   23000 END @ 2016-12-25 13:39:56.798235, training accuracy 0.88500, ave validation accuracy 0.83300
# << best model so far is saved in ckpt_model_07B_run01/best/model-23800 >> ave validation accuracy 0.83443
# << best model so far is saved in ckpt_model_07B_run01/best/model-23900 >> ave validation accuracy 0.83485
# << best model so far is saved in ckpt_model_07B_run01/best/model-24000 >> ave validation accuracy 0.83558
# STEP   24000 END @ 2016-12-25 13:42:19.810337, training accuracy 0.91500, ave validation accuracy 0.83558
# << best model so far is saved in ckpt_model_07B_run01/best/model-24100 >> ave validation accuracy 0.83609
# << best model so far is saved in ckpt_model_07B_run01/best/model-24200 >> ave validation accuracy 0.83719
# STEP   25000 END @ 2016-12-25 13:44:36.289627, training accuracy 0.87500, ave validation accuracy 0.83601
# << best model so far is saved in ckpt_model_07B_run01/best/model-26000 >> ave validation accuracy 0.83758
# STEP   26000 END @ 2016-12-25 13:46:47.886674, training accuracy 0.89500, ave validation accuracy 0.83758
# << best model so far is saved in ckpt_model_07B_run01/best/model-26100 >> ave validation accuracy 0.83818
# << best model so far is saved in ckpt_model_07B_run01/best/model-26500 >> ave validation accuracy 0.83819
# << best model so far is saved in ckpt_model_07B_run01/best/model-26600 >> ave validation accuracy 0.83906
# << best model so far is saved in ckpt_model_07B_run01/best/model-26700 >> ave validation accuracy 0.83908
# STEP   27000 END @ 2016-12-25 13:49:16.009868, training accuracy 0.88000, ave validation accuracy 0.83843
# << best model so far is saved in ckpt_model_07B_run01/best/model-27300 >> ave validation accuracy 0.83939
# << best model so far is saved in ckpt_model_07B_run01/best/model-27600 >> ave validation accuracy 0.83958
# << best model so far is saved in ckpt_model_07B_run01/best/model-27900 >> ave validation accuracy 0.83983
# STEP   28000 END @ 2016-12-25 13:51:39.162746, training accuracy 0.91500, ave validation accuracy 0.83900
# STEP   29000 END @ 2016-12-25 13:53:45.368561, training accuracy 0.90500, ave validation accuracy 0.83940
# << best model so far is saved in ckpt_model_07B_run01/best/model-29100 >> ave validation accuracy 0.83996
# << best model so far is saved in ckpt_model_07B_run01/best/model-29500 >> ave validation accuracy 0.84046
# << best model so far is saved in ckpt_model_07B_run01/best/model-29700 >> ave validation accuracy 0.84063
# << best model so far is saved in ckpt_model_07B_run01/best/model-29800 >> ave validation accuracy 0.84066
# << best model so far is saved in ckpt_model_07B_run01/best/model-29900 >> ave validation accuracy 0.84106
# << best model so far is saved in ckpt_model_07B_run01/best/model-30000 >> ave validation accuracy 0.84144
# STEP   30000 END @ 2016-12-25 13:56:24.870300, training accuracy 0.90000, ave validation accuracy 0.84144
# << best model so far is saved in ckpt_model_07B_run01/best/model-30900 >> ave validation accuracy 0.84170
# << best model so far is saved in ckpt_model_07B_run01/best/model-31000 >> ave validation accuracy 0.84190
# STEP   31000 END @ 2016-12-25 13:58:42.705910, training accuracy 0.88000, ave validation accuracy 0.84190
# << best model so far is saved in ckpt_model_07B_run01/best/model-31500 >> ave validation accuracy 0.84211
# STEP   32000 END @ 2016-12-25 14:00:54.021068, training accuracy 0.89500, ave validation accuracy 0.84163
# << best model so far is saved in ckpt_model_07B_run01/best/model-32300 >> ave validation accuracy 0.84218
# << best model so far is saved in ckpt_model_07B_run01/best/model-32400 >> ave validation accuracy 0.84309
# << best model so far is saved in ckpt_model_07B_run01/best/model-32500 >> ave validation accuracy 0.84383
# << best model so far is saved in ckpt_model_07B_run01/best/model-32600 >> ave validation accuracy 0.84420
# << best model so far is saved in ckpt_model_07B_run01/best/model-32700 >> ave validation accuracy 0.84425
# << best model so far is saved in ckpt_model_07B_run01/best/model-32800 >> ave validation accuracy 0.84511
# << best model so far is saved in ckpt_model_07B_run01/best/model-32900 >> ave validation accuracy 0.84529
# << best model so far is saved in ckpt_model_07B_run01/best/model-33000 >> ave validation accuracy 0.84533
# STEP   33000 END @ 2016-12-25 14:03:43.762587, training accuracy 0.93000, ave validation accuracy 0.84533
# STEP   34000 END @ 2016-12-25 14:05:49.934964, training accuracy 0.90500, ave validation accuracy 0.84275
# << best model so far is saved in ckpt_model_07B_run01/best/model-34800 >> ave validation accuracy 0.84625
# << best model so far is saved in ckpt_model_07B_run01/best/model-34900 >> ave validation accuracy 0.84695
# STEP   35000 END @ 2016-12-25 14:08:06.496031, training accuracy 0.88500, ave validation accuracy 0.84685
# STEP   36000 END @ 2016-12-25 14:10:12.704698, training accuracy 0.90500, ave validation accuracy 0.84459
# STEP   37000 END @ 2016-12-25 14:12:18.750576, training accuracy 0.91500, ave validation accuracy 0.84524
# << best model so far is saved in ckpt_model_07B_run01/best/model-37700 >> ave validation accuracy 0.84718
# << best model so far is saved in ckpt_model_07B_run01/best/model-37800 >> ave validation accuracy 0.84753
# << best model so far is saved in ckpt_model_07B_run01/best/model-37900 >> ave validation accuracy 0.84778
# STEP   38000 END @ 2016-12-25 14:14:41.701265, training accuracy 0.89500, ave validation accuracy 0.84773
# << best model so far is saved in ckpt_model_07B_run01/best/model-38100 >> ave validation accuracy 0.84808
# << best model so far is saved in ckpt_model_07B_run01/best/model-38500 >> ave validation accuracy 0.84836
# STEP   39000 END @ 2016-12-25 14:16:58.119082, training accuracy 0.90500, ave validation accuracy 0.84653
# STEP   40000 END @ 2016-12-25 14:19:04.395919, training accuracy 0.90500, ave validation accuracy 0.84794
# << best model so far is saved in ckpt_model_07B_run01/best/model-40100 >> ave validation accuracy 0.84900
# << best model so far is saved in ckpt_model_07B_run01/best/model-40200 >> ave validation accuracy 0.84921
# << best model so far is saved in ckpt_model_07B_run01/best/model-40300 >> ave validation accuracy 0.84938
# << best model so far is saved in ckpt_model_07B_run01/best/model-40400 >> ave validation accuracy 0.84990
# << best model so far is saved in ckpt_model_07B_run01/best/model-40500 >> ave validation accuracy 0.84993
# STEP   41000 END @ 2016-12-25 14:21:38.842682, training accuracy 0.89000, ave validation accuracy 0.84873
# STEP   42000 END @ 2016-12-25 14:23:44.887992, training accuracy 0.93500, ave validation accuracy 0.84771
# << best model so far is saved in ckpt_model_07B_run01/best/model-42600 >> ave validation accuracy 0.85043
# << best model so far is saved in ckpt_model_07B_run01/best/model-42700 >> ave validation accuracy 0.85053
# STEP   43000 END @ 2016-12-25 14:26:02.814114, training accuracy 0.92500, ave validation accuracy 0.85008
# STEP   44000 END @ 2016-12-25 14:28:09.046628, training accuracy 0.93500, ave validation accuracy 0.84836
# STEP   45000 END @ 2016-12-25 14:30:15.245499, training accuracy 0.91500, ave validation accuracy 0.85040
# STEP   46000 END @ 2016-12-25 14:32:21.266685, training accuracy 0.95000, ave validation accuracy 0.85014
# << best model so far is saved in ckpt_model_07B_run01/best/model-46100 >> ave validation accuracy 0.85071
# << best model so far is saved in ckpt_model_07B_run01/best/model-46200 >> ave validation accuracy 0.85074
# STEP   47000 END @ 2016-12-25 14:34:37.705037, training accuracy 0.89000, ave validation accuracy 0.84978
# << best model so far is saved in ckpt_model_07B_run01/best/model-47900 >> ave validation accuracy 0.85099
# STEP   48000 END @ 2016-12-25 14:36:49.036317, training accuracy 0.95000, ave validation accuracy 0.85096
# << best model so far is saved in ckpt_model_07B_run01/best/model-48100 >> ave validation accuracy 0.85106
# << best model so far is saved in ckpt_model_07B_run01/best/model-48200 >> ave validation accuracy 0.85120
# << best model so far is saved in ckpt_model_07B_run01/best/model-48300 >> ave validation accuracy 0.85145
# << hourly save at ckpt_model_07B_run01/hourly/model-48600 and pickle_model_07B_run01 >>
# << best model so far is saved in ckpt_model_07B_run01/best/model-48700 >> ave validation accuracy 0.85180
# << best model so far is saved in ckpt_model_07B_run01/best/model-48800 >> ave validation accuracy 0.85243
# << best model so far is saved in ckpt_model_07B_run01/best/model-48900 >> ave validation accuracy 0.85249
# << best model so far is saved in ckpt_model_07B_run01/best/model-49000 >> ave validation accuracy 0.85279
# STEP   49000 END @ 2016-12-25 14:39:38.904159, training accuracy 0.90500, ave validation accuracy 0.85279
# << best model so far is saved in ckpt_model_07B_run01/best/model-49100 >> ave validation accuracy 0.85350
# << best model so far is saved in ckpt_model_07B_run01/best/model-49200 >> ave validation accuracy 0.85416
# STEP   50000 END @ 2016-12-25 14:41:56.729124, training accuracy 0.95500, ave validation accuracy 0.85209
# << best model so far is saved in ckpt_model_07B_run01/best/model-50600 >> ave validation accuracy 0.85428
# << best model so far is saved in ckpt_model_07B_run01/best/model-50800 >> ave validation accuracy 0.85470
# STEP   51000 END @ 2016-12-25 14:44:13.228744, training accuracy 0.92500, ave validation accuracy 0.85431
# << best model so far is saved in ckpt_model_07B_run01/best/model-52000 >> ave validation accuracy 0.85493
# STEP   52000 END @ 2016-12-25 14:46:25.927775, training accuracy 0.91500, ave validation accuracy 0.85493
# << best model so far is saved in ckpt_model_07B_run01/best/model-52100 >> ave validation accuracy 0.85525
# << best model so far is saved in ckpt_model_07B_run01/best/model-52200 >> ave validation accuracy 0.85536
# << best model so far is saved in ckpt_model_07B_run01/best/model-52400 >> ave validation accuracy 0.85538
# STEP   53000 END @ 2016-12-25 14:48:48.833915, training accuracy 0.90000, ave validation accuracy 0.85464
# << best model so far is saved in ckpt_model_07B_run01/best/model-53400 >> ave validation accuracy 0.85570
# << best model so far is saved in ckpt_model_07B_run01/best/model-53500 >> ave validation accuracy 0.85595
# STEP   54000 END @ 2016-12-25 14:51:05.065752, training accuracy 0.91500, ave validation accuracy 0.85504
# STEP   55000 END @ 2016-12-25 14:53:11.337363, training accuracy 0.92500, ave validation accuracy 0.85549
# STEP   56000 END @ 2016-12-25 14:55:17.471363, training accuracy 0.93500, ave validation accuracy 0.85461
# << best model so far is saved in ckpt_model_07B_run01/best/model-56600 >> ave validation accuracy 0.85620
# << best model so far is saved in ckpt_model_07B_run01/best/model-56900 >> ave validation accuracy 0.85644
# << best model so far is saved in ckpt_model_07B_run01/best/model-57000 >> ave validation accuracy 0.85653
# STEP   57000 END @ 2016-12-25 14:57:40.097541, training accuracy 0.93500, ave validation accuracy 0.85653
# STEP   58000 END @ 2016-12-25 14:59:46.311324, training accuracy 0.95500, ave validation accuracy 0.85611
# << best model so far is saved in ckpt_model_07B_run01/best/model-58500 >> ave validation accuracy 0.85663
# << best model so far is saved in ckpt_model_07B_run01/best/model-58600 >> ave validation accuracy 0.85720
# << best model so far is saved in ckpt_model_07B_run01/best/model-58900 >> ave validation accuracy 0.85721
# << best model so far is saved in ckpt_model_07B_run01/best/model-59000 >> ave validation accuracy 0.85725
# STEP   59000 END @ 2016-12-25 15:02:14.291350, training accuracy 0.97500, ave validation accuracy 0.85725
# << best model so far is saved in ckpt_model_07B_run01/best/model-59100 >> ave validation accuracy 0.85743
# << best model so far is saved in ckpt_model_07B_run01/best/model-59200 >> ave validation accuracy 0.85744
# << best model so far is saved in ckpt_model_07B_run01/best/model-59300 >> ave validation accuracy 0.85745
# << best model so far is saved in ckpt_model_07B_run01/best/model-59600 >> ave validation accuracy 0.85751
# STEP   60000 END @ 2016-12-25 15:04:42.245152, training accuracy 0.92000, ave validation accuracy 0.85700
# << best model so far is saved in ckpt_model_07B_run01/best/model-60300 >> ave validation accuracy 0.85763
# << best model so far is saved in ckpt_model_07B_run01/best/model-60600 >> ave validation accuracy 0.85781
# << best model so far is saved in ckpt_model_07B_run01/best/model-60700 >> ave validation accuracy 0.85800
# STEP   61000 END @ 2016-12-25 15:07:05.180716, training accuracy 0.97000, ave validation accuracy 0.85755
# << best model so far is saved in ckpt_model_07B_run01/best/model-61200 >> ave validation accuracy 0.85800
# STEP   62000 END @ 2016-12-25 15:09:16.473852, training accuracy 0.94000, ave validation accuracy 0.85656
# << best model so far is saved in ckpt_model_07B_run01/best/model-62300 >> ave validation accuracy 0.85820
# << best model so far is saved in ckpt_model_07B_run01/best/model-62400 >> ave validation accuracy 0.85848
# << best model so far is saved in ckpt_model_07B_run01/best/model-62600 >> ave validation accuracy 0.85854
# << best model so far is saved in ckpt_model_07B_run01/best/model-62700 >> ave validation accuracy 0.85868
# << best model so far is saved in ckpt_model_07B_run01/best/model-62800 >> ave validation accuracy 0.85889
# STEP   63000 END @ 2016-12-25 15:11:51.018331, training accuracy 0.95000, ave validation accuracy 0.85804
# << best model so far is saved in ckpt_model_07B_run01/best/model-64000 >> ave validation accuracy 0.85955
# STEP   64000 END @ 2016-12-25 15:14:02.537912, training accuracy 0.96000, ave validation accuracy 0.85955
# << best model so far is saved in ckpt_model_07B_run01/best/model-64100 >> ave validation accuracy 0.85968
# STEP   65000 END @ 2016-12-25 15:16:13.832986, training accuracy 0.95500, ave validation accuracy 0.85809
# STEP   66000 END @ 2016-12-25 15:18:20.026775, training accuracy 0.94000, ave validation accuracy 0.85941
# << best model so far is saved in ckpt_model_07B_run01/best/model-66800 >> ave validation accuracy 0.86026
# << best model so far is saved in ckpt_model_07B_run01/best/model-66900 >> ave validation accuracy 0.86113
# STEP   67000 END @ 2016-12-25 15:20:36.537093, training accuracy 0.92500, ave validation accuracy 0.86105
# << best model so far is saved in ckpt_model_07B_run01/best/model-67200 >> ave validation accuracy 0.86144
# << best model so far is saved in ckpt_model_07B_run01/best/model-67300 >> ave validation accuracy 0.86159
# STEP   68000 END @ 2016-12-25 15:22:54.296778, training accuracy 0.93000, ave validation accuracy 0.86049
# << best model so far is saved in ckpt_model_07B_run01/best/model-68400 >> ave validation accuracy 0.86189
# << best model so far is saved in ckpt_model_07B_run01/best/model-68900 >> ave validation accuracy 0.86194
# STEP   69000 END @ 2016-12-25 15:25:12.182938, training accuracy 0.94000, ave validation accuracy 0.86185
# STEP   70000 END @ 2016-12-25 15:27:18.361057, training accuracy 0.94500, ave validation accuracy 0.85906
# STEP   71000 END @ 2016-12-25 15:29:24.545276, training accuracy 0.93500, ave validation accuracy 0.86025
# STEP   72000 END @ 2016-12-25 15:31:30.813031, training accuracy 0.91500, ave validation accuracy 0.86130
# << best model so far is saved in ckpt_model_07B_run01/best/model-72400 >> ave validation accuracy 0.86240
# << best model so far is saved in ckpt_model_07B_run01/best/model-72500 >> ave validation accuracy 0.86263
# << best model so far is saved in ckpt_model_07B_run01/best/model-72600 >> ave validation accuracy 0.86296
# << best model so far is saved in ckpt_model_07B_run01/best/model-72700 >> ave validation accuracy 0.86319
# STEP   73000 END @ 2016-12-25 15:33:58.661325, training accuracy 0.95000, ave validation accuracy 0.86318
# << best model so far is saved in ckpt_model_07B_run01/best/model-73100 >> ave validation accuracy 0.86331
# STEP   74000 END @ 2016-12-25 15:36:10.098374, training accuracy 0.93500, ave validation accuracy 0.86130
# STEP   75000 END @ 2016-12-25 15:38:16.157412, training accuracy 0.92000, ave validation accuracy 0.86173
# << hourly save at ckpt_model_07B_run01/hourly/model-75100 and pickle_model_07B_run01 >>
# STEP   76000 END @ 2016-12-25 15:40:28.932605, training accuracy 0.94500, ave validation accuracy 0.86079
# STEP   77000 END @ 2016-12-25 15:42:35.012428, training accuracy 0.94500, ave validation accuracy 0.86200
# STEP   78000 END @ 2016-12-25 15:44:41.148448, training accuracy 0.92000, ave validation accuracy 0.86204
# STEP   79000 END @ 2016-12-25 15:46:47.390699, training accuracy 0.94500, ave validation accuracy 0.86290
# STEP   80000 END @ 2016-12-25 15:48:53.562632, training accuracy 0.93500, ave validation accuracy 0.86165
# STEP   81000 END @ 2016-12-25 15:50:59.789175, training accuracy 0.95500, ave validation accuracy 0.86283
# << best model so far is saved in ckpt_model_07B_run01/best/model-81100 >> ave validation accuracy 0.86356
# << best model so far is saved in ckpt_model_07B_run01/best/model-81200 >> ave validation accuracy 0.86360
# << best model so far is saved in ckpt_model_07B_run01/best/model-81600 >> ave validation accuracy 0.86368
# << best model so far is saved in ckpt_model_07B_run01/best/model-81700 >> ave validation accuracy 0.86418
# << best model so far is saved in ckpt_model_07B_run01/best/model-81800 >> ave validation accuracy 0.86438
# STEP   82000 END @ 2016-12-25 15:53:32.969071, training accuracy 0.93500, ave validation accuracy 0.86393
# STEP   83000 END @ 2016-12-25 15:55:39.179716, training accuracy 0.95000, ave validation accuracy 0.86344
# << best model so far is saved in ckpt_model_07B_run01/best/model-83600 >> ave validation accuracy 0.86443
# STEP   84000 END @ 2016-12-25 15:57:50.456548, training accuracy 0.91500, ave validation accuracy 0.86431
# STEP   85000 END @ 2016-12-25 15:59:56.629541, training accuracy 0.92000, ave validation accuracy 0.86386
# STEP   86000 END @ 2016-12-25 16:02:02.652104, training accuracy 0.94500, ave validation accuracy 0.86389
# << best model so far is saved in ckpt_model_07B_run01/best/model-86300 >> ave validation accuracy 0.86445
# << best model so far is saved in ckpt_model_07B_run01/best/model-86400 >> ave validation accuracy 0.86461
# << best model so far is saved in ckpt_model_07B_run01/best/model-86500 >> ave validation accuracy 0.86478
# << best model so far is saved in ckpt_model_07B_run01/best/model-86800 >> ave validation accuracy 0.86478
# STEP   87000 END @ 2016-12-25 16:04:30.812736, training accuracy 0.95500, ave validation accuracy 0.86416
# STEP   88000 END @ 2016-12-25 16:06:36.925076, training accuracy 0.90500, ave validation accuracy 0.86343
# STEP   89000 END @ 2016-12-25 16:08:43.090690, training accuracy 0.95000, ave validation accuracy 0.86236
# STEP   90000 END @ 2016-12-25 16:10:49.265533, training accuracy 0.93500, ave validation accuracy 0.86371
# STEP   91000 END @ 2016-12-25 16:12:55.418915, training accuracy 0.91000, ave validation accuracy 0.86245
# STEP   92000 END @ 2016-12-25 16:15:01.634501, training accuracy 0.96000, ave validation accuracy 0.86401
# STEP   93000 END @ 2016-12-25 16:17:07.695972, training accuracy 0.96500, ave validation accuracy 0.86310
# STEP   94000 END @ 2016-12-25 16:19:13.797922, training accuracy 0.94500, ave validation accuracy 0.86289
# STEP   95000 END @ 2016-12-25 16:21:19.910094, training accuracy 0.95000, ave validation accuracy 0.86305
# STEP   96000 END @ 2016-12-25 16:23:26.136480, training accuracy 0.94500, ave validation accuracy 0.86311
# << best model so far is saved in ckpt_model_07B_run01/best/model-96400 >> ave validation accuracy 0.86491
# STEP   97000 END @ 2016-12-25 16:25:37.637947, training accuracy 0.92000, ave validation accuracy 0.86455
# STEP   98000 END @ 2016-12-25 16:27:43.866478, training accuracy 0.95500, ave validation accuracy 0.86409
# STEP   99000 END @ 2016-12-25 16:29:49.950051, training accuracy 0.95000, ave validation accuracy 0.86409
# STEP  100000 END @ 2016-12-25 16:31:56.105544, training accuracy 0.95000, ave validation accuracy 0.86434
# << best model so far is saved in ckpt_model_07B_run01/best/model-100300 >> ave validation accuracy 0.86531
# << best model so far is saved in ckpt_model_07B_run01/best/model-100400 >> ave validation accuracy 0.86540
# STEP  101000 END @ 2016-12-25 16:34:12.407696, training accuracy 0.95000, ave validation accuracy 0.86456
# << best model so far is saved in ckpt_model_07B_run01/best/model-101600 >> ave validation accuracy 0.86543
# STEP  102000 END @ 2016-12-25 16:36:24.973258, training accuracy 0.96000, ave validation accuracy 0.86419
# << best model so far is saved in ckpt_model_07B_run01/best/model-102500 >> ave validation accuracy 0.86561
# << best model so far is saved in ckpt_model_07B_run01/best/model-102900 >> ave validation accuracy 0.86583
# << hourly save at ckpt_model_07B_run01/hourly/model-103000 and pickle_model_07B_run01 >>
# STEP  103000 END @ 2016-12-25 16:38:47.650950, training accuracy 0.93000, ave validation accuracy 0.86581
# << best model so far is saved in ckpt_model_07B_run01/best/model-103500 >> ave validation accuracy 0.86629
# << best model so far is saved in ckpt_model_07B_run01/best/model-103600 >> ave validation accuracy 0.86640
# STEP  104000 END @ 2016-12-25 16:41:04.064099, training accuracy 0.97000, ave validation accuracy 0.86634
# STEP  105000 END @ 2016-12-25 16:43:10.299880, training accuracy 0.96500, ave validation accuracy 0.86300
# STEP  106000 END @ 2016-12-25 16:45:16.529963, training accuracy 0.96000, ave validation accuracy 0.86620
# << best model so far is saved in ckpt_model_07B_run01/best/model-106100 >> ave validation accuracy 0.86656
# << best model so far is saved in ckpt_model_07B_run01/best/model-106500 >> ave validation accuracy 0.86683
# STEP  107000 END @ 2016-12-25 16:47:34.271486, training accuracy 0.95500, ave validation accuracy 0.86630
# STEP  108000 END @ 2016-12-25 16:49:40.314807, training accuracy 0.94000, ave validation accuracy 0.86583
# STEP  109000 END @ 2016-12-25 16:51:46.615368, training accuracy 0.94000, ave validation accuracy 0.86490
# << best model so far is saved in ckpt_model_07B_run01/best/model-109800 >> ave validation accuracy 0.86748
# << best model so far is saved in ckpt_model_07B_run01/best/model-109900 >> ave validation accuracy 0.86760
# << best model so far is saved in ckpt_model_07B_run01/best/model-110000 >> ave validation accuracy 0.86809
# STEP  110000 END @ 2016-12-25 16:54:08.029927, training accuracy 0.96500, ave validation accuracy 0.86809
# << best model so far is saved in ckpt_model_07B_run01/best/model-110100 >> ave validation accuracy 0.86840
# << best model so far is saved in ckpt_model_07B_run01/best/model-110400 >> ave validation accuracy 0.86886
# STEP  111000 END @ 2016-12-25 16:56:25.985281, training accuracy 0.92500, ave validation accuracy 0.86739
# STEP  112000 END @ 2016-12-25 16:58:32.268404, training accuracy 0.93000, ave validation accuracy 0.86784
# STEP  113000 END @ 2016-12-25 17:00:38.547819, training accuracy 0.95500, ave validation accuracy 0.86621
# STEP  114000 END @ 2016-12-25 17:02:44.659260, training accuracy 0.97500, ave validation accuracy 0.86748
# STEP  115000 END @ 2016-12-25 17:04:50.990503, training accuracy 0.95500, ave validation accuracy 0.86783
# STEP  116000 END @ 2016-12-25 17:06:57.355235, training accuracy 0.94000, ave validation accuracy 0.86828
# STEP  117000 END @ 2016-12-25 17:09:03.489821, training accuracy 0.96000, ave validation accuracy 0.86715
# STEP  118000 END @ 2016-12-25 17:11:09.823714, training accuracy 0.96000, ave validation accuracy 0.86671
# STEP  119000 END @ 2016-12-25 17:13:16.105308, training accuracy 0.93500, ave validation accuracy 0.86551
# STEP  120000 END @ 2016-12-25 17:15:22.358142, training accuracy 0.98500, ave validation accuracy 0.86850
# STEP  121000 END @ 2016-12-25 17:17:28.471673, training accuracy 0.96000, ave validation accuracy 0.86874
# << best model so far is saved in ckpt_model_07B_run01/best/model-121100 >> ave validation accuracy 0.86899
# << best model so far is saved in ckpt_model_07B_run01/best/model-121200 >> ave validation accuracy 0.86930
# STEP  122000 END @ 2016-12-25 17:19:44.822782, training accuracy 0.93000, ave validation accuracy 0.86718
# STEP  123000 END @ 2016-12-25 17:21:50.933342, training accuracy 0.95000, ave validation accuracy 0.86638
# STEP  124000 END @ 2016-12-25 17:23:57.073741, training accuracy 0.95500, ave validation accuracy 0.86809
# STEP  125000 END @ 2016-12-25 17:26:03.216156, training accuracy 0.95000, ave validation accuracy 0.86688
# STEP  126000 END @ 2016-12-25 17:28:09.336127, training accuracy 0.96500, ave validation accuracy 0.86683
# STEP  127000 END @ 2016-12-25 17:30:15.447383, training accuracy 0.96000, ave validation accuracy 0.86619
# STEP  128000 END @ 2016-12-25 17:32:21.529475, training accuracy 0.95500, ave validation accuracy 0.86720
# STEP  129000 END @ 2016-12-25 17:34:27.611804, training accuracy 0.94000, ave validation accuracy 0.86666
# STEP  130000 END @ 2016-12-25 17:36:33.703717, training accuracy 0.95000, ave validation accuracy 0.86545
# STEP  131000 END @ 2016-12-25 17:38:39.996813, training accuracy 0.95500, ave validation accuracy 0.86778
# << hourly save at ckpt_model_07B_run01/hourly/model-131100 and pickle_model_07B_run01 >>
# STEP  132000 END @ 2016-12-25 17:40:52.495200, training accuracy 0.97000, ave validation accuracy 0.86670
# STEP  133000 END @ 2016-12-25 17:42:58.626249, training accuracy 0.94500, ave validation accuracy 0.86846
# STEP  134000 END @ 2016-12-25 17:45:04.728408, training accuracy 0.97000, ave validation accuracy 0.86730
# STEP  135000 END @ 2016-12-25 17:47:10.846939, training accuracy 0.96500, ave validation accuracy 0.86730
# STEP  136000 END @ 2016-12-25 17:49:16.973081, training accuracy 0.95500, ave validation accuracy 0.86825
# STEP  137000 END @ 2016-12-25 17:51:23.083655, training accuracy 0.96500, ave validation accuracy 0.86739
# STEP  138000 END @ 2016-12-25 17:53:29.208189, training accuracy 0.91500, ave validation accuracy 0.86814
# STEP  139000 END @ 2016-12-25 17:55:35.315308, training accuracy 0.93500, ave validation accuracy 0.86914
# << best model so far is saved in ckpt_model_07B_run01/best/model-139100 >> ave validation accuracy 0.87010
# << best model so far is saved in ckpt_model_07B_run01/best/model-139600 >> ave validation accuracy 0.87021
# STEP  140000 END @ 2016-12-25 17:57:53.323388, training accuracy 0.96500, ave validation accuracy 0.86955
# STEP  141000 END @ 2016-12-25 17:59:59.390711, training accuracy 0.96500, ave validation accuracy 0.86963
# << best model so far is saved in ckpt_model_07B_run01/best/model-142000 >> ave validation accuracy 0.87039
# STEP  142000 END @ 2016-12-25 18:02:09.290712, training accuracy 0.97500, ave validation accuracy 0.87039
# STEP  143000 END @ 2016-12-25 18:04:15.493970, training accuracy 0.93500, ave validation accuracy 0.87019
# << best model so far is saved in ckpt_model_07B_run01/best/model-143200 >> ave validation accuracy 0.87056
# << best model so far is saved in ckpt_model_07B_run01/best/model-143300 >> ave validation accuracy 0.87063
# << best model so far is saved in ckpt_model_07B_run01/best/model-143600 >> ave validation accuracy 0.87081
# STEP  144000 END @ 2016-12-25 18:06:39.585136, training accuracy 0.98000, ave validation accuracy 0.86980
# << best model so far is saved in ckpt_model_07B_run01/best/model-144900 >> ave validation accuracy 0.87126
# << best model so far is saved in ckpt_model_07B_run01/best/model-145000 >> ave validation accuracy 0.87145
# STEP  145000 END @ 2016-12-25 18:08:55.756394, training accuracy 0.96500, ave validation accuracy 0.87145
# << best model so far is saved in ckpt_model_07B_run01/best/model-145100 >> ave validation accuracy 0.87205
# STEP  146000 END @ 2016-12-25 18:11:06.929114, training accuracy 0.95000, ave validation accuracy 0.86871
# STEP  147000 END @ 2016-12-25 18:13:13.155772, training accuracy 0.92500, ave validation accuracy 0.86856
# STEP  148000 END @ 2016-12-25 18:15:19.454994, training accuracy 0.96000, ave validation accuracy 0.86835
# STEP  149000 END @ 2016-12-25 18:17:25.652583, training accuracy 0.97000, ave validation accuracy 0.86879
# STEP  150000 END @ 2016-12-25 18:19:31.773711, training accuracy 0.96500, ave validation accuracy 0.86953
# STEP  151000 END @ 2016-12-25 18:21:37.929955, training accuracy 0.93000, ave validation accuracy 0.86848
# STEP  152000 END @ 2016-12-25 18:23:44.142363, training accuracy 0.95500, ave validation accuracy 0.86859
# STEP  153000 END @ 2016-12-25 18:25:50.226940, training accuracy 0.96500, ave validation accuracy 0.86980
# STEP  154000 END @ 2016-12-25 18:27:56.373775, training accuracy 0.95500, ave validation accuracy 0.87145
# STEP  155000 END @ 2016-12-25 18:30:02.557904, training accuracy 0.95500, ave validation accuracy 0.86869
# STEP  156000 END @ 2016-12-25 18:32:08.778287, training accuracy 0.99000, ave validation accuracy 0.87008
# STEP  157000 END @ 2016-12-25 18:34:14.964707, training accuracy 0.94000, ave validation accuracy 0.86929
# STEP  158000 END @ 2016-12-25 18:36:21.183895, training accuracy 0.97000, ave validation accuracy 0.87016
# STEP  159000 END @ 2016-12-25 18:38:27.384000, training accuracy 0.95500, ave validation accuracy 0.86916
# << hourly save at ckpt_model_07B_run01/hourly/model-159300 and pickle_model_07B_run01 >>
# STEP  160000 END @ 2016-12-25 18:40:38.666943, training accuracy 0.94500, ave validation accuracy 0.86875
# STEP  161000 END @ 2016-12-25 18:42:44.863586, training accuracy 0.96500, ave validation accuracy 0.86956
# STEP  162000 END @ 2016-12-25 18:44:51.008117, training accuracy 0.97500, ave validation accuracy 0.86860
# STEP  163000 END @ 2016-12-25 18:46:57.219833, training accuracy 0.91000, ave validation accuracy 0.86953
# STEP  164000 END @ 2016-12-25 18:49:03.323470, training accuracy 0.95500, ave validation accuracy 0.87003
# STEP  165000 END @ 2016-12-25 18:51:09.657750, training accuracy 0.98000, ave validation accuracy 0.86958
# STEP  166000 END @ 2016-12-25 18:53:15.728664, training accuracy 0.97000, ave validation accuracy 0.87020
# STEP  167000 END @ 2016-12-25 18:55:21.986872, training accuracy 0.94500, ave validation accuracy 0.87009
# STEP  168000 END @ 2016-12-25 18:57:28.211747, training accuracy 0.96000, ave validation accuracy 0.86958
# STEP  169000 END @ 2016-12-25 18:59:34.456372, training accuracy 0.96500, ave validation accuracy 0.86999
# STEP  170000 END @ 2016-12-25 19:01:40.658423, training accuracy 0.94500, ave validation accuracy 0.86999
# STEP  171000 END @ 2016-12-25 19:03:46.933045, training accuracy 0.97000, ave validation accuracy 0.86970
# ...
# STEP  586000 END @ 2016-12-26 09:42:50.225132, training accuracy 0.97000, ave validation accuracy 0.87940
# STEP  587000 END @ 2016-12-26 09:44:56.310694, training accuracy 0.97000, ave validation accuracy 0.88023
# STEP  588000 END @ 2016-12-26 09:47:02.393686, training accuracy 0.95500, ave validation accuracy 0.87929
# STEP  589000 END @ 2016-12-26 09:49:08.547632, training accuracy 0.97000, ave validation accuracy 0.87924
# << best model so far is saved in ckpt_model_07B_run01/best/model-589600 >> ave validation accuracy 0.88118
# << best model so far is saved in ckpt_model_07B_run01/best/model-589800 >> ave validation accuracy 0.88149
# << best model so far is saved in ckpt_model_07B_run01/best/model-589900 >> ave validation accuracy 0.88154
# << best model so far is saved in ckpt_model_07B_run01/best/model-590000 >> ave validation accuracy 0.88173
# STEP  590000 END @ 2016-12-26 09:51:36.648974, training accuracy 0.98000, ave validation accuracy 0.88173
# STEP  591000 END @ 2016-12-26 09:53:42.772057, training accuracy 0.99000, ave validation accuracy 0.88034
# STEP  592000 END @ 2016-12-26 09:55:48.945286, training accuracy 0.98500, ave validation accuracy 0.88049
# STEP  593000 END @ 2016-12-26 09:57:55.030138, training accuracy 0.98000, ave validation accuracy 0.87845
# STEP  594000 END @ 2016-12-26 10:00:01.129156, training accuracy 0.99000, ave validation accuracy 0.87845
# STEP  595000 END @ 2016-12-26 10:02:07.209464, training accuracy 0.97500, ave validation accuracy 0.88026
# STEP  596000 END @ 2016-12-26 10:04:13.343976, training accuracy 0.97500, ave validation accuracy 0.88063
# STEP  597000 END @ 2016-12-26 10:06:19.424129, training accuracy 0.97000, ave validation accuracy 0.87926
# STEP  598000 END @ 2016-12-26 10:08:25.516208, training accuracy 1.00000, ave validation accuracy 0.87951
# STEP  599000 END @ 2016-12-26 10:10:31.740264, training accuracy 0.99000, ave validation accuracy 0.87975
# STEP  600000 END @ 2016-12-26 10:12:38.092617, training accuracy 0.97500, ave validation accuracy 0.87909
# STEP  601000 END @ 2016-12-26 10:14:44.304452, training accuracy 0.99000, ave validation accuracy 0.87964
# STEP  602000 END @ 2016-12-26 10:16:50.602001, training accuracy 0.98000, ave validation accuracy 0.88015
# STEP  603000 END @ 2016-12-26 10:18:56.526754, training accuracy 0.98000, ave validation accuracy 0.88014
# STEP  604000 END @ 2016-12-26 10:21:02.578135, training accuracy 0.98500, ave validation accuracy 0.87970
# STEP  605000 END @ 2016-12-26 10:23:08.695161, training accuracy 0.97500, ave validation accuracy 0.87924
# STEP  606000 END @ 2016-12-26 10:25:14.762657, training accuracy 0.99500, ave validation accuracy 0.87975
# STEP  607000 END @ 2016-12-26 10:27:20.962560, training accuracy 0.98000, ave validation accuracy 0.87968
# STEP  608000 END @ 2016-12-26 10:29:26.996305, training accuracy 0.97000, ave validation accuracy 0.87924
# STEP  609000 END @ 2016-12-26 10:31:33.091688, training accuracy 0.98500, ave validation accuracy 0.87933
# STEP  610000 END @ 2016-12-26 10:33:39.047654, training accuracy 0.98500, ave validation accuracy 0.87971
# STEP  611000 END @ 2016-12-26 10:35:45.093906, training accuracy 0.98000, ave validation accuracy 0.87933
# STEP  612000 END @ 2016-12-26 10:37:51.079916, training accuracy 0.99000, ave validation accuracy 0.87948
# STEP  613000 END @ 2016-12-26 10:39:56.966229, training accuracy 0.97000, ave validation accuracy 0.87825
# STEP  614000 END @ 2016-12-26 10:42:03.076084, training accuracy 0.97500, ave validation accuracy 0.87928
# << hourly save at ckpt_model_07B_run01/hourly/model-614100 and pickle_model_07B_run01 >>
# STEP  615000 END @ 2016-12-26 10:44:15.822890, training accuracy 0.97000, ave validation accuracy 0.87956
# STEP  616000 END @ 2016-12-26 10:46:21.940030, training accuracy 0.97500, ave validation accuracy 0.87981
# STEP  617000 END @ 2016-12-26 10:48:28.002549, training accuracy 0.97500, ave validation accuracy 0.87906
# STEP  618000 END @ 2016-12-26 10:50:34.071723, training accuracy 0.98500, ave validation accuracy 0.88026
# STEP  619000 END @ 2016-12-26 10:52:40.184254, training accuracy 0.99500, ave validation accuracy 0.87946
# STEP  620000 END @ 2016-12-26 10:54:46.338300, training accuracy 0.99000, ave validation accuracy 0.87968
# STEP  621000 END @ 2016-12-26 10:56:52.365388, training accuracy 0.97500, ave validation accuracy 0.87786
# STEP  622000 END @ 2016-12-26 10:58:58.473262, training accuracy 0.98000, ave validation accuracy 0.88061
# STEP  623000 END @ 2016-12-26 11:01:04.517564, training accuracy 0.99000, ave validation accuracy 0.87896
# STEP  624000 END @ 2016-12-26 11:03:10.609685, training accuracy 0.97000, ave validation accuracy 0.87856
# STEP  625000 END @ 2016-12-26 11:05:16.627577, training accuracy 0.98500, ave validation accuracy 0.87841
# STEP  626000 END @ 2016-12-26 11:07:22.793337, training accuracy 0.98000, ave validation accuracy 0.87974
# STEP  627000 END @ 2016-12-26 11:09:28.888572, training accuracy 0.98000, ave validation accuracy 0.87873
# STEP  628000 END @ 2016-12-26 11:11:34.890122, training accuracy 0.97500, ave validation accuracy 0.87843
# STEP  629000 END @ 2016-12-26 11:13:40.914483, training accuracy 0.99000, ave validation accuracy 0.87919
# STEP  630000 END @ 2016-12-26 11:15:46.889605, training accuracy 0.97000, ave validation accuracy 0.87899
# STEP  631000 END @ 2016-12-26 11:17:52.932788, training accuracy 0.99000, ave validation accuracy 0.87919
# STEP  632000 END @ 2016-12-26 11:19:59.150077, training accuracy 0.99000, ave validation accuracy 0.87869
# STEP  633000 END @ 2016-12-26 11:22:05.268740, training accuracy 0.98000, ave validation accuracy 0.87950
# STEP  634000 END @ 2016-12-26 11:24:11.213540, training accuracy 0.97000, ave validation accuracy 0.88004
# STEP  635000 END @ 2016-12-26 11:26:17.201830, training accuracy 0.98000, ave validation accuracy 0.87931
# STEP  636000 END @ 2016-12-26 11:28:23.473274, training accuracy 0.99000, ave validation accuracy 0.87973
# STEP  637000 END @ 2016-12-26 11:30:29.431434, training accuracy 0.97000, ave validation accuracy 0.88026
# STEP  638000 END @ 2016-12-26 11:32:35.415205, training accuracy 0.99000, ave validation accuracy 0.87938
# STEP  639000 END @ 2016-12-26 11:34:41.357262, training accuracy 0.98500, ave validation accuracy 0.88009
# STEP  640000 END @ 2016-12-26 11:36:47.395683, training accuracy 0.98500, ave validation accuracy 0.88024
# STEP  641000 END @ 2016-12-26 11:38:53.401053, training accuracy 0.98500, ave validation accuracy 0.87973
# STEP  642000 END @ 2016-12-26 11:40:59.541947, training accuracy 0.96500, ave validation accuracy 0.87820
# << hourly save at ckpt_model_07B_run01/hourly/model-642700 and pickle_model_07B_run01 >>
# STEP  643000 END @ 2016-12-26 11:43:10.699328, training accuracy 0.98000, ave validation accuracy 0.87966
# STEP  644000 END @ 2016-12-26 11:45:16.817697, training accuracy 0.97500, ave validation accuracy 0.88103
# STEP  645000 END @ 2016-12-26 11:47:23.027988, training accuracy 0.99000, ave validation accuracy 0.88060
# STEP  646000 END @ 2016-12-26 11:49:29.102540, training accuracy 0.98000, ave validation accuracy 0.88039
# STEP  647000 END @ 2016-12-26 11:51:35.453649, training accuracy 0.98000, ave validation accuracy 0.87980
# STEP  648000 END @ 2016-12-26 11:53:41.576164, training accuracy 0.98000, ave validation accuracy 0.87994
# STEP  649000 END @ 2016-12-26 11:55:47.745164, training accuracy 0.99500, ave validation accuracy 0.87919
# STEP  650000 END @ 2016-12-26 11:57:53.893173, training accuracy 0.97500, ave validation accuracy 0.87904
# STEP  651000 END @ 2016-12-26 11:59:59.877204, training accuracy 0.98500, ave validation accuracy 0.88113
# STEP  652000 END @ 2016-12-26 12:02:06.015998, training accuracy 0.99000, ave validation accuracy 0.87994
# STEP  653000 END @ 2016-12-26 12:04:12.106989, training accuracy 0.96500, ave validation accuracy 0.87988
# STEP  654000 END @ 2016-12-26 12:06:18.205874, training accuracy 0.96000, ave validation accuracy 0.87963
# STEP  655000 END @ 2016-12-26 12:08:24.337499, training accuracy 0.98000, ave validation accuracy 0.87991
# STEP  656000 END @ 2016-12-26 12:10:30.337667, training accuracy 0.98500, ave validation accuracy 0.87899
# STEP  657000 END @ 2016-12-26 12:12:36.454312, training accuracy 0.99500, ave validation accuracy 0.87959
# STEP  658000 END @ 2016-12-26 12:14:42.526502, training accuracy 0.98000, ave validation accuracy 0.87926
# STEP  659000 END @ 2016-12-26 12:16:48.576569, training accuracy 0.99000, ave validation accuracy 0.88009
# STEP  660000 END @ 2016-12-26 12:18:54.615096, training accuracy 0.98000, ave validation accuracy 0.87846
# STEP  661000 END @ 2016-12-26 12:21:00.848216, training accuracy 0.97000, ave validation accuracy 0.87911
# STEP  662000 END @ 2016-12-26 12:23:06.987601, training accuracy 0.98000, ave validation accuracy 0.88073
# STEP  663000 END @ 2016-12-26 12:25:13.070257, training accuracy 0.98500, ave validation accuracy 0.88054
# STEP  664000 END @ 2016-12-26 12:27:19.157472, training accuracy 0.97000, ave validation accuracy 0.87988
# STEP  665000 END @ 2016-12-26 12:29:25.365167, training accuracy 0.97500, ave validation accuracy 0.88013
# STEP  666000 END @ 2016-12-26 12:31:31.407850, training accuracy 0.96000, ave validation accuracy 0.88001
# STEP  667000 END @ 2016-12-26 12:33:37.468785, training accuracy 0.99000, ave validation accuracy 0.88050
# << best model so far is saved in ckpt_model_07B_run01/best/model-667800 >> ave validation accuracy 0.88189
# << best model so far is saved in ckpt_model_07B_run01/best/model-668000 >> ave validation accuracy 0.88209
# STEP  668000 END @ 2016-12-26 12:35:55.448324, training accuracy 0.98500, ave validation accuracy 0.88209
# STEP  669000 END @ 2016-12-26 12:38:01.426304, training accuracy 0.99000, ave validation accuracy 0.87933
# STEP  670000 END @ 2016-12-26 12:40:07.564677, training accuracy 0.97000, ave validation accuracy 0.87814
# STEP  671000 END @ 2016-12-26 12:42:13.693061, training accuracy 0.98500, ave validation accuracy 0.87976
# << hourly save at ckpt_model_07B_run01/hourly/model-671200 and pickle_model_07B_run01 >>
# STEP  672000 END @ 2016-12-26 12:44:23.821113, training accuracy 0.97500, ave validation accuracy 0.87999
# STEP  673000 END @ 2016-12-26 12:46:29.921423, training accuracy 0.97000, ave validation accuracy 0.87938
# STEP  674000 END @ 2016-12-26 12:48:35.973609, training accuracy 0.98000, ave validation accuracy 0.88006
# STEP  675000 END @ 2016-12-26 12:50:41.970416, training accuracy 0.99000, ave validation accuracy 0.88025
# STEP  676000 END @ 2016-12-26 12:52:48.025790, training accuracy 0.97000, ave validation accuracy 0.88099
# STEP  677000 END @ 2016-12-26 12:54:54.006027, training accuracy 0.99000, ave validation accuracy 0.88101
# STEP  678000 END @ 2016-12-26 12:57:00.170619, training accuracy 0.99000, ave validation accuracy 0.87853
# STEP  679000 END @ 2016-12-26 12:59:06.302739, training accuracy 0.98500, ave validation accuracy 0.87993
# STEP  680000 END @ 2016-12-26 13:01:12.349967, training accuracy 0.98500, ave validation accuracy 0.88069
# STEP  681000 END @ 2016-12-26 13:03:18.276865, training accuracy 0.95500, ave validation accuracy 0.88051
# STEP  682000 END @ 2016-12-26 13:05:24.362400, training accuracy 0.98000, ave validation accuracy 0.88069
# STEP  683000 END @ 2016-12-26 13:07:30.453584, training accuracy 1.00000, ave validation accuracy 0.87928
# STEP  684000 END @ 2016-12-26 13:09:36.437723, training accuracy 0.99000, ave validation accuracy 0.87931
# STEP  685000 END @ 2016-12-26 13:11:42.420731, training accuracy 1.00000, ave validation accuracy 0.88000
# STEP  686000 END @ 2016-12-26 13:13:48.608384, training accuracy 0.97500, ave validation accuracy 0.87996
# STEP  687000 END @ 2016-12-26 13:15:54.578878, training accuracy 0.99000, ave validation accuracy 0.87954
# STEP  688000 END @ 2016-12-26 13:18:00.827560, training accuracy 0.98000, ave validation accuracy 0.88101
# STEP  689000 END @ 2016-12-26 13:20:06.927732, training accuracy 0.97500, ave validation accuracy 0.88004
# STEP  690000 END @ 2016-12-26 13:22:13.171406, training accuracy 0.96500, ave validation accuracy 0.88029
# STEP  691000 END @ 2016-12-26 13:24:19.212657, training accuracy 0.98500, ave validation accuracy 0.88059
# STEP  692000 END @ 2016-12-26 13:26:25.268880, training accuracy 0.99000, ave validation accuracy 0.88199
# << best model so far is saved in ckpt_model_07B_run01/best/model-692100 >> ave validation accuracy 0.88221
# << best model so far is saved in ckpt_model_07B_run01/best/model-692200 >> ave validation accuracy 0.88248
# << best model so far is saved in ckpt_model_07B_run01/best/model-692500 >> ave validation accuracy 0.88273
# << best model so far is saved in ckpt_model_07B_run01/best/model-692600 >> ave validation accuracy 0.88284
# STEP  693000 END @ 2016-12-26 13:28:55.338705, training accuracy 0.98500, ave validation accuracy 0.88195
# STEP  694000 END @ 2016-12-26 13:31:01.501767, training accuracy 0.99500, ave validation accuracy 0.88143
# STEP  695000 END @ 2016-12-26 13:33:07.546191, training accuracy 0.98000, ave validation accuracy 0.88124
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-feafc4fc8124> in <module>()
#       1 #Train the model
# ----> 2 train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#
# /home/kumiko/cifar10/helper_functions.pyc in train(continued, graph_variables, accuracy_log, train_data, train_labels, validation_data, validation_labels)
#     251             _, summary = sess.run([graph_variables['optimizer'], graph_variables['summarizer']],
#     252                                   feed_dict={graph_variables['data']: batch_data, graph_variables['labels']: batch_labels,
# --> 253                                              graph_variables['keep_prob']: accuracy_log['variables']['dropout_train_keep_prob'], graph_variables['is_training']: True})
#     254
#     255             if i % accuracy_log['variables']['log_every'] == 0:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Test accuracy
test_accuracy(graph_variables, accuracy_log, test_data, test_labels)
# Out:
# << test accuracy 0.87050 >>
